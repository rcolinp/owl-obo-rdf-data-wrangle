# %%
import obonet as obo
import networkx as nx

# %%
# Using obonet, read in OBOFoundry URL for ncit.obo
## Reference http://www.obofoundry.org/ for all available OBO ontologies via OBOFoundry
# This will take ~2.5 minutes to complete

url = 'http://purl.obolibrary.org/obo/ncit.obo'
graph = obo.read_obo(url)
len(graph)
# Out:
# 162169

# %%
# Number of edges
graph.number_of_edges()
# Out:
# 235888

# %%
# Number of nodes
graph.number_of_nodes()
# Out:
# 162169

# %%
# Retreive properties of Parp Inhibitor (Poly (ADP-Ribose) Polymerase Inhibitor) -> Parp Inhibitor
graph.nodes['NCIT:C62554']
# Out:
# {'name': 'Poly (ADP-Ribose) Polymerase Inhibitor',
#  'def': '"Any substance that inhibits Poly (ADP-Ribose) polymerase, an enzyme involved in detecting DNA single strand breaks and the initiation of DNA repair. Inhibition of Poly (ADP-Ribose) polymerase has direct cytotoxic effects by inhibiting DNA repair and causing cell death." []',
#  'subset': ['NCIT:C116977', 'NCIT:C116978'],
#  'synonym': ['"PARP Inhibitor" EXACT []',
#   '"PARP Inhibitor" EXACT []',
#   '"PARP inhibitor" EXACT []',
#   '"Poly (ADP-Ribose) Polymerase Inhibitor" EXACT []',
#   '"poly (ADP-ribose) polymerase inhibitor" EXACT []',
#   '"Poly(ADP-Ribose) Polymerase Inhibitor" EXACT []'],
#  'is_a': ['NCIT:C163758', 'NCIT:C471'],
#  'relationship': ['NCIT:R146 NCIT:C48215'],
#  'property_value': ['NCIT:NHC0 "C62554" xsd:string',
#   'NCIT:P106 "Chemical Viewed Functionally" xsd:string',
#   'NCIT:P107 "PARP Inhibitor" xsd:string',
#   'NCIT:P108 "Poly (ADP-Ribose) Polymerase Inhibitor" xsd:string',
#   'NCIT:P207 "C1882413" xsd:string',
#   'NCIT:P322 "CTRP" xsd:string',
#   'NCIT:P325 "A substance that blocks an enzyme involved in many functions of the cell, including the repair of DNA damage. DNA damage may be caused by normal cell actions, UV light, some anticancer drugs, and radiation used to treat cancer. It may cause cancer cells to die. It is a type of targeted therapy." xsd:string',
#   'NCIT:P366 "Poly_ADP-Ribose_Polymerase_Inhibitor" xsd:string',
#   'NCIT:P368 CHEBI:62913 xsd:string']}

# %%
# Define a id (source code i.e. NCIT:C62554) to preferred label mapping for NCI Thesaurus OBO file 
id_to_name = {id_: data.get('name') for id_, data in graph.nodes(data=True)}
name_to_id = {data['name']: id_ for id_, data in graph.nodes(data=True) if 'name' in data}

# %%
# id -> name mapping
print({len(id_to_name)})
id_to_name
# Out:
# {162169}
# {'NCIT:C1000': 'Recombinant Amphiregulin',
#  'NCIT:C10000': 'Cyclophosphamide/Fluoxymesterone/Mitolactol/Prednisone/Tamoxifen',
#  'NCIT:C100000': 'Percutaneous Coronary Intervention for ST Elevation Myocardial Infarction-Stable-Over 12 Hours From Symptom Onset',
#  'NCIT:C100001': 'Percutaneous Coronary Intervention for ST Elevation Myocardial Infarction-Stable After Successful Full-Dose Thrombolytic Therapy',
#  'NCIT:C100002': 'Percutaneous Coronary Intervention for ST Elevation Myocardial Infarction-Unstable-Over 12 Hours From Symptom Onset',
#  'NCIT:C100003': 'Percutaneous Mitral Valve Repair',
#  'NCIT:C100004': 'Pericardial Stripping',
#  'NCIT:C100005': 'Post-Cardiac Transplant Evaluation',
#  'NCIT:C100006': 'Pre-Operative Evaluation for Non-Cardiovascular Surgery',
#  'NCIT:C100007': 'Previously Implanted Cardiac Lead',
#  'NCIT:C100008': 'Rescue Percutaneous Coronary Intervention for ST Elevation Myocardial Infarction After Failed Full-Dose Thrombolytic Therapy',
#  'NCIT:C100009': 'Reused Cardiac Lead',
#  'NCIT:C10001': 'CONPADRI-I Regimen',
#  'NCIT:C100010': 'Right Cardiac Ventricle Assist Device Procedure',
#  'NCIT:C100011': 'Right Cardiac Ventricle Pacing Malfunction',
#  'NCIT:C100012': 'Severe Cardiac Valve Regurgitation',
#  'NCIT:C100013': 'Severe Cardiac Valve Stenosis',
#  'NCIT:C100014': 'Spontaneous Sustained Ventricular Tachycardia by ECG Finding',
#  'NCIT:C100015': 'Staged Percutaneous Coronary Intervention',
#  'NCIT:C100016': 'Subject Delay in Providing Consent',
#  'NCIT:C100017': 'Surgical Maze Procedure',
#  'NCIT:C100018': 'Syncope with High Risk Cardiac Characteristics',
#  'NCIT:C100019': 'Syncope with Inducible Ventricular Tachycardia by ECG Finding',
#  'NCIT:C10002': 'Cyclophosphamide/Doxorubicin/Fluorouracil/Methotrexate/Prednisone/Vincristine',
#  'NCIT:C100020': 'Three Vessel Coronary Disease',
#  'NCIT:C100021': 'Thrombolysis in Myocardial Infarction Flow',
#  'NCIT:C100022': 'Transcatheter Aortic Valve Implantation',
#  'NCIT:C100023': 'Two Vessel Coronary Disease',
#  'NCIT:C100024': 'Typical Coronary Artery Disease Symptom',
#  'NCIT:C100025': 'Unable to Obtain Acceptable Pacing Thresholds',
#  'NCIT:C100026': 'Unable to Obtain Satisfactory Coronary Sinus Access',
#  'NCIT:C100027': 'Unable to Obtain Satisfactory Vascular Access',
#  'NCIT:C100028': 'Unable to Position Lead Due to Coronary Sinus Dissection',
#  'NCIT:C100029': 'Unable to Position Lead In tributary Vein of Coronary Sinus',
#  'NCIT:C10003': 'Methotrexate/Teniposide',
#  'NCIT:C100030': 'Upgrade to Cardiac Device with Additional Pacing Capabilities',
#  'NCIT:C100031': 'Urgent Procedure',
#  'NCIT:C100032': 'American College of Cardiology/American Heart Association Lesion Complexity Class',
#  'NCIT:C100033': 'Cardiac Arrest/Arrhythmia Etiology Unknown',
#  'NCIT:C100034': 'Cardiac Lead Dislodgement Requiring Reposition/Reoperation',
#  'NCIT:C100035': 'Faulty Device Connector/Header',
#  'NCIT:C100036': 'Idiopathic Primary Ventricular Tachycardia/Ventricular Flutter by ECG Finding',
#  'NCIT:C100037': 'American College of Cardiology/American Heart Association Lesion Complexity Score A',
#  'NCIT:C100038': 'American College of Cardiology/American Heart Association Lesion Complexity Score B',
#  'NCIT:C100039': 'American College of Cardiology/American Heart Association Lesion Complexity Score C',
#  'NCIT:C10004': 'Cyclophosphamide/Fluorouracil/Methotrexate/Prednisone/Tamoxifen/Vincristine',
#  'NCIT:C100040': 'Thrombolysis in Myocardial Infarction Flow-0',
#  'NCIT:C100041': 'Thrombolysis in Myocardial Infarction Flow-1',
#  'NCIT:C100042': 'Thrombolysis in Myocardial Infarction Flow-2',
#  'NCIT:C100043': 'Thrombolysis in Myocardial Infarction Flow-3',
#  'NCIT:C100044': 'Pulmonic Valvuloplasty',
#  'NCIT:C100045': 'Manufacturer Recall',
#  'NCIT:C100046': 'Evaux Spring Water-based Topical Spray',
#  'NCIT:C100047': 'File Transfer Protocol',
#  'NCIT:C100048': 'Secure File Transfer Protocol',
#  'NCIT:C100049': 'Transfer Of Images And Data',
#  'NCIT:C10005': 'Altretamine/Cyclophosphamide/Doxorubicin/Prednisone/Vincristine',
#  'NCIT:C100050': 'Needle Free Injection',
#  'NCIT:C100051': 'Renal Cell Carcinoma Associated with Neuroblastoma',
#  'NCIT:C100052': 'Needle Free Injection Dosing Unit',
#  'NCIT:C100053': 'Sinus Node Functional Assessment',
#  'NCIT:C100054': 'Conjunctival Melanocytic Intraepithelial Neoplasia',
#  'NCIT:C100055': 'Immigrant',
#  'NCIT:C100056': 'Arterial Access Site',
#  'NCIT:C100057': 'Arterial Access Closure',
#  'NCIT:C100058': 'Pre-Procedure',
#  'NCIT:C100059': 'Post-Procedure',
#  'NCIT:C10006': 'Altretamine/Cisplatin/Cyclophosphamide/Misonidazole',
#  'NCIT:C100060': 'Intrinsic QRS Duration',
#  'NCIT:C100061': 'Paced Ventricular Rhythm without Intrinsic Ventricular Complexes',
#  'NCIT:C100062': 'Chronic Total Coronary Artery Occlusion',
#  'NCIT:C100063': 'Coronary Vessel Lesion',
#  'NCIT:C100064': 'Coronary Artery Graft',
#  'NCIT:C100065': 'Glyceryl Dibehenate',
#  'NCIT:C100066': 'Coronary Lesion Complexity',
#  'NCIT:C100067': 'Coronary Reperfusion Procedure',
#  'NCIT:C100068': 'Cardiac Ablation',
#  'NCIT:C100069': 'Cardiac Valve Injury',
#  'NCIT:C10007': 'CytaBOM Regimen',
#  'NCIT:C100070': 'Coronary Venous Dissection',
#  'NCIT:C100071': 'Cardiac Computerized Tomographic Angiography',
#  'NCIT:C100072': 'Coronary Culprit Lesion',
#  'NCIT:C100073': 'Cardiac Stress Test',
#  'NCIT:C100074': 'Cardiac Ischemic Risk Score',
#  'NCIT:C100075': 'Non-Invasive Cardiac Stress Test',
#  'NCIT:C100076': 'Sinus Rhythm',
#  'NCIT:C100077': 'Luminal Carotid Thrombus',
#  'NCIT:C100078': 'Transplant Waiting List',
#  'NCIT:C100079': 'Smoking Tobacco',
#  'NCIT:C10008': 'Asparaginase/Methotrexate/Vincristine',
#  'NCIT:C100080': 'Cardiac Stent Placement',
#  'NCIT:C100081': 'In Stent Restenosis',
#  'NCIT:C100082': 'Guidewire Across Lesion',
#  'NCIT:C100083': 'Coronary Artery Perforation',
#  'NCIT:C100084': 'Cardiac Diagnostic Procedure',
#  'NCIT:C100085': 'Coronary Angiography',
#  'NCIT:C100086': 'Coronary Artery Dominance',
#  'NCIT:C100087': 'Intra-Aortic Balloon Pump',
#  'NCIT:C100088': 'Interferon Gamma-1a',
#  'NCIT:C100089': 'Interferon Gamma-1b',
#  'NCIT:C10009': 'Prednisolone/Tamoxifen',
#  'NCIT:C100090': 'Bifocal',
#  'NCIT:C100091': 'Eosinophil Lysophospholipase',
#  'NCIT:C100092': 'Fistulagram',
#  'NCIT:C100093': 'Central Nervous System Nongerminomatous Germ Cell Tumor',
#  'NCIT:C100094': 'HGNC_ID',
#  'NCIT:C100095': 'Lichenoid',
#  'NCIT:C100096': 'Oral Mucositis Rating Scale',
#  'NCIT:C100097': 'Ginger Flavor',
#  'NCIT:C100098': 'Ademetionine',
#  'NCIT:C100099': 'Synthetic Breast Cancer Peptides-Tetanus Toxoid-Poly ICLC Vaccine',
#  'NCIT:C1001': 'Rintatolimod',
#  'NCIT:C10010': 'Asparaginase/Cyclophosphamide/Methotrexate/Prednisone/Vincristine/Zorubicin',
#  'NCIT:C100100': 'HPV E1/E2 Interaction Inhibitor Gel AP611074',
#  'NCIT:C100101': 'Naratuximab Emtansine',
#  'NCIT:C100102': 'Adenovirus/Cytomegalovirus/Epstein-Barr Virus-specific Allogeneic Cytotoxic T Lymphocytes',
#  'NCIT:C100103': 'Cellular Sheet Dosage Form',
#  'NCIT:C100104': 'Sign or Symptom',
#  'NCIT:C100106': 'ADAS-Cog CDISC Version Questionnaire Question',
#  'NCIT:C100107': 'BPI Questionnaire Question',
#  'NCIT:C100108': 'BPI Short Form Questionnaire Question',
#  'NCIT:C100109': 'BPRS-A Clinical Classification Question',
#  'NCIT:C10011': 'Cyclophosphamide/Melphalan/Methylprednisolone',
#  'NCIT:C100110': 'CDISC Questionnaire Terminology',
#  'NCIT:C100111': 'CGI Questionnaire Question',
#  'NCIT:C100112': 'COMM Questionnaire Question',
#  'NCIT:C100113': 'C-SSRS Baseline Questionnaire Question',
#  'NCIT:C100114': 'EQ-5D-3L Questionnaire Question',
#  'NCIT:C100115': 'FPSR Questionnaire Question',
#  'NCIT:C100116': 'KPS Scale Questionnaire Question',
#  'NCIT:C100117': 'MDS-UPDRS Questionnaire Question',
#  'NCIT:C100118': 'MMSE Functional Test Question',
#  'NCIT:C100119': 'MNSI Questionnaire Question',
#  'NCIT:C10012': 'Cyclophosphamide/Prednisone/Vincristine/Zorubicin',
#  'NCIT:C100120': 'NPI Questionnaire Question',
#  'NCIT:C100121': 'PDQUALIF Questionnaire Question',
#  'NCIT:C100122': 'Pepsinogen Measurement',
#  'NCIT:C100123': 'RDQ Questionnaire Question',
#  'NCIT:C100124': 'Short-Form MPQ-2 Questionnaire Question',
#  'NCIT:C100125': 'SOAPP-R Questionnaire Question',
#  'NCIT:C100126': 'UPDRS Clinical Classification Question',
#  'NCIT:C100127': 'HAMD-17 Questionnaire Question',
#  'NCIT:C100128': 'Partner',
#  'NCIT:C100129': 'CDISC Questionnaire Category Terminology',
#  'NCIT:C10013': 'Doxorubicin/Fluoxymesterone/Mitolactol/Tamoxifen',
#  'NCIT:C100130': 'CDISC SDTM Relationship to Subject Terminology',
#  'NCIT:C100131': 'CDISC Questionnaire ADAS-Cog CDISC Version Test Name Terminology',
#  'NCIT:C100132': 'CDISC Questionnaire ADAS-Cog CDISC Version Test Code Terminology',
#  'NCIT:C100133': 'CDISC Clinical Classification BPRS-A Test Name Terminology',
#  'NCIT:C100134': 'CDISC Clinical Classification BPRS-A Test Code Terminology',
#  'NCIT:C100135': 'CDISC Questionnaire EQ-5D-3L Test Name Terminology',
#  'NCIT:C100136': 'CDISC Questionnaire EQ-5D-3L Test Code Terminology',
#  'NCIT:C100137': 'CDISC Clinical Classification HAMD 17 Test Name Terminology',
#  'NCIT:C100138': 'CDISC Clinical Classification HAMD 17 Test Code Terminology',
#  'NCIT:C100139': 'CDISC Questionnaire MDS-UPDRS Test Name Terminology',
#  'NCIT:C10014': 'Fluoxymesterone/Mitolactol/Mitoxantrone/Tamoxifen',
#  'NCIT:C100140': 'CDISC Questionnaire MDS-UPDRS Test Code Terminology',
#  'NCIT:C100141': 'CDISC Functional Test MMSE Test Name Terminology',
#  'NCIT:C100142': 'CDISC Functional Test MMSE Test Code Terminology',
#  'NCIT:C100143': 'CDISC Questionnaire NPI Test Name Terminology',
#  'NCIT:C100144': 'CDISC Questionnaire NPI Test Code Terminology',
#  'NCIT:C100145': 'CDISC Questionnaire PDQUALIF Test Name Terminology',
#  'NCIT:C100146': 'CDISC Questionnaire PDQUALIF Test Code Terminology',
#  'NCIT:C100147': 'CDISC Clinical Classification UPDRS Test Name Terminology',
#  'NCIT:C100148': 'CDISC Clinical Classification UPDRS Test Code Terminology',
#  'NCIT:C100149': 'CDISC Questionnaire CGI Test Name Terminology',
#  'NCIT:C10015': 'Cisplatin/Dianhydrogalactitol/Doxorubicin',
#  'NCIT:C100150': 'CDISC Questionnaire CGI Test Code Terminology',
#  'NCIT:C100151': 'CDISC Questionnaire MNSI Test Name Terminology',
#  'NCIT:C100152': 'CDISC Questionnaire MNSI Test Code Terminology',
#  'NCIT:C100153': 'CDISC Questionnaire FPSR Test Name Terminology',
#  'NCIT:C100154': 'CDISC Questionnaire FPSR Test Code Terminology',
#  'NCIT:C100155': 'CDISC Questionnaire Short-Form MPQ-2 Test Name Terminology',
#  'NCIT:C100156': 'CDISC Questionnaire Short-Form MPQ-2 Test Code Terminology',
#  'NCIT:C100157': 'CDISC Questionnaire COMM Test Name Terminology',
#  'NCIT:C100158': 'CDISC Questionnaire COMM Test Code Terminology',
#  'NCIT:C100159': 'CDISC Questionnaire SOAPP-R Test Name Terminology',
#  'NCIT:C10016': 'Ancitabine Hydrochloride/Daunorubicin/Mercaptopurine/Prednisolone',
#  'NCIT:C100160': 'CDISC Questionnaire SOAPP-R Test Code Terminology',
#  'NCIT:C100161': 'CDISC Questionnaire BPI Test Name Terminology',
#  'NCIT:C100162': 'CDISC Questionnaire BPI Test Code Terminology',
#  'NCIT:C100163': 'CDISC Questionnaire BPI Short Form Test Name Terminology',
#  'NCIT:C100164': 'CDISC Questionnaire BPI Short Form Test Code Terminology',
#  'NCIT:C100165': 'CDISC Questionnaire RDQ Test Name Terminology',
#  'NCIT:C100166': 'CDISC Questionnaire RDQ Test Code Terminology',
#  'NCIT:C100167': 'CDISC Questionnaire C-SSRS Baseline Test Name Terminology',
#  'NCIT:C100168': 'CDISC Questionnaire C-SSRS Baseline Test Code Terminology',
#  'NCIT:C100169': 'CDISC Clinical Classification KPS Scale Test Name Terminology',
#  'NCIT:C10017': 'Doxorubicin/Fluoxymesterone/Methotrexate/Mitolactol/Tamoxifen/Vincristine',
#  'NCIT:C100170': 'CDISC Clinical Classification KPS Scale Test Code Terminology',
#  'NCIT:C100171': 'SF36 v1.0 Standard Questionnaire Question',
#  'NCIT:C100172': 'WPAI:SHP v2.0 Questionnaire Question',
#  'NCIT:C100173': 'CDISC Questionnaire SF36 v1.0 Standard Test Name Terminology',
#  'NCIT:C100174': 'CDISC Questionnaire SF36 v1.0 Standard Test Code Terminology',
#  'NCIT:C100175': 'CDISC Questionnaire WPAI:SHP v2.0 Test Name Terminology',
#  'NCIT:C100176': 'CDISC Questionnaire WPAI:SHP v2.0 Test Code Terminology',
#  'NCIT:C100177': 'CDISC ADAS-Cog - Word Recall Average Score',
#  'NCIT:C100178': 'CDISC ADAS-Cog - Word Recall Trial 1 Subscore',
#  'NCIT:C100179': 'CDISC ADAS-Cog - Word Recall Trial 2 Subscore',
#  'NCIT:C10018': 'Dianhydrogalactitol/Etoposide',
#  'NCIT:C100180': 'CDISC ADAS-Cog - Word Recall Trial 3 Subscore',
#  'NCIT:C100181': 'CDISC ADAS-Cog - Word Recall: Word 1',
#  'NCIT:C100182': 'CDISC ADAS-Cog - Word Recall: Word 2',
#  'NCIT:C100183': 'CDISC ADAS-Cog - Word Recall: Word 3',
#  'NCIT:C100184': 'CDISC ADAS-Cog - Word Recall: Word 4',
#  'NCIT:C100185': 'CDISC ADAS-Cog - Word Recall: Word 5',
#  'NCIT:C100186': 'CDISC ADAS-Cog - Word Recall: Word 6',
#  'NCIT:C100187': 'CDISC ADAS-Cog - Word Recall: Word 7',
#  'NCIT:C100188': 'CDISC ADAS-Cog - Word Recall: Word 8',
#  'NCIT:C100189': 'CDISC ADAS-Cog - Word Recall: Word 9',
#  'NCIT:C10019': 'DZAPO Regimen',
#  'NCIT:C100190': 'CDISC ADAS-Cog - Word Recall: Word 10',
#  'NCIT:C100191': 'CDISC ADAS-Cog - Naming Objects and Fingers Summary Score',
#  'NCIT:C100192': 'CDISC ADAS-Cog - Naming Objects and Fingers: 1',
#  'NCIT:C100193': 'CDISC ADAS-Cog - Naming Objects and Fingers: 2',
#  'NCIT:C100194': 'CDISC ADAS-Cog - Naming Objects and Fingers: 3',
#  'NCIT:C100195': 'CDISC ADAS-Cog - Naming Objects and Fingers: 4',
#  'NCIT:C100196': 'CDISC ADAS-Cog - Naming Objects and Fingers: 5',
#  'NCIT:C100197': 'CDISC ADAS-Cog - Naming Objects and Fingers: 6',
#  'NCIT:C100198': 'CDISC ADAS-Cog - Naming Objects and Fingers: 7',
#  'NCIT:C100199': 'CDISC ADAS-Cog - Naming Objects and Fingers: 8',
#  'NCIT:C1002': 'Recombinant Angiogenin',
#  'NCIT:C10020': 'Fluorouracil/Methotrexate/Mitolactol/Prednisone',
#  'NCIT:C100200': 'CDISC ADAS-Cog - Naming Objects and Fingers: 9',
#  'NCIT:C100201': 'CDISC ADAS-Cog - Naming Objects and Fingers: 10',
#  'NCIT:C100202': 'CDISC ADAS-Cog - Naming Objects and Fingers: 11',
#  'NCIT:C100203': 'CDISC ADAS-Cog - Naming Objects and Fingers: 12',
#  'NCIT:C100204': 'CDISC ADAS-Cog - Naming Objects and Fingers: Thumb',
#  'NCIT:C100205': 'CDISC ADAS-Cog - Naming Objects and Fingers: Pointer',
#  'NCIT:C100206': 'CDISC ADAS-Cog - Naming Objects and Fingers: Middle',
#  'NCIT:C100207': 'CDISC ADAS-Cog - Naming Objects and Fingers: Ring',
#  'NCIT:C100208': 'CDISC ADAS-Cog - Naming Objects and Fingers: Pinky',
#  'NCIT:C100209': 'CDISC ADAS-Cog - Commands Summary Score',
#  'NCIT:C10021': 'BCG/Cyclophosphamide/Doxorubicin/Tegafur',
#  'NCIT:C100210': 'CDISC ADAS-Cog - Commands: Fist',
#  'NCIT:C100211': 'CDISC ADAS-Cog - Commands: Ceiling',
#  'NCIT:C100212': 'CDISC ADAS-Cog - Commands: Pencil',
#  'NCIT:C100213': 'CDISC ADAS-Cog - Commands: Watch',
#  'NCIT:C100214': 'CDISC ADAS-Cog - Commands: Shoulder',
#  'NCIT:C100215': 'CDISC ADAS-Cog - Delayed Word Recall Summary Score',
#  'NCIT:C100216': 'CDISC ADAS-Cog - Delayed Word Recall: Word 1',
#  'NCIT:C100217': 'CDISC ADAS-Cog - Delayed Word Recall: Word 2',
#  'NCIT:C100218': 'CDISC ADAS-Cog - Delayed Word Recall: Word 3',
#  'NCIT:C100219': 'CDISC ADAS-Cog - Delayed Word Recall: Word 4',
#  'NCIT:C10022': 'Fluorouracil/Razoxane/Semustine',
#  'NCIT:C100220': 'CDISC ADAS-Cog - Delayed Word Recall: Word 5',
#  'NCIT:C100221': 'CDISC ADAS-Cog - Delayed Word Recall: Word 6',
#  'NCIT:C100222': 'CDISC ADAS-Cog - Delayed Word Recall: Word 7',
#  'NCIT:C100223': 'CDISC ADAS-Cog - Delayed Word Recall: Word 8',
#  'NCIT:C100224': 'CDISC ADAS-Cog - Delayed Word Recall: Word 9',
#  'NCIT:C100225': 'CDISC ADAS-Cog - Delayed Word Recall: Word 10',
#  'NCIT:C100226': 'CDISC ADAS-Cog - Constructional Praxis Summary Score',
#  'NCIT:C100227': 'CDISC ADAS-Cog - Constructional Praxis: Circle',
#  'NCIT:C100228': 'CDISC ADAS-Cog - Constructional Praxis: 2 Rectangles',
#  'NCIT:C100229': 'CDISC ADAS-Cog - Constructional Praxis: Diamond',
#  'NCIT:C10023': 'Doxorubicin/Mitomycin/Tegafur Regimen',
#  'NCIT:C100230': 'CDISC ADAS-Cog - Constructional Praxis: Cube',
#  'NCIT:C100231': 'CDISC ADAS-Cog - Attempt to Draw',
#  'NCIT:C100232': 'CDISC ADAS-Cog - Ideational Praxis Summary Score',
#  'NCIT:C100233': 'CDISC ADAS-Cog - Ideational Praxis: Fold',
#  'NCIT:C100234': 'CDISC ADAS-Cog - Ideational Praxis: Insert',
#  'NCIT:C100235': 'CDISC ADAS-Cog - Ideational Praxis: Seal',
#  'NCIT:C100236': 'CDISC ADAS-Cog - Ideational Praxis: Address',
#  'NCIT:C100237': 'CDISC ADAS-Cog - Ideational Praxis: Stamp',
#  'NCIT:C100238': 'CDISC ADAS-Cog - Orientation Summary Score',
#  'NCIT:C100239': 'CDISC ADAS-Cog - Orientation: Full Name',
#  'NCIT:C10024': 'Asparaginase/Methotrexate Regimen',
#  'NCIT:C100240': 'CDISC ADAS-Cog - Orientation: Month',
#  'NCIT:C100241': 'CDISC ADAS-Cog - Orientation: Date',
#  'NCIT:C100242': 'CDISC ADAS-Cog - Orientation: Year',
#  'NCIT:C100243': 'CDISC ADAS-Cog - Orientation: Day of Week',
#  'NCIT:C100244': 'CDISC ADAS-Cog - Orientation: Season',
#  'NCIT:C100245': 'CDISC ADAS-Cog - Orientation: Place',
#  'NCIT:C100246': 'CDISC ADAS-Cog - Orientation: Time',
#  'NCIT:C100247': 'CDISC ADAS-Cog - Word Recognition Summary Score',
#  'NCIT:C100248': 'CDISC ADAS-Cog - Word Recognition Trial 1 Summary Score',
#  'NCIT:C100249': 'CDISC ADAS-Cog - Word Recognition Trial 2 Summary Score',
#  'NCIT:C10025': 'Asparaginase/Cytarabine/Doxorubicin/Prednisone/Vincristine',
#  'NCIT:C100250': 'CDISC ADAS-Cog - Word Recognition Trial 3 Summary Score',
#  'NCIT:C100251': 'CDISC ADAS-Cog - Word Recognition: Word 1',
#  'NCIT:C100252': 'CDISC ADAS-Cog - Word Recognition: Word 2',
#  'NCIT:C100253': 'CDISC ADAS-Cog - Word Recognition: Word 3',
#  'NCIT:C100254': 'CDISC ADAS-Cog - Word Recognition: Word 4',
#  'NCIT:C100255': 'CDISC ADAS-Cog - Word Recognition: Word 5',
#  'NCIT:C100256': 'CDISC ADAS-Cog - Word Recognition: Word 6',
#  'NCIT:C100257': 'CDISC ADAS-Cog - Word Recognition: Word 7',
#  'NCIT:C100258': 'CDISC ADAS-Cog - Word Recognition: Word 8',
#  'NCIT:C100259': 'CDISC ADAS-Cog - Word Recognition: Word 9',
#  'NCIT:C10026': 'Chlorambucil/Prednisone/Vinblastine/Vincristine',
#  'NCIT:C100260': 'CDISC ADAS-Cog - Word Recognition: Word 10',
#  'NCIT:C100261': 'CDISC ADAS-Cog - Word Recognition: Word 11',
#  'NCIT:C100262': 'CDISC ADAS-Cog - Word Recognition: Word 12',
#  'NCIT:C100263': 'CDISC ADAS-Cog - Word Recognition: Word 13',
#  'NCIT:C100264': 'CDISC ADAS-Cog - Word Recognition: Word 14',
#  'NCIT:C100265': 'CDISC ADAS-Cog - Word Recognition: Word 15',
#  'NCIT:C100266': 'CDISC ADAS-Cog - Word Recognition: Word 16',
#  'NCIT:C100267': 'CDISC ADAS-Cog - Word Recognition: Word 17',
#  'NCIT:C100268': 'CDISC ADAS-Cog - Word Recognition: Word 18',
#  'NCIT:C100269': 'CDISC ADAS-Cog - Word Recognition: Word 19',
#  'NCIT:C10027': 'Fluorouracil/Mitomycin',
#  'NCIT:C100270': 'CDISC ADAS-Cog - Word Recognition: Word 20',
#  'NCIT:C100271': 'CDISC ADAS-Cog - Word Recognition: Word 21',
#  'NCIT:C100272': 'CDISC ADAS-Cog - Word Recognition: Word 22',
#  'NCIT:C100273': 'CDISC ADAS-Cog - Word Recognition: Word 23',
#  'NCIT:C100274': 'CDISC ADAS-Cog - Word Recognition: Word 24',
#  'NCIT:C100275': 'CDISC ADAS-Cog - Remembering Test Instructions',
#  'NCIT:C100276': 'CDISC ADAS-Cog - Spoken Language Ability',
#  'NCIT:C100277': 'CDISC ADAS-Cog - Word Difficulty in Spontaneous Speech',
#  'NCIT:C100278': 'CDISC ADAS-Cog - Comprehension',
#  'NCIT:C100279': 'CDISC ADAS-Cog - Concentration/Distractibility',
#  'NCIT:C10028': 'MCBP Regimen',
#  'NCIT:C100280': 'CDISC ADAS-Cog - Number Cancellation Summary Score',
#  'NCIT:C100281': 'CDISC ADAS-Cog - Number Cancellation: Correct',
#  'NCIT:C100282': 'CDISC ADAS-Cog - Number Cancellation: Errors',
#  'NCIT:C100283': 'CDISC ADAS-Cog - Number Cancellation: Remind',
#  'NCIT:C100284': 'CDISC ADAS-Cog - Executive Function Maze Summary Score',
#  'NCIT:C100285': 'CDISC ADAS-Cog - Executive Function Maze: Errors',
#  'NCIT:C100286': 'CDISC ADAS-Cog - Executive Function Maze: Time',
#  'NCIT:C100287': 'BPI - Marital Status',
#  'NCIT:C100288': 'BPI - Education',
#  'NCIT:C100289': 'BPI - Professional Degree',
#  'NCIT:C10029': 'Doxorubicin/Lomustine/Mechlorethamine',
#  'NCIT:C100290': 'BPI - Current Occupation',
#  'NCIT:C100291': "BPI - Spouse's Occupation",
#  'NCIT:C100292': 'BPI - Current Job Status',
#  'NCIT:C100293': 'BPI - How Long Since Diagnosis',
#  'NCIT:C100294': 'BPI - Pain Due to Present Disease',
#  'NCIT:C100295': 'BPI - Pain as a Symptom',
#  'NCIT:C100296': 'BPI - Surgery in Past Month',
#  'NCIT:C100297': 'BPI - Kind of Surgery in Past Month',
#  'NCIT:C100298': 'BPI - Pain Other than Everyday Kinds',
#  'NCIT:C100299': 'BPI - Pain Medications in the Last 7 Days',
#  'NCIT:C1003': 'Ansamycin Antineoplastic Antibiotic',
#  'NCIT:C10030': 'Doxorubicin/Semustine Regimen',
#  'NCIT:C100300': 'BPI - Pain Requires Medication Daily',
#  'NCIT:C100301': 'BPI - Areas of Pain',
#  'NCIT:C100302': 'BPI - Area Hurts Most',
#  'NCIT:C100303': 'BPI - Pain at its Worst in Last Week',
#  'NCIT:C100304': 'BPI - Pain at its Least in Last Week',
#  'NCIT:C100305': 'BPI - Pain on the Average',
#  'NCIT:C100306': 'BPI - Pain Right Now',
#  'NCIT:C100307': 'BPI - Things that Make Pain Feel Better',
#  'NCIT:C100308': 'BPI - Things that Make your Pain Worse',
#  'NCIT:C100309': 'BPI - Treatments Receiving for Pain',
#  'NCIT:C10031': 'Dactinomycin/Doxorubicin/Methotrexate/Vincristine Regimen',
#  'NCIT:C100310': 'BPI - Relief Pain Treatments Provided',
#  'NCIT:C100311': 'BPI - Hours before Pain Returns',
#  'NCIT:C100312': 'BPI - Pain Due to Effects of Treatment',
#  'NCIT:C100313': 'BPI - Pain Due to Primary Disease',
#  'NCIT:C100314': 'BPI - Pain Due to Unrelated Medical Condition',
#  'NCIT:C100315': 'BPI - Describe Unrelated Medical Condition',
#  'NCIT:C100316': 'BPI - Aching',
#  'NCIT:C100317': 'BPI - Throbbing',
#  'NCIT:C100318': 'BPI - Shooting',
#  'NCIT:C100319': 'BPI - Stabbing',
#  'NCIT:C10032': 'Cyclophosphamide/Prednisolone/Teniposide',
#  'NCIT:C100320': 'BPI - Gnawing',
#  'NCIT:C100321': 'BPI - Sharp',
#  'NCIT:C100322': 'BPI - Tender',
#  'NCIT:C100323': 'BPI - Burning',
#  'NCIT:C100324': 'BPI - Exhausting',
#  'NCIT:C100325': 'BPI - Tiring',
#  'NCIT:C100326': 'BPI - Penetrating',
#  'NCIT:C100327': 'BPI - Nagging',
#  'NCIT:C100328': 'BPI - Numb',
#  'NCIT:C100329': 'BPI - Miserable',
#  'NCIT:C10033': 'Fluorouracil/Melphalan',
#  'NCIT:C100330': 'BPI - Unbearable',
#  'NCIT:C100331': 'BPI - Pain Interfered with General Activity',
#  'NCIT:C100332': 'BPI - Pain Interfered with Mood',
#  'NCIT:C100333': 'BPI - Pain Interfered with Walking Ability',
#  'NCIT:C100334': 'BPI - Pain Interfered with Normal Work',
#  'NCIT:C100335': 'BPI - Pain Interfered with Relations',
#  'NCIT:C100336': 'BPI - Pain Interfered with Sleep',
#  'NCIT:C100337': 'BPI - Pain Interfered with Enjoyment of Life',
#  'NCIT:C100338': 'BPI - Prefer to Take Pain Medicine',
#  'NCIT:C100339': 'BPI - Take my Pain Medicine',
#  'NCIT:C10034': 'Doxorubicin/Fluorouracil/Melphalan',
#  'NCIT:C100340': 'BPI - Need Stronger Type of Pain Medication',
#  'NCIT:C100341': 'BPI - Need more Pain Medication than Prescribed',
#  'NCIT:C100342': 'BPI - Concerned with Too Much Pain Medication Use',
#  'NCIT:C100343': 'BPI - Why Concerned with Too Much Pain Medication Use',
#  'NCIT:C100344': 'BPI - Problems with Side Effects Pain Medication',
#  'NCIT:C100345': 'BPI - What Side Effects from Pain Medication',
#  'NCIT:C100346': 'BPI - Need Further Information about Pain Medication',
#  'NCIT:C100347': 'BPI - Warm Compresses to Relieve Pain',
#  'NCIT:C100348': 'BPI - Cold Compresses to Relieve Pain',
#  'NCIT:C100349': 'BPI - Relaxation Techniques Relieve Pain',
#  'NCIT:C10035': 'Mercaptopurine/Methotrexate/Vincristine',
#  'NCIT:C100350': 'BPI - Distraction to Relieve Pain',
#  'NCIT:C100351': 'BPI - Biofeedback to Relieve Pain',
#  'NCIT:C100352': 'BPI - Hypnosis to Relieve Pain',
#  'NCIT:C100353': 'BPI - Other Methods to Relieve Pain',
#  'NCIT:C100354': 'BPI - Specified Other Method to Relieve Pain',
#  'NCIT:C100355': 'BPI - Medications not Prescribed Taken for Pain',
#  'NCIT:C100356': 'BPI Short Form - Pain Other Than Everyday Kinds',
#  'NCIT:C100357': 'BPI Short Form - Areas of Pain',
#  'NCIT:C100358': 'BPI Short Form - Area that Hurts Most',
#  'NCIT:C100359': 'BPI Short Form - Pain at its Worst in Last 24 Hours',
#  'NCIT:C10036': 'ROAP Regimen',
#  'NCIT:C100360': 'BPI Short Form - Pain at its Least in Last 24 Hours',
#  'NCIT:C100361': 'BPI Short Form - Pain on the Average',
#  'NCIT:C100362': 'BPI Short Form - Pain Right Now',
#  'NCIT:C100363': 'BPI Short Form - Treatments or Medications Receiving for Pain',
#  'NCIT:C100364': 'BPI Short Form - Relief from Pain Treatments Provided',
#  'NCIT:C100365': 'BPI Short Form - Pain Interfered with General Activity',
#  'NCIT:C100366': 'BPI Short Form - Pain Interfered with Mood',
#  'NCIT:C100367': 'BPI Short Form - Pain Interfered with Walking Ability',
#  'NCIT:C100368': 'BPI Short Form - Pain Interfered with Normal Work',
#  'NCIT:C100369': 'BPI Short Form - Pain Interfered with Relations',
#  'NCIT:C10037': 'Dacarbazine/Zorubicin',
#  'NCIT:C100370': 'BPI Short Form - Pain Interfered with Sleep',
#  'NCIT:C100371': 'BPI Short Form - Pain Interfered with Enjoyment of Life',
#  'NCIT:C100372': 'BPRS-A - Somatic Concern',
#  'NCIT:C100373': 'BPRS-A - Anxiety',
#  'NCIT:C100374': 'BPRS-A - Emotional Withdrawal',
#  'NCIT:C100375': 'BPRS-A - Conceptual Disorganization',
#  'NCIT:C100376': 'BPRS-A - Guilt Feelings',
#  'NCIT:C100377': 'BPRS-A - Tension',
#  'NCIT:C100378': 'BPRS-A - Mannerisms and Posturing',
#  'NCIT:C100379': 'BPRS-A - Grandiosity',
#  'NCIT:C10038': 'Methotrexate/Prednisone/Thioguanine/Vincristine',
#  'NCIT:C100380': 'BPRS-A - Depressive Mood',
#  'NCIT:C100381': 'BPRS-A - Hostility',
#  'NCIT:C100382': 'BPRS-A - Suspiciousness',
#  'NCIT:C100383': 'BPRS-A - Hallucinatory Behavior',
#  'NCIT:C100384': 'BPRS-A - Motor Retardation',
#  'NCIT:C100385': 'BPRS-A - Uncooperativeness',
#  'NCIT:C100386': 'BPRS-A - Unusual Thought Content',
#  'NCIT:C100387': 'BPRS-A - Blunted Affect',
#  'NCIT:C100388': 'BPRS-A - Excitement',
#  'NCIT:C100389': 'BPRS-A - Disorientation',
#  'NCIT:C10039': 'Amifostine/Cisplatin/Monoclonal Antibody R24',
#  'NCIT:C100390': 'Mean QRS Duration Ventricular Paced',
#  'NCIT:C100391': 'Corrected QT Interval',
#  'NCIT:C100392': 'EQ-5D-3L - Mobility',
#  'NCIT:C100393': 'EQ-5D-3L - Self-Care',
#  'NCIT:C100394': 'EQ-5D-3L - Usual Activities',
#  'NCIT:C100395': 'EQ-5D-3L - Pain or Discomfort',
#  'NCIT:C100396': 'EQ-5D-3L - Anxiety or Depression',
#  'NCIT:C100397': 'EQ-5D-3L - EQ VAS Score',
#  'NCIT:C100398': 'HAMD-17 - Depressed Mood',
#  'NCIT:C100399': 'HAMD-17 - Feelings of Guilt',
#  'NCIT:C1004': 'Antineoplaston A10',
#  'NCIT:C10040': 'Fluorouracil/Leucovorin Calcium/Sargramostim',
#  'NCIT:C100400': 'HAMD-17 - Suicide',
#  'NCIT:C100401': 'HAMD-17 - Insomnia - Early Night',
#  'NCIT:C100402': 'HAMD-17 - Insomnia - Middle Night',
#  'NCIT:C100403': 'HAMD-17 - Insomnia - Early Morning',
#  'NCIT:C100404': 'HAMD-17 - Work and Activities',
#  'NCIT:C100405': 'HAMD-17 - Retardation',
#  'NCIT:C100406': 'HAMD-17 - Agitation',
#  'NCIT:C100407': 'HAMD-17 - Psychic Anxiety',
#  'NCIT:C100408': 'HAMD-17 - Somatic Anxiety',
#  'NCIT:C100409': 'HAMD-17 - Somatic Symptoms Gastrointestinal',
#  'NCIT:C10041': 'Bleomycin/Cisplatin/Cyclophosphamide/Doxorubicin/Fluorouracil/Vincristine',
#  'NCIT:C100410': 'HAMD-17 - General Somatic Symptoms',
#  'NCIT:C100411': 'HAMD-17 - Genital Symptoms',
#  'NCIT:C100412': 'HAMD-17 - Hypochondriasis',
#  'NCIT:C100413': 'HAMD-17 - Loss of Weight According to Patient',
#  'NCIT:C100414': 'HAMD-17 - Loss of Weight According to Weekly Measurements',
#  'NCIT:C100415': 'HAMD-17 - Insight',
#  'NCIT:C100416': 'HAMD-17 - Total Score',
#  'NCIT:C100417': 'KPS Scale - Karnofsky Performance Status',
#  'NCIT:C100418': 'Sideroblast Measurement',
#  'NCIT:C100419': 'Ring Sideroblast Measurement',
#  'NCIT:C10042': 'Bleomycin/Cyclophosphamide/Cytarabine/Doxorubicin/Etoposide/Methotrexate/Prednisone/Sargramostim/Vincristine',
#  'NCIT:C100420': 'Tricyclic Antidepressant Measurement',
#  'NCIT:C100422': 'Ecarin Clotting Time Measurement',
#  'NCIT:C100423': 'CH50 Measurement',
#  'NCIT:C100424': 'Platelet Hematocrit Measurement',
#  'NCIT:C100425': 'HDL Cholesterol to LDL Cholesterol Ratio Measurement',
#  'NCIT:C100427': 'Apolipoprotein C2 Measurement',
#  'NCIT:C100428': 'Apolipoprotein J Measurement',
#  'NCIT:C100429': 'Alpha-1 Acid Glycoprotein Measurement',
#  'NCIT:C10043': 'Cisplatin/Cyclophosphamide/Fluorouracil/Vincristine',
#  'NCIT:C100430': 'Alanine Aminopeptidase Measurement',
#  'NCIT:C100431': 'Chemokine Receptor CXCR3 Measurement',
#  'NCIT:C100432': 'Ceruloplasmin Measurement',
#  'NCIT:C100433': 'Kidney Injury Molecule-1 Measurement',
#  'NCIT:C100434': 'Non-Prostatic Acid Phosphatase Measurement',
#  'NCIT:C100435': 'Prealbumin Measurement',
#  'NCIT:C100436': 'Protein S Measurement',
#  'NCIT:C100437': 'Retinol Binding Protein Measurement',
#  'NCIT:C100438': 'Soluble Transferrin Receptor Measurement',
#  'NCIT:C100439': 'Iohexol Clearance',
#  'NCIT:C10044': 'Altretamine/Cyclophosphamide/Methotrexate',
#  'NCIT:C100440': 'EDTA Clearance',
#  'NCIT:C100441': 'Diethylene Triamine Pentaacetic Acid Clearance',
#  'NCIT:C100442': 'Immature Neutrophils to Leukocytes Ratio Measurement',
#  'NCIT:C100443': 'Immature Lymphocytes to Leukocytes Ratio Measurement',
#  'NCIT:C100444': 'Immature Lymphocytes Measurement',
#  'NCIT:C100445': 'Immature Granulocytes to Leukocytes Ratio Measurement',
#  'NCIT:C100446': 'Proerythroblast Measurement',
#  'NCIT:C100447': 'Homeostatic Model Assessment of Insulin Resistance',
#  'NCIT:C100448': 'Free Glycerol Measurement',
#  'NCIT:C100449': 'Glomerular Filtration Rate from Beta-Trace Protein Adjusted for BSA Measurement',
#  'NCIT:C10045': 'Cisplatin/Mitoguazone/Vinblastine',
#  'NCIT:C100450': 'Glomerular Filtration Rate from B-2 Microglobulin Adjusted for BSA Measurement',
#  'NCIT:C100452': 'Ova and Parasite Measurement',
#  'NCIT:C100453': 'Plasmodium Measurement',
#  'NCIT:C100454': 'Liver Kidney Microsomal Type 1 IgG Antibody Measurement',
#  'NCIT:C100455': 'Liver Kidney Microsomal Type 1 IgM Antibody Measurement',
#  'NCIT:C100456': 'Liver Kidney Microsomal Type 1 IgA Antibody Measurement',
#  'NCIT:C100457': 'Ribonucleoprotein Antibody Measurement',
#  'NCIT:C100458': 'Scl-70 Antibody Measurement',
#  'NCIT:C100459': 'Jo-1 Antibody Measurement',
#  'NCIT:C10046': 'Ampligen/Interleukin-2',
#  'NCIT:C100460': 'HLA-B27 Antigen Measurement',
#  'NCIT:C100461': 'Alpha-1 Microglobulin Measurement',
#  'NCIT:C100462': 'Alpha-1 Microglobulin to Creatinine Ratio Measurement',
#  'NCIT:C100463': 'DNase-B Antibody Measurement',
#  'NCIT:C100464': 'Chlamydia trachomatis IgA Antibody Measurement',
#  'NCIT:C100465': 'Chlamydia trachomatis IgM Antibody Measurement',
#  'NCIT:C100466': 'Chlamydia trachomatis IgG Antibody Measurement',
#  'NCIT:C100467': 'Pepsinogen I Measurement',
#  'NCIT:C100468': 'Pepsinogen II Measurement',
#  'NCIT:C100469': 'Pepsinogen A Measurement',
#  'NCIT:C10047': 'Cisplatin/Cytarabine/Etoposide/Sargramostim',
#  'NCIT:C100470': 'Pepsinogen C Measurement',
#  'NCIT:C100471': 'Activated Protein C Resistance Measurement',
#  'NCIT:C100472': 'Beta Carotene Measurement',
#  'NCIT:C100473': 'MDS-UPDRS - Cognitive Impairment',
#  'NCIT:C100474': 'MDS-UPDRS - Hallucinations and Psychosis',
#  'NCIT:C100475': 'MDS-UPDRS - Depressed Mood',
#  'NCIT:C100476': 'MDS-UPDRS - Anxious Mood',
#  'NCIT:C100477': 'MDS-UPDRS - Apathy',
#  'NCIT:C100478': 'MDS-UPDRS - Features of Dopamine Dysregulation Syndrome',
#  'NCIT:C100479': 'MDS-UPDRS - Sleep Problems',
#  'NCIT:C10048': 'Cyclophosphamide/Dexrazoxane/Doxorubicin/Vincristine',
#  'NCIT:C100480': 'MDS-UPDRS - Daytime Sleepiness',
#  'NCIT:C100481': 'MDS-UPDRS - Pain and Other Sensations',
#  'NCIT:C100482': 'MDS-UPDRS - Urinary Problems',
#  'NCIT:C100483': 'MDS-UPDRS - Constipation Problems',
#  'NCIT:C100484': 'MDS-UPDRS - Lightheadedness on Standing',
#  'NCIT:C100485': 'MDS-UPDRS - Fatigue',
#  'NCIT:C100486': 'MDS-UPDRS - Speech',
#  'NCIT:C100487': 'MDS-UPDRS - Saliva and Drooling',
#  'NCIT:C100488': 'MDS-UPDRS - Chewing and Swallowing',
#  'NCIT:C100489': 'MDS-UPDRS - Eating Tasks',
#  'NCIT:C10049': 'Carmustine/Cyclophosphamide/Thiotepa/Vincristine',
#  'NCIT:C100490': 'MDS-UPDRS - Dressing',
#  'NCIT:C100491': 'MDS-UPDRS - Hygiene',
#  'NCIT:C100492': 'MDS-UPDRS - Handwriting',
#  'NCIT:C100493': 'MDS-UPDRS - Doing Hobbies and Other Activities',
#  'NCIT:C100494': 'MDS-UPDRS - Turning in Bed',
#  'NCIT:C100495': 'MDS-UPDRS - Tremor',
#  'NCIT:C100496': 'MDS-UPDRS - Walking and Balance',
#  'NCIT:C100497': 'MDS-UPDRS - Freezing',
#  'NCIT:C100498': "MDS-UPDRS - Medication for Parkinson's Disease",
#  'NCIT:C100499': 'MDS-UPDRS - Clinical State on Medication',
#  'NCIT:C1005': 'Arsenic Trioxide',
#  'NCIT:C10050': 'Asparaginase/Idarubicin/Prednisone/Vincristine',
#  'NCIT:C100500': 'MDS-UPDRS - Taking Levodopa',
#  'NCIT:C100501': 'MDS-UPDRS - Minutes Since Levodopa Dose',
#  'NCIT:C100502': 'MDS-UPDRS - Speech Problems',
#  'NCIT:C100503': 'MDS-UPDRS - Facial Expression',
#  'NCIT:C100504': 'MDS-UPDRS - Rigidity Neck',
#  'NCIT:C100505': 'MDS-UPDRS - Rigidity Right Upper Extremity',
#  'NCIT:C100506': 'MDS-UPDRS - Rigidity Left Upper Extremity',
#  'NCIT:C100507': 'MDS-UPDRS - Rigidity Right Lower Extremity',
#  'NCIT:C100508': 'MDS-UPDRS - Rigidity Left Lower Extremity',
#  'NCIT:C100509': 'MDS-UPDRS - Right Finger Tapping',
#  'NCIT:C10051': 'Carmustine/Triazinate',
#  'NCIT:C100510': 'MDS-UPDRS - Left Finger Tapping',
#  'NCIT:C100511': 'MDS-UPDRS - Right Hand Movements',
#  'NCIT:C100512': 'MDS-UPDRS - Left Hand Movements',
#  'NCIT:C100513': 'MDS-UPDRS - Pronanation-Supination Movement of Right Hand',
#  'NCIT:C100514': 'MDS-UPDRS - Pronanation-Supination Movement of Left Hand',
#  'NCIT:C100515': 'MDS-UPDRS - Right Toe Tapping',
#  'NCIT:C100516': 'MDS-UPDRS - Left Toe Tapping',
#  'NCIT:C100517': 'MDS-UPDRS - Right Leg Agility',
#  'NCIT:C100518': 'MDS-UPDRS - Left Leg Agility',
#  'NCIT:C100519': 'MDS-UPDRS - Arising from Chair',
#  'NCIT:C10052': 'Asparaginase/Cytarabine/Idarubicin',
#  'NCIT:C100520': 'MDS-UPDRS - Gait',
#  'NCIT:C100521': 'MDS-UPDRS - Freezing of Gait',
#  'NCIT:C100522': 'MDS-UPDRS - Postural Stability',
#  'NCIT:C100523': 'MDS-UPDRS - Posture',
#  'NCIT:C100524': 'MDS-UPDRS - Body Bradykinesia',
#  'NCIT:C100525': 'MDS-UPDRS - Postural Tremor of Right Hand',
#  'NCIT:C100526': 'MDS-UPDRS - Kinetic Tremor of Left Hand',
#  'NCIT:C100527': 'MDS-UPDRS - Rest Tremor Amplitude Right Upper Extremity',
#  'NCIT:C100528': 'MDS-UPDRS - Rest Tremor Amplitude Left Upper Extremity',
#  'NCIT:C100529': 'MDS-UPDRS - Rest Tremor Amplitude Right Lower Extremity',
#  'NCIT:C10053': 'CAFP Regimen',
#  'NCIT:C100530': 'MDS-UPDRS - Rest Tremor Amplitude Left Lower Extremity',
#  'NCIT:C100531': 'MDS-UPDRS - Rest Tremor Amplitude Lip or Jaw',
#  'NCIT:C100532': 'MDS-UPDRS - Consistency of Rest Tremor',
#  'NCIT:C100533': 'MDS-UPDRS - Dyskinesias During Exam',
#  'NCIT:C100534': 'MDS-UPDRS - Movements Interfere with Ratings',
#  'NCIT:C100535': 'MDS-UPDRS - Hoehn and Yahr Stage',
#  'NCIT:C100536': 'MDS-UPDRS - Time Spent with Dyskinesias',
#  'NCIT:C100537': 'MDS-UPDRS - Functional Impact of Dyskinesias',
#  'NCIT:C100538': 'MDS-UPDRS - Time Spent in the Off State',
#  'NCIT:C100539': 'MDS-UPDRS - Functional Impact of Fluctuations',
#  'NCIT:C10054': 'Asparaginase/Cytarabine/Daunorubicin',
#  'NCIT:C100540': 'MDS-UPDRS - Complexity of Motor Fluctuations',
#  'NCIT:C100541': 'MDS-UPDRS - Painful Off-state Dystonia',
#  'NCIT:C100542': 'MMSE - Question 1',
#  'NCIT:C100543': 'MMSE - What Is the Year',
#  'NCIT:C100544': 'MMSE - What Is the Season',
#  'NCIT:C100545': 'MMSE - What Is the Date',
#  'NCIT:C100546': 'MMSE - What Is the Day of Week',
#  'NCIT:C100547': 'MMSE - What Is the Month of Year',
#  'NCIT:C100548': 'MMSE - Question 2',
#  'NCIT:C100549': 'MMSE - What Is the State',
#  'NCIT:C10055': 'Cyclophosphamide/Doxorubicin/Folic Acid/Methotrexate',
#  'NCIT:C100550': 'MMSE - What Is the County',
#  'NCIT:C100551': 'MMSE - What Is the City or Town',
#  'NCIT:C100552': 'MMSE - What Is the Building',
#  'NCIT:C100553': 'MMSE - What Is the Floor',
#  'NCIT:C100554': 'MMSE - Question 3',
#  'NCIT:C100555': 'MMSE - Repeat Word 1',
#  'NCIT:C100556': 'MMSE - Repeat Word 2',
#  'NCIT:C100557': 'MMSE - Repeat Word 3',
#  'NCIT:C100558': 'MMSE - Question 4',
#  'NCIT:C100559': 'MMSE - What is 100 Take Away 7',
#  'NCIT:C10056': 'Cyclophosphamide/Cytarabine/Daunorubicin/Dexamethasone/Thioguanine/Vincristine',
#  'NCIT:C100560': 'MMSE - Keep Subtracting 7 Step 2',
#  'NCIT:C100561': 'MMSE - Keep Subtracting 7 Step 3',
#  'NCIT:C100562': 'MMSE - Keep Subtracting 7 Step 4',
#  'NCIT:C100563': 'MMSE - Keep Subtracting 7 Step 5',
#  'NCIT:C100564': 'MMSE - Question 4C',
#  'NCIT:C100565': 'MMSE - Spell Backward Letter 1',
#  'NCIT:C100566': 'MMSE - Spell Backward Letter 2',
#  'NCIT:C100567': 'MMSE - Spell Backward Letter 3',
#  'NCIT:C100568': 'MMSE - Spell Backward Letter 4',
#  'NCIT:C100569': 'MMSE - Spell Backward Letter 5',
#  'NCIT:C10057': 'Fenretinide/Tamoxifen',
#  'NCIT:C100570': 'MMSE - Attention and Calculation Subtotal',
#  'NCIT:C100571': 'MMSE - Question 5',
#  'NCIT:C100572': 'MMSE - Recall Word 1',
#  'NCIT:C100573': 'MMSE - Recall Word 2',
#  'NCIT:C100574': 'MMSE - Recall Word 3',
#  'NCIT:C100575': 'MMSE - Question 6',
#  'NCIT:C100576': 'MMSE - Naming Object 1',
#  'NCIT:C100577': 'MMSE - Naming Object 2',
#  'NCIT:C100578': 'MMSE - Repeat What I Say',
#  'NCIT:C100579': 'MMSE - Question 8',
#  'NCIT:C10058': 'Altretamine/Cisplatin/Cyclophosphamide/Fluorouracil Regimen',
#  'NCIT:C100580': 'MMSE - Take in Right Hand',
#  'NCIT:C100581': 'MMSE - Fold in Half',
#  'NCIT:C100582': 'MMSE - Put on Floor or Table',
#  'NCIT:C100583': 'MMSE - Read This and Do What It Says',
#  'NCIT:C100584': 'MMSE - Write a Sentence',
#  'NCIT:C100585': 'MMSE - Copy This Design',
#  'NCIT:C100586': 'MMSE - Total Score',
#  'NCIT:C100587': 'MNSI - Legs and/or Feet Numb',
#  'NCIT:C100588': 'MNSI - Burning Pain Legs/Feet',
#  'NCIT:C100589': 'MNSI - Feet Too Sensitive to Touch',
#  'NCIT:C10059': 'Dactinomycin/Tumor Necrosis Factor',
#  'NCIT:C100590': 'MNSI - Muscle Cramps Legs/Feet',
#  'NCIT:C100591': 'MNSI - Prickling Feelings Legs/Feet',
#  'NCIT:C100592': 'MNSI - Hurt When Bed Covers Touch Skin',
#  'NCIT:C100593': 'MNSI - Able to Tell Hot from Cold Water',
#  'NCIT:C100594': 'MNSI - Open Sore on Foot',
#  'NCIT:C100595': 'MNSI - Doctor Says Diabetic Neuropathy',
#  'NCIT:C100596': 'MNSI - Feel Weak All Over Most Times',
#  'NCIT:C100597': 'MNSI - Symptoms Worse at Night',
#  'NCIT:C100598': 'MNSI - Legs Hurt When Walking',
#  'NCIT:C100599': 'MNSI - Able to Sense Feet When Walking',
#  'NCIT:C1006': 'Ammonium Trichlorotellurate',
#  'NCIT:C10060': 'Cisplatin/Doxorubicin/Fluorouracil/Leucovorin Calcium',
#  'NCIT:C100600': 'MNSI - Skin So Dry That Feet Crack Open',
#  'NCIT:C100601': 'MNSI - Ever Had Amputation',
#  'NCIT:C100602': 'MNSI - History Total',
#  'NCIT:C100603': 'MNSI - Right Foot Appears Normal',
#  'NCIT:C100604': 'MNSI - Right Foot Deformities',
#  'NCIT:C100605': 'MNSI - Right Foot Infection',
#  'NCIT:C100606': 'MNSI - Right Foot Fissure',
#  'NCIT:C100607': 'MNSI - Right Foot Other Abnormal Specify',
#  'NCIT:C100608': 'MNSI - Left Foot Appears Normal',
#  'NCIT:C100609': 'MNSI - Left Foot Deformities',
#  'NCIT:C10061': 'Altretamine/Lomustine/Methotrexate',
#  'NCIT:C100610': 'MNSI - Left Foot Infection',
#  'NCIT:C100611': 'MNSI - Left Foot Fissure',
#  'NCIT:C100612': 'MNSI - Left Foot Other Abnormal Specify',
#  'NCIT:C100613': 'MNSI - Right Foot Ulceration',
#  'NCIT:C100614': 'MNSI - Left Foot Ulceration',
#  'NCIT:C100615': 'MNSI - Right Ankle Reflexes',
#  'NCIT:C100616': 'MNSI - Left Ankle Reflexes',
#  'NCIT:C100617': 'MNSI - Right Foot Vibration Great Toe',
#  'NCIT:C100618': 'MNSI - Left Foot Vibration Great Toe',
#  'NCIT:C100619': 'MNSI - Right Foot Monofilament',
#  'NCIT:C10062': 'Cyclophosphamide/Doxorubicin/Melphalan/Methotrexate/Vincristine',
#  'NCIT:C100620': 'MNSI - Left Foot Monofilament',
#  'NCIT:C100621': 'MNSI - Physical Assessment Total Score',
#  'NCIT:C100622': 'NPI - Have Beliefs That You Know are Not True',
#  'NCIT:C100623': 'NPI - He/She is in Danger',
#  'NCIT:C100624': 'NPI - Others are Stealing From Him/Her',
#  'NCIT:C100625': 'NPI - His/Her Spouse is Having an Affair',
#  'NCIT:C100626': 'NPI - Unwelcome Guests are Living in His/Her House',
#  'NCIT:C100627': 'NPI - His/Her Spouse or Others Are Not Who They Claim To Be',
#  'NCIT:C100628': 'NPI - His/Her House Is Not His/Her Home',
#  'NCIT:C100629': 'NPI - Family Members Plan to Abandon Him/Her',
#  'NCIT:C10063': 'Cyclophosphamide/Doxorubicin/Ethinyl Estradiol/Fluorouracil/Leucovorin Calcium',
#  'NCIT:C100630': 'NPI - Television or Magazine Figures Are Actually Present In the Home',
#  'NCIT:C100631': "NPI - Any Other Unusual Things That I Haven't Asked About",
#  'NCIT:C100632': 'NPI - Hallucinations Such as Seeing False Visions or Hearing False Voices',
#  'NCIT:C100633': 'NPI - Describe Hearing Voices or Act as if He/She Hears Voices',
#  'NCIT:C100634': 'NPI - Talk to People Who Are Not There',
#  'NCIT:C100635': 'NPI - Describe Seeing Things Not Seen by Others',
#  'NCIT:C100636': 'NPI - Report Smelling Odors Not Smelled by Others',
#  'NCIT:C100637': 'NPI - Describe Feeling Things on His/Her Skin',
#  'NCIT:C100638': 'NPI - Describe Tastes That Are Without Any Known Cause',
#  'NCIT:C100639': 'NPI - Describe Any Other Unusual Sensory Experiences',
#  'NCIT:C10064': 'Cyclophosphamide/Fluorouracil/Leucovorin Calcium/Mitoxantrone',
#  'NCIT:C100640': 'NPI - Periods When He/She Refuses to Cooperate',
#  'NCIT:C100641': 'NPI - Get Upset with Those Trying to Care for Him/Her',
#  'NCIT:C100642': 'NPI - Stubborn',
#  'NCIT:C100643': 'NPI - Uncooperative',
#  'NCIT:C100644': 'NPI - Any Other Behaviors That Make Him/Her Hard to Handle',
#  'NCIT:C100645': 'NPI - Shout or Curse Angrily',
#  'NCIT:C100646': 'NPI - Slam doors, Kick Furniture, Throw Things',
#  'NCIT:C100647': 'NPI - Attempt to Hurt or Hit Others',
#  'NCIT:C100648': 'NPI - Any Other Aggressive or Agitated Behaviors',
#  'NCIT:C100649': 'NPI - Seem Sad or Depressed',
#  'NCIT:C10065': 'Floxuridine/Leucovorin Calcium',
#  'NCIT:C100650': 'NPI - Periods of Tearfulness or Sobbing',
#  'NCIT:C100651': 'NPI - Say, or Act as if He/She is Sad or in Low Spirits',
#  'NCIT:C100652': 'NPI - Put Him/Herself Down or Say That He/She Feels Like a Failure',
#  'NCIT:C100653': 'NPI - Say That He/She is a Bad Person',
#  'NCIT:C100654': 'NPI - Seem Very Discouraged',
#  'NCIT:C100655': 'NPI - Say He/She is a Burden to the Family',
#  'NCIT:C100656': 'NPI - Express a Wish for Death',
#  'NCIT:C100657': 'NPI - Show Any Other Signs of Depression or Sadness',
#  'NCIT:C100658': 'NPI - Very Nervous, Worried, or Frightened for No Apparent Reason',
#  'NCIT:C100659': 'NPI - Say That He/She is Worried About Planned Events',
#  'NCIT:C10066': 'Fluorouracil/Interferon Beta',
#  'NCIT:C100660': 'NPI - Periods of Feeling Shaky, Unable to Relax, or Feeling Excessively Tense',
#  'NCIT:C100661': 'NPI - Periods of Shortness of Breath, Gasping, or Sighing for No Apparent Reason',
#  'NCIT:C100662': 'NPI - Complain of Butterflies, Racing or Pounding Heart',
#  'NCIT:C100663': 'NPI - Avoid Certain Places or Situations That Make Him/Her More Nervous',
#  'NCIT:C100664': 'NPI - Become Nervous and Upset When Separated From You',
#  'NCIT:C100665': 'NPI - Show Any Other Signs of Anxiety',
#  'NCIT:C100666': 'NPI - Seem Too Cheerful or Too Happy for No Reason',
#  'NCIT:C100667': 'NPI - Appear to Feel Good or to Be Too Happy',
#  'NCIT:C100668': 'NPI - Fine Humor and Laugh at Things That Others Do Not Find Funny',
#  'NCIT:C100669': 'NPI - Seem to Have a Childish Sense of Humor',
#  'NCIT:C10067': 'Cyclophosphamide/Doxorubicin/Fluorouracil/Streptozocin',
#  'NCIT:C100670': 'NPI - Tell Jokes or Make Remarks That are Not Funny to Others',
#  'NCIT:C100671': 'NPI - Play Childish Pranks',
#  'NCIT:C100672': 'NPI - Talk Big or Claim to Have More Abilities or Wealth Than is True',
#  'NCIT:C100673': 'NPI - Show Any Other Signs of Feeling Too Good or Being Too Happy',
#  'NCIT:C100674': 'NPI - Lost Interest in the World Around Him/Her',
#  'NCIT:C100675': 'NPI - Seem Less Spontaneous and Less Active Than Usual',
#  'NCIT:C100676': 'NPI - Less Likely Initiate to Initiate a Conversation',
#  'NCIT:C100677': 'NPI - Less Affectionate or Lacking in Emotions',
#  'NCIT:C100678': 'NPI - Contribute Less to Household Chores',
#  'NCIT:C100679': 'NPI - Less Interested in the Activities and Plans of Others',
#  'NCIT:C10068': 'Octreotide/Tamoxifen',
#  'NCIT:C100680': 'NPI - Lost Interest in Friends and Family Members',
#  'NCIT:C100681': 'NPI - Less Enthusiastic About His/Her Usual Interests',
#  'NCIT:C100682': "NPI - Show Any Other Signs That He/She Doesn't Care About Doing New Things",
#  'NCIT:C100683': 'NPI - Seem to Act Impulsively Without Thinking',
#  'NCIT:C100684': 'NPI - Act Impulsively without Appearing to Consider the Consequences',
#  'NCIT:C100685': 'NPI - Talk to Total Strangers as if He/She Knew Them',
#  'NCIT:C100686': 'NPI - Say Things to People that are Insensitive',
#  'NCIT:C100687': 'NPI - Say Crude Things or Make Sexual Remarks',
#  'NCIT:C100688': 'NPI - Talk Openly About Very Personal or Private Matters',
#  'NCIT:C100689': 'NPI - Take Liberties or Touch or Hug Others',
#  'NCIT:C10069': 'Melphalan/Methylprednisolone/Vincristine',
#  'NCIT:C100690': 'NPI - Show Any Other Signs of Loss of Control of His/Her Impulses',
#  'NCIT:C100691': 'NPI - Get Irritated and Easily Disturbed',
#  'NCIT:C100692': "NPI - Bad Temper, Flying 'Off the Handle' Easily Over Little Things",
#  'NCIT:C100693': 'NPI - Rapidly Change Moods From One to Another',
#  'NCIT:C100694': 'NPI - Sudden Flares of Anger',
#  'NCIT:C100695': 'NPI - Impatient, Having Trouble Coping with Delays',
#  'NCIT:C100696': 'NPI - Cranky and Irritable',
#  'NCIT:C100697': 'NPI - Argumentative and Difficult to Get Along With',
#  'NCIT:C100698': 'NPI - Show Any Other Signs of Irritability',
#  'NCIT:C100699': 'NPI - Pace, Do Things Over and Over, Repeatedly Pick at Things',
#  'NCIT:C1007': 'Azapicyl',
#  'NCIT:C10070': 'FACVP Regimen',
#  'NCIT:C100700': 'NPI - Pace Around the House Without Apparent Purpose',
#  'NCIT:C100701': 'NPI - Rummage Around Opening and Unpacking Drawers or Closets',
#  'NCIT:C100702': 'NPI - Repeatedly Put On and Take Off Clothing',
#  'NCIT:C100703': "NPI - Repetitive Activities or 'Habits'",
#  'NCIT:C100704': 'NPI - Engage in Repetitive Activities',
#  'NCIT:C100705': 'NPI - Fidget Excessively, Seem Unable to Sit Still',
#  'NCIT:C100706': 'NPI - Do Any Other Activities Over and Over',
#  'NCIT:C100707': 'NPI - Difficulty Sleeping',
#  'NCIT:C100708': 'NPI - Difficulty Falling Asleep',
#  'NCIT:C100709': 'NPI - Get Up During the Night',
#  'NCIT:C10071': 'Cyclophosphamide/Mercaptopurine/Prednisone/Vincristine Regimen',
#  'NCIT:C100710': 'NPI - Wander, Pace or Get Involved in Inappropriate Activities at Night',
#  'NCIT:C100711': 'NPI - Awaken You During the Night',
#  'NCIT:C100712': 'NPI - Wake Up at Night, Dress, and Plan to Go Out',
#  'NCIT:C100713': 'NPI - Awaken Too Early in Morning',
#  'NCIT:C100714': 'NPI - Sleep Excessively During the Day',
#  'NCIT:C100715': 'NPI - Any Other Nighttime Behaviors That Bother You',
#  'NCIT:C100716': 'NPI - Change in Appetite, Weight, or Eating Habits',
#  'NCIT:C100717': 'NPI - Loss of Appetite',
#  'NCIT:C100718': 'NPI - Increase in Appetite',
#  'NCIT:C100719': 'NPI - Loss of Weight',
#  'NCIT:C10072': 'Cyclophosphamide/Dexrazoxane/Doxorubicin/Fluorouracil',
#  'NCIT:C100720': 'NPI - Gained Weight',
#  'NCIT:C100721': 'NPI - Change in Eating Behavior',
#  'NCIT:C100722': 'NPI - Change in Kind of Food He/She Likes',
#  'NCIT:C100723': 'NPI - Developed Eating Behaviors Such as Eating Exactly the Same Types of Food',
#  'NCIT:C100724': 'NPI - Any Other Changes in Appetite or Eating',
#  'NCIT:C100725': 'PDQUALIF - Lightheadedness',
#  'NCIT:C100726': 'PDQUALIF - Imbalance',
#  'NCIT:C100727': 'PDQUALIF - Swallowing Difficulty',
#  'NCIT:C100728': 'PDQUALIF - Communication',
#  'NCIT:C100729': 'PDQUALIF - Nocturia',
#  'NCIT:C10073': 'Doxorubicin/Fluorouracil/Mitomycin/Triazinate',
#  'NCIT:C100730': 'PDQUALIF - Sexual Ability',
#  'NCIT:C100731': 'PDQUALIF - Neuropathy in Hands or Feet',
#  'NCIT:C100732': 'PDQUALIF - Bladder Control Difficulty',
#  'NCIT:C100733': 'PDQUALIF - Constipation',
#  'NCIT:C100734': 'PDQUALIF - Trouble with Sleep Initiation or Waking Early',
#  'NCIT:C100735': 'PDQUALIF - Trouble with Sleep Maintenance',
#  'NCIT:C100736': 'PDQUALIF - Positive Outlook Difficult',
#  'NCIT:C100737': 'PDQUALIF - Burden to Others',
#  'NCIT:C100738': 'PDQUALIF - Social Life Affected',
#  'NCIT:C100739': 'PDQUALIF - Worry about Future',
#  'NCIT:C10074': 'Asparaginase/Cytarabine/Sargramostim',
#  'NCIT:C100740': 'PDQUALIF - Difficulty in Asking for Help',
#  'NCIT:C100741': 'PDQUALIF - Important to Maintain Independence',
#  'NCIT:C100742': 'PDQUALIF - Difficulty in Adjusting to Change',
#  'NCIT:C100743': 'PDQUALIF - Social Life Not Affected',
#  'NCIT:C100744': 'PDQUALIF - Travel Important',
#  'NCIT:C100745': 'PDQUALIF - Family Relationship Affected',
#  'NCIT:C100746': 'PDQUALIF - Social Isolation',
#  'NCIT:C100747': 'PDQUALIF - Self Concept Change',
#  'NCIT:C100748': 'PDQUALIF - Sexual Desirability',
#  'NCIT:C100749': 'PDQUALIF - Independent Hygiene in Past 7 Days',
#  'NCIT:C10075': 'Etoposide/Methotrexate',
#  'NCIT:C100750': 'PDQUALIF - Independent Food Preparation in Past 7 Days',
#  'NCIT:C100751': 'PDQUALIF - Problem with Communication in the Past 7 Days',
#  'NCIT:C100752': 'PDQUALIF - Fatigue in Past 7 Days',
#  'NCIT:C100753': 'PDQUALIF - House Work in Past 7 Days',
#  'NCIT:C100754': 'PDQUALIF - Sleep with Partner in Past 7 Days',
#  'NCIT:C100755': 'PDQUALIF - Driving in Past 7 Days',
#  'NCIT:C100756': 'PDQUALIF - Financial Strain in Past 7 Days',
#  'NCIT:C100757': "PDQUALIF - Parkinson's Symptoms",
#  'NCIT:C100758': 'Lateral Decubitus Position',
#  'NCIT:C100759': 'Brief Pain Inventory Questionnaire',
#  'NCIT:C10076': 'Doxorubicin/Fluorouracil/Triazinate',
#  'NCIT:C100760': 'Brief Pain Inventory Short Form Questionnaire',
#  'NCIT:C100761': 'Brief Psychiatric Rating Scale A Clinical Classification',
#  'NCIT:C100762': "Alzheimer's Disease Assessment Scale-Cognitive CDISC Version Questionnaire",
#  'NCIT:C100763': 'Clinical Global Impression Original Version Questionnaire',
#  'NCIT:C100764': 'Current Opioid Misuse Measure Questionnaire',
#  'NCIT:C100765': 'Columbia-Suicide Severity Rating Scale Baseline Questionnaire',
#  'NCIT:C100766': 'Faces Pain Scale Revised Questionnaire',
#  'NCIT:C100767': 'Hamilton Depression Rating Scale 17 Item Clinical Classification',
#  'NCIT:C100768': 'Karnofsky Performance Status Scale Clinical Classification',
#  'NCIT:C100769': "Movement Disorder Society Unified Parkinson's Disease Rating Scale Questionnaire",
#  'NCIT:C10077': 'Interferon Gamma/Levamisole',
#  'NCIT:C100771': 'Michigan Neuropathy Screening Instrument Questionnaire',
#  'NCIT:C100772': 'Neuropsychiatric Inventory Questionnaire',
#  'NCIT:C100773': "Parkinson's Disease Quality of Life Scale Questionnaire",
#  'NCIT:C100774': 'Roland Morris Disability Questionnaire',
#  'NCIT:C100775': 'Short Form 36 Health Survey Standard, US Version 1.0 Questionnaire',
#  'NCIT:C100776': 'Short-Form McGill Pain Questionnaire-2',
#  'NCIT:C100777': 'Screener and Opioid Assessment for Patients with Pain Revised Questionnaire',
#  'NCIT:C100778': "Unified Parkinson's Disease Rating Scale Clinical Classification",
#  'NCIT:C100779': 'Work Productivity and Activity Impairment Specific Health Problems Version 2.0 Questionnaire',
#  'NCIT:C10078': 'Cyclophosphamide/Doxorubicin/Fluorouracil/Sargramostim',
#  'NCIT:C100780': 'RDQ - Stay at Home',
#  'NCIT:C100781': 'RDQ - Change Position Frequently',
#  'NCIT:C100782': 'RDQ - Walk More Slowly',
#  'NCIT:C100783': 'RDQ - Not Do Any Usual House Jobs',
#  'NCIT:C100784': 'RDQ - Use Handrail to Get Upstairs',
#  'NCIT:C100785': 'RDQ - Lie Down to Rest More Often',
#  'NCIT:C100786': 'RDQ - Hold on to Get Out of a Chair',
#  'NCIT:C100787': 'RDQ - Get Other People to Do Things',
#  'NCIT:C100788': 'RDQ - Get Dressed More Slowly',
#  'NCIT:C100789': 'RDQ - Only Stand for Short Periods',
#  'NCIT:C10079': 'Bleomycin/Procarbazine/Vinblastine',
#  'NCIT:C100790': 'RDQ - Try Not to Bend or Kneel',
#  'NCIT:C100791': 'RDQ - Difficult to Get Out of a Chair',
#  'NCIT:C100792': 'RDQ - Painful Almost All the Time',
#  'NCIT:C100793': 'RDQ - Difficult to Turn Over in Bed',
#  'NCIT:C100794': 'RDQ - Appetite is Not Very Good',
#  'NCIT:C100795': 'RDQ - Trouble Putting on Socks or Stockings',
#  'NCIT:C100796': 'RDQ - Only Walk Short Distances',
#  'NCIT:C100797': 'RDQ - Sleep Less Well',
#  'NCIT:C100798': 'RDQ - Get Dressed With Help',
#  'NCIT:C100799': 'RDQ - Sit Down Most of the Day',
#  'NCIT:C1008': 'Azaribine',
#  'NCIT:C10080': 'Cytarabine/Doxorubicin/Mercaptopurine/Prednisone/Vincristine',
#  'NCIT:C100800': 'RDQ - Avoid Heavy Jobs',
#  'NCIT:C100801': 'RDQ - More Irritable With People',
#  'NCIT:C100802': 'RDQ - Go Upstairs More Slowly',
#  'NCIT:C100803': 'RDQ - Stay in Bed',
#  'NCIT:C100804': 'RDQ - Total Derived Score',
#  'NCIT:C100805': 'Biological Grandchild',
#  'NCIT:C100806': 'Biological Grandparent',
#  'NCIT:C100808': 'Third Degree Relative',
#  'NCIT:C100809': 'Biological Sibling',
#  'NCIT:C10081': 'Altretamine/Etoposide/Procarbazine',
#  'NCIT:C100810': 'Organ Donor',
#  'NCIT:C100811': 'Pregnancy Partner',
#  'NCIT:C100812': 'Sexual Partner',
#  'NCIT:C100813': 'SF36 v1.0 Standard - In General You Say Your Health Is',
#  'NCIT:C100814': 'SF36 v1.0 Standard - Comp Year Ago Rate Gen Health Now',
#  'NCIT:C100815': 'SF36 v1.0 Standard - Limit Vigorous Activities',
#  'NCIT:C100816': 'SF36 v1.0 Standard - Limit Moderate Activities',
#  'NCIT:C100817': 'SF36 v1.0 Standard - Limit Lifting or Carrying',
#  'NCIT:C100818': 'SF36 v1.0 Standard - Limit Climbing Several Flights',
#  'NCIT:C100819': 'SF36 v1.0 Standard - Limit Climbing One Flight Stairs',
#  'NCIT:C10082': 'Bleomycin/Cisplatin/Doxorubicin',
#  'NCIT:C100820': 'SF36 v1.0 Standard - Limit Bending/Kneeling/Stooping',
#  'NCIT:C100821': 'SF36 v1.0 Standard - Limit Walking More Than a Mile',
#  'NCIT:C100822': 'SF36 v1.0 Standard - Limit Walking Several Blocks',
#  'NCIT:C100823': 'SF36 v1.0 Standard - Limit Walking One Block',
#  'NCIT:C100824': 'SF36 v1.0 Standard - Limit Bathing or Dressing Yourself',
#  'NCIT:C100825': 'SF36 v1.0 Standard - Physical: Cut Down Time on Work',
#  'NCIT:C100826': 'SF36 v1.0 Standard - Physical: Accomplished Less',
#  'NCIT:C100827': 'SF36 v1.0 Standard - Physical: Limited Kind of Work',
#  'NCIT:C100828': 'SF36 v1.0 Standard - Physical: Difficulty Perform Work',
#  'NCIT:C100829': 'SF36 v1.0 Standard - Emotional: Cut Down Time on Work',
#  'NCIT:C10083': 'FUVAC Regimen',
#  'NCIT:C100830': 'SF36 v1.0 Standard - Emotional: Accomplished Less',
#  'NCIT:C100831': 'SF36 v1.0 Standard - Emotional: Did Work Less Carefully',
#  'NCIT:C100832': 'SF36 v1.0 Standard - Extent Phys/Emotional Interfered',
#  'NCIT:C100833': 'SF36 v1.0 Standard - How Much Bodily Pain Have You Had',
#  'NCIT:C100834': 'SF36 v1.0 Standard - Pain Interfere With Normal Work',
#  'NCIT:C100835': 'SF36 v1.0 Standard - Did You Feel Full of Pep',
#  'NCIT:C100836': 'SF36 v1.0 Standard - Have You Been Very Nervous Person',
#  'NCIT:C100837': 'SF36 v1.0 Standard - Felt Down Nothing Cheer You Up',
#  'NCIT:C100838': 'SF36 v1.0 Standard - Have You Felt Calm and Peaceful',
#  'NCIT:C100839': 'SF36 v1.0 Standard - Did You Have a Lot of Energy',
#  'NCIT:C10084': 'Cytarabine/Doxorubicin/Mercaptopurine',
#  'NCIT:C100840': 'SF36 v1.0 Standard - You Felt Downhearted and Blue',
#  'NCIT:C100841': 'SF36 v1.0 Standard - Did You Feel Worn Out',
#  'NCIT:C100842': 'SF36 v1.0 Standard - Have You Been Happy Person',
#  'NCIT:C100843': 'SF36 v1.0 Standard - Did You Feel Tired',
#  'NCIT:C100844': 'SF36 v1.0 Standard - Time Phys/Emotional Interfered',
#  'NCIT:C100845': 'SF36 v1.0 Standard - Get Sick Little Easier Than Other',
#  'NCIT:C100846': 'SF36 v1.0 Standard - I Am as Healthy as Anybody I Know',
#  'NCIT:C100847': 'SF36 v1.0 Standard - I Expect My Health to Get Worse',
#  'NCIT:C100848': 'SF36 v1.0 Standard - My Health is Excellent',
#  'NCIT:C100849': 'SF-MPQ-2 - Throbbing Pain',
#  'NCIT:C10085': 'Altretamine/Cyclophosphamide/Doxorubicin',
#  'NCIT:C100850': 'SF-MPQ-2 - Shooting Pain',
#  'NCIT:C100851': 'SF-MPQ-2 - Stabbing Pain',
#  'NCIT:C100852': 'SF-MPQ-2 - Sharp Pain',
#  'NCIT:C100853': 'SF-MPQ-2 - Cramping Pain',
#  'NCIT:C100854': 'SF-MPQ-2 - Gnawing Pain',
#  'NCIT:C100855': 'SF-MPQ-2 - Hot-burning Pain',
#  'NCIT:C100856': 'SF-MPQ-2 - Aching Pain',
#  'NCIT:C100857': 'SF-MPQ-2 - Heavy Pain',
#  'NCIT:C100858': 'SF-MPQ-2 - Tender',
#  'NCIT:C100859': 'SF-MPQ-2 - Splitting Pain',
#  'NCIT:C10086': 'Cytarabine/Prednisone/Thioguanine/Vincristine',
#  'NCIT:C100860': 'SF-MPQ-2 - Tiring-Exhausting',
#  'NCIT:C100861': 'SF-MPQ-2 - Sickening',
#  'NCIT:C100862': 'SF-MPQ-2 - Fearful',
#  'NCIT:C100863': 'SF-MPQ-2 - Punishing-Cruel',
#  'NCIT:C100864': 'SF-MPQ-2 - Electric-Shock Pain',
#  'NCIT:C100865': 'SF-MPQ-2 - Cold-Freezing Pain',
#  'NCIT:C100866': 'SF-MPQ-2 - Piercing',
#  'NCIT:C100867': 'SF-MPQ-2 - Pain Caused by Light Touch',
#  'NCIT:C100868': 'SF-MPQ-2 - Itching',
#  'NCIT:C100869': 'SF-MPQ-2 - Numbness',
#  'NCIT:C10087': 'Dacarbazine/Dactinomycin/Vincristine',
#  'NCIT:C100870': 'SOAPP-R - How Often Mood Swings',
#  'NCIT:C100871': 'SOAPP-R - Need Higher Doses of Medication',
#  'NCIT:C100872': 'SOAPP-R - Felt Impatient With Doctors',
#  'NCIT:C100873': 'SOAPP-R - Felt That Things Are Overwhelming',
#  'NCIT:C100874': 'SOAPP-R - How Often Tension at Home',
#  'NCIT:C100875': 'SOAPP-R - How Often Counted Pain Pills',
#  'NCIT:C100876': 'SOAPP-R - Concerned People Will Judge You',
#  'NCIT:C100877': 'SOAPP-R - How Often Feel Bored',
#  'NCIT:C100878': 'SOAPP-R - How Often Taken More Pain Medication',
#  'NCIT:C100879': 'SOAPP-R - Worried About Being Left Alone',
#  'NCIT:C10088': 'Cytarabine/Zorubicin',
#  'NCIT:C100880': 'SOAPP-R - Felt Craving for Medication',
#  'NCIT:C100881': 'SOAPP-R - Others Expressed Concern Over Medication Use',
#  'NCIT:C100882': 'SOAPP-R - How Often Friends Had Problem',
#  'NCIT:C100883': 'SOAPP-R - Others Told You Bad Temper',
#  'NCIT:C100884': 'SOAPP-R - Felt Consumed to Get Pain Medication',
#  'NCIT:C100885': 'SOAPP-R - Run Out of Pain Medication Early',
#  'NCIT:C100886': 'SOAPP-R - Others Kept You From what You Deserve',
#  'NCIT:C100887': 'SOAPP-R - Legal Problems or Arrested',
#  'NCIT:C100888': 'SOAPP-R - Attended AA or NA Meeting',
#  'NCIT:C100889': 'SOAPP-R - Argument Where Someone Got Hurt',
#  'NCIT:C10089': 'Cisplatin/Cyclophosphamide/Cytarabine/Hydroxyurea/Lomustine/Methylprednisolone/Procarbazine/Vincristine',
#  'NCIT:C100890': 'SOAPP-R - How Often Sexually Abused',
#  'NCIT:C100891': 'SOAPP-R - Others Suggested Drug or Alcohol Problem',
#  'NCIT:C100892': 'SOAPP-R - How Often Borrowed Pain Medication',
#  'NCIT:C100893': 'SOAPP-R - Treated for Alcohol or Drug Problem',
#  'NCIT:C100894': 'SOAPP-R - Any Additional Information',
#  'NCIT:C100895': 'SOAPP-R - Score',
#  'NCIT:C100896': 'Prostatic Fluid',
#  'NCIT:C100897': 'Thousand Copies per Milliliter',
#  'NCIT:C100898': 'Million Copies per Milliliter',
#  'NCIT:C100899': 'Diopter',
#  'NCIT:C1009': 'Ethyleneimine',
#  'NCIT:C10090': 'Doxorubicin/Methotrexate/Vinblastine',
#  'NCIT:C100900': 'Copies per Milliliter',
#  'NCIT:C100901': 'UPDRS - Mentation, Behavior and Mood: Intellectual Impairment',
#  'NCIT:C100902': 'UPDRS - Mentation, Behavior and Mood: Thought Disorder',
#  'NCIT:C100903': 'UPDRS - Mentation, Behavior and Mood: Depression',
#  'NCIT:C100904': 'UPDRS - Mentation, Behavior and Mood: Motivation/Initiative',
#  ...}

# %%
# name -> id mapping
print({len(name_to_id)})
name_to_id
# Out:
# {162031}
# {'Recombinant Amphiregulin': 'NCIT:C1000',
#  'Cyclophosphamide/Fluoxymesterone/Mitolactol/Prednisone/Tamoxifen': 'NCIT:C10000',
#  'Percutaneous Coronary Intervention for ST Elevation Myocardial Infarction-Stable-Over 12 Hours From Symptom Onset': 'NCIT:C100000',
#  'Percutaneous Coronary Intervention for ST Elevation Myocardial Infarction-Stable After Successful Full-Dose Thrombolytic Therapy': 'NCIT:C100001',
#  'Percutaneous Coronary Intervention for ST Elevation Myocardial Infarction-Unstable-Over 12 Hours From Symptom Onset': 'NCIT:C100002',
#  'Percutaneous Mitral Valve Repair': 'NCIT:C100003',
#  'Pericardial Stripping': 'NCIT:C100004',
#  'Post-Cardiac Transplant Evaluation': 'NCIT:C100005',
#  'Pre-Operative Evaluation for Non-Cardiovascular Surgery': 'NCIT:C100006',
#  'Previously Implanted Cardiac Lead': 'NCIT:C100007',
#  'Rescue Percutaneous Coronary Intervention for ST Elevation Myocardial Infarction After Failed Full-Dose Thrombolytic Therapy': 'NCIT:C100008',
#  'Reused Cardiac Lead': 'NCIT:C100009',
#  'CONPADRI-I Regimen': 'NCIT:C10001',
#  'Right Cardiac Ventricle Assist Device Procedure': 'NCIT:C100010',
#  'Right Cardiac Ventricle Pacing Malfunction': 'NCIT:C100011',
#  'Severe Cardiac Valve Regurgitation': 'NCIT:C100012',
#  'Severe Cardiac Valve Stenosis': 'NCIT:C100013',
#  'Spontaneous Sustained Ventricular Tachycardia by ECG Finding': 'NCIT:C100014',
#  'Staged Percutaneous Coronary Intervention': 'NCIT:C100015',
#  'Subject Delay in Providing Consent': 'NCIT:C100016',
#  'Surgical Maze Procedure': 'NCIT:C100017',
#  'Syncope with High Risk Cardiac Characteristics': 'NCIT:C100018',
#  'Syncope with Inducible Ventricular Tachycardia by ECG Finding': 'NCIT:C100019',
#  'Cyclophosphamide/Doxorubicin/Fluorouracil/Methotrexate/Prednisone/Vincristine': 'NCIT:C10002',
#  'Three Vessel Coronary Disease': 'NCIT:C100020',
#  'Thrombolysis in Myocardial Infarction Flow': 'NCIT:C100021',
#  'Transcatheter Aortic Valve Implantation': 'NCIT:C100022',
#  'Two Vessel Coronary Disease': 'NCIT:C100023',
#  'Typical Coronary Artery Disease Symptom': 'NCIT:C100024',
#  'Unable to Obtain Acceptable Pacing Thresholds': 'NCIT:C100025',
#  'Unable to Obtain Satisfactory Coronary Sinus Access': 'NCIT:C100026',
#  'Unable to Obtain Satisfactory Vascular Access': 'NCIT:C100027',
#  'Unable to Position Lead Due to Coronary Sinus Dissection': 'NCIT:C100028',
#  'Unable to Position Lead In tributary Vein of Coronary Sinus': 'NCIT:C100029',
#  'Methotrexate/Teniposide': 'NCIT:C10003',
#  'Upgrade to Cardiac Device with Additional Pacing Capabilities': 'NCIT:C100030',
#  'Urgent Procedure': 'NCIT:C100031',
#  'American College of Cardiology/American Heart Association Lesion Complexity Class': 'NCIT:C100032',
#  'Cardiac Arrest/Arrhythmia Etiology Unknown': 'NCIT:C100033',
#  'Cardiac Lead Dislodgement Requiring Reposition/Reoperation': 'NCIT:C100034',
#  'Faulty Device Connector/Header': 'NCIT:C100035',
#  'Idiopathic Primary Ventricular Tachycardia/Ventricular Flutter by ECG Finding': 'NCIT:C100036',
#  'American College of Cardiology/American Heart Association Lesion Complexity Score A': 'NCIT:C100037',
#  'American College of Cardiology/American Heart Association Lesion Complexity Score B': 'NCIT:C100038',
#  'American College of Cardiology/American Heart Association Lesion Complexity Score C': 'NCIT:C100039',
#  'Cyclophosphamide/Fluorouracil/Methotrexate/Prednisone/Tamoxifen/Vincristine': 'NCIT:C10004',
#  'Thrombolysis in Myocardial Infarction Flow-0': 'NCIT:C100040',
#  'Thrombolysis in Myocardial Infarction Flow-1': 'NCIT:C100041',
#  'Thrombolysis in Myocardial Infarction Flow-2': 'NCIT:C100042',
#  'Thrombolysis in Myocardial Infarction Flow-3': 'NCIT:C100043',
#  'Pulmonic Valvuloplasty': 'NCIT:C100044',
#  'Manufacturer Recall': 'NCIT:C100045',
#  'Evaux Spring Water-based Topical Spray': 'NCIT:C100046',
#  'File Transfer Protocol': 'NCIT:C100047',
#  'Secure File Transfer Protocol': 'NCIT:C100048',
#  'Transfer Of Images And Data': 'NCIT:C100049',
#  'Altretamine/Cyclophosphamide/Doxorubicin/Prednisone/Vincristine': 'NCIT:C10005',
#  'Needle Free Injection': 'NCIT:C100050',
#  'Renal Cell Carcinoma Associated with Neuroblastoma': 'NCIT:C100051',
#  'Needle Free Injection Dosing Unit': 'NCIT:C100052',
#  'Sinus Node Functional Assessment': 'NCIT:C100053',
#  'Conjunctival Melanocytic Intraepithelial Neoplasia': 'NCIT:C100054',
#  'Immigrant': 'NCIT:C100055',
#  'Arterial Access Site': 'NCIT:C100056',
#  'Arterial Access Closure': 'NCIT:C100057',
#  'Pre-Procedure': 'NCIT:C100058',
#  'Post-Procedure': 'NCIT:C100059',
#  'Altretamine/Cisplatin/Cyclophosphamide/Misonidazole': 'NCIT:C10006',
#  'Intrinsic QRS Duration': 'NCIT:C100060',
#  'Paced Ventricular Rhythm without Intrinsic Ventricular Complexes': 'NCIT:C100061',
#  'Chronic Total Coronary Artery Occlusion': 'NCIT:C100062',
#  'Coronary Vessel Lesion': 'NCIT:C100063',
#  'Coronary Artery Graft': 'NCIT:C100064',
#  'Glyceryl Dibehenate': 'NCIT:C100065',
#  'Coronary Lesion Complexity': 'NCIT:C100066',
#  'Coronary Reperfusion Procedure': 'NCIT:C100067',
#  'Cardiac Ablation': 'NCIT:C100068',
#  'Cardiac Valve Injury': 'NCIT:C100069',
#  'CytaBOM Regimen': 'NCIT:C10007',
#  'Coronary Venous Dissection': 'NCIT:C100070',
#  'Cardiac Computerized Tomographic Angiography': 'NCIT:C100071',
#  'Coronary Culprit Lesion': 'NCIT:C100072',
#  'Cardiac Stress Test': 'NCIT:C100073',
#  'Cardiac Ischemic Risk Score': 'NCIT:C100074',
#  'Non-Invasive Cardiac Stress Test': 'NCIT:C100075',
#  'Sinus Rhythm': 'NCIT:C100076',
#  'Luminal Carotid Thrombus': 'NCIT:C100077',
#  'Transplant Waiting List': 'NCIT:C100078',
#  'Smoking Tobacco': 'NCIT:C100079',
#  'Asparaginase/Methotrexate/Vincristine': 'NCIT:C10008',
#  'Cardiac Stent Placement': 'NCIT:C100080',
#  'In Stent Restenosis': 'NCIT:C100081',
#  'Guidewire Across Lesion': 'NCIT:C100082',
#  'Coronary Artery Perforation': 'NCIT:C100083',
#  'Cardiac Diagnostic Procedure': 'NCIT:C100084',
#  'Coronary Angiography': 'NCIT:C100085',
#  'Coronary Artery Dominance': 'NCIT:C100086',
#  'Intra-Aortic Balloon Pump': 'NCIT:C100087',
#  'Interferon Gamma-1a': 'NCIT:C100088',
#  'Interferon Gamma-1b': 'NCIT:C100089',
#  'Prednisolone/Tamoxifen': 'NCIT:C10009',
#  'Bifocal': 'NCIT:C100090',
#  'Eosinophil Lysophospholipase': 'NCIT:C100091',
#  'Fistulagram': 'NCIT:C100092',
#  'Central Nervous System Nongerminomatous Germ Cell Tumor': 'NCIT:C100093',
#  'HGNC_ID': 'NCIT:C100094',
#  'Lichenoid': 'NCIT:C100095',
#  'Oral Mucositis Rating Scale': 'NCIT:C100096',
#  'Ginger Flavor': 'NCIT:C100097',
#  'Ademetionine': 'NCIT:C100098',
#  'Synthetic Breast Cancer Peptides-Tetanus Toxoid-Poly ICLC Vaccine': 'NCIT:C100099',
#  'Rintatolimod': 'NCIT:C1001',
#  'Asparaginase/Cyclophosphamide/Methotrexate/Prednisone/Vincristine/Zorubicin': 'NCIT:C10010',
#  'HPV E1/E2 Interaction Inhibitor Gel AP611074': 'NCIT:C100100',
#  'Naratuximab Emtansine': 'NCIT:C100101',
#  'Adenovirus/Cytomegalovirus/Epstein-Barr Virus-specific Allogeneic Cytotoxic T Lymphocytes': 'NCIT:C100102',
#  'Cellular Sheet Dosage Form': 'NCIT:C100103',
#  'Sign or Symptom': 'NCIT:C100104',
#  'ADAS-Cog CDISC Version Questionnaire Question': 'NCIT:C100106',
#  'BPI Questionnaire Question': 'NCIT:C100107',
#  'BPI Short Form Questionnaire Question': 'NCIT:C100108',
#  'BPRS-A Clinical Classification Question': 'NCIT:C100109',
#  'Cyclophosphamide/Melphalan/Methylprednisolone': 'NCIT:C10011',
#  'CDISC Questionnaire Terminology': 'NCIT:C100110',
#  'CGI Questionnaire Question': 'NCIT:C100111',
#  'COMM Questionnaire Question': 'NCIT:C100112',
#  'C-SSRS Baseline Questionnaire Question': 'NCIT:C100113',
#  'EQ-5D-3L Questionnaire Question': 'NCIT:C100114',
#  'FPSR Questionnaire Question': 'NCIT:C100115',
#  'KPS Scale Questionnaire Question': 'NCIT:C100116',
#  'MDS-UPDRS Questionnaire Question': 'NCIT:C100117',
#  'MMSE Functional Test Question': 'NCIT:C100118',
#  'MNSI Questionnaire Question': 'NCIT:C100119',
#  'Cyclophosphamide/Prednisone/Vincristine/Zorubicin': 'NCIT:C10012',
#  'NPI Questionnaire Question': 'NCIT:C100120',
#  'PDQUALIF Questionnaire Question': 'NCIT:C100121',
#  'Pepsinogen Measurement': 'NCIT:C100122',
#  'RDQ Questionnaire Question': 'NCIT:C100123',
#  'Short-Form MPQ-2 Questionnaire Question': 'NCIT:C100124',
#  'SOAPP-R Questionnaire Question': 'NCIT:C100125',
#  'UPDRS Clinical Classification Question': 'NCIT:C100126',
#  'HAMD-17 Questionnaire Question': 'NCIT:C100127',
#  'Partner': 'NCIT:C100128',
#  'CDISC Questionnaire Category Terminology': 'NCIT:C100129',
#  'Doxorubicin/Fluoxymesterone/Mitolactol/Tamoxifen': 'NCIT:C10013',
#  'CDISC SDTM Relationship to Subject Terminology': 'NCIT:C100130',
#  'CDISC Questionnaire ADAS-Cog CDISC Version Test Name Terminology': 'NCIT:C100131',
#  'CDISC Questionnaire ADAS-Cog CDISC Version Test Code Terminology': 'NCIT:C100132',
#  'CDISC Clinical Classification BPRS-A Test Name Terminology': 'NCIT:C100133',
#  'CDISC Clinical Classification BPRS-A Test Code Terminology': 'NCIT:C100134',
#  'CDISC Questionnaire EQ-5D-3L Test Name Terminology': 'NCIT:C100135',
#  'CDISC Questionnaire EQ-5D-3L Test Code Terminology': 'NCIT:C100136',
#  'CDISC Clinical Classification HAMD 17 Test Name Terminology': 'NCIT:C100137',
#  'CDISC Clinical Classification HAMD 17 Test Code Terminology': 'NCIT:C100138',
#  'CDISC Questionnaire MDS-UPDRS Test Name Terminology': 'NCIT:C100139',
#  'Fluoxymesterone/Mitolactol/Mitoxantrone/Tamoxifen': 'NCIT:C10014',
#  'CDISC Questionnaire MDS-UPDRS Test Code Terminology': 'NCIT:C100140',
#  'CDISC Functional Test MMSE Test Name Terminology': 'NCIT:C100141',
#  'CDISC Functional Test MMSE Test Code Terminology': 'NCIT:C100142',
#  'CDISC Questionnaire NPI Test Name Terminology': 'NCIT:C100143',
#  'CDISC Questionnaire NPI Test Code Terminology': 'NCIT:C100144',
#  'CDISC Questionnaire PDQUALIF Test Name Terminology': 'NCIT:C100145',
#  'CDISC Questionnaire PDQUALIF Test Code Terminology': 'NCIT:C100146',
#  'CDISC Clinical Classification UPDRS Test Name Terminology': 'NCIT:C100147',
#  'CDISC Clinical Classification UPDRS Test Code Terminology': 'NCIT:C100148',
#  'CDISC Questionnaire CGI Test Name Terminology': 'NCIT:C100149',
#  'Cisplatin/Dianhydrogalactitol/Doxorubicin': 'NCIT:C10015',
#  'CDISC Questionnaire CGI Test Code Terminology': 'NCIT:C100150',
#  'CDISC Questionnaire MNSI Test Name Terminology': 'NCIT:C100151',
#  'CDISC Questionnaire MNSI Test Code Terminology': 'NCIT:C100152',
#  'CDISC Questionnaire FPSR Test Name Terminology': 'NCIT:C100153',
#  'CDISC Questionnaire FPSR Test Code Terminology': 'NCIT:C100154',
#  'CDISC Questionnaire Short-Form MPQ-2 Test Name Terminology': 'NCIT:C100155',
#  'CDISC Questionnaire Short-Form MPQ-2 Test Code Terminology': 'NCIT:C100156',
#  'CDISC Questionnaire COMM Test Name Terminology': 'NCIT:C100157',
#  'CDISC Questionnaire COMM Test Code Terminology': 'NCIT:C100158',
#  'CDISC Questionnaire SOAPP-R Test Name Terminology': 'NCIT:C100159',
#  'Ancitabine Hydrochloride/Daunorubicin/Mercaptopurine/Prednisolone': 'NCIT:C10016',
#  'CDISC Questionnaire SOAPP-R Test Code Terminology': 'NCIT:C100160',
#  'CDISC Questionnaire BPI Test Name Terminology': 'NCIT:C100161',
#  'CDISC Questionnaire BPI Test Code Terminology': 'NCIT:C100162',
#  'CDISC Questionnaire BPI Short Form Test Name Terminology': 'NCIT:C100163',
#  'CDISC Questionnaire BPI Short Form Test Code Terminology': 'NCIT:C100164',
#  'CDISC Questionnaire RDQ Test Name Terminology': 'NCIT:C100165',
#  'CDISC Questionnaire RDQ Test Code Terminology': 'NCIT:C100166',
#  'CDISC Questionnaire C-SSRS Baseline Test Name Terminology': 'NCIT:C100167',
#  'CDISC Questionnaire C-SSRS Baseline Test Code Terminology': 'NCIT:C100168',
#  'CDISC Clinical Classification KPS Scale Test Name Terminology': 'NCIT:C100169',
#  'Doxorubicin/Fluoxymesterone/Methotrexate/Mitolactol/Tamoxifen/Vincristine': 'NCIT:C10017',
#  'CDISC Clinical Classification KPS Scale Test Code Terminology': 'NCIT:C100170',
#  'SF36 v1.0 Standard Questionnaire Question': 'NCIT:C100171',
#  'WPAI:SHP v2.0 Questionnaire Question': 'NCIT:C100172',
#  'CDISC Questionnaire SF36 v1.0 Standard Test Name Terminology': 'NCIT:C100173',
#  'CDISC Questionnaire SF36 v1.0 Standard Test Code Terminology': 'NCIT:C100174',
#  'CDISC Questionnaire WPAI:SHP v2.0 Test Name Terminology': 'NCIT:C100175',
#  'CDISC Questionnaire WPAI:SHP v2.0 Test Code Terminology': 'NCIT:C100176',
#  'CDISC ADAS-Cog - Word Recall Average Score': 'NCIT:C100177',
#  'CDISC ADAS-Cog - Word Recall Trial 1 Subscore': 'NCIT:C100178',
#  'CDISC ADAS-Cog - Word Recall Trial 2 Subscore': 'NCIT:C100179',
#  'Dianhydrogalactitol/Etoposide': 'NCIT:C10018',
#  'CDISC ADAS-Cog - Word Recall Trial 3 Subscore': 'NCIT:C100180',
#  'CDISC ADAS-Cog - Word Recall: Word 1': 'NCIT:C100181',
#  'CDISC ADAS-Cog - Word Recall: Word 2': 'NCIT:C100182',
#  'CDISC ADAS-Cog - Word Recall: Word 3': 'NCIT:C100183',
#  'CDISC ADAS-Cog - Word Recall: Word 4': 'NCIT:C100184',
#  'CDISC ADAS-Cog - Word Recall: Word 5': 'NCIT:C100185',
#  'CDISC ADAS-Cog - Word Recall: Word 6': 'NCIT:C100186',
#  'CDISC ADAS-Cog - Word Recall: Word 7': 'NCIT:C100187',
#  'CDISC ADAS-Cog - Word Recall: Word 8': 'NCIT:C100188',
#  'CDISC ADAS-Cog - Word Recall: Word 9': 'NCIT:C100189',
#  'DZAPO Regimen': 'NCIT:C10019',
#  'CDISC ADAS-Cog - Word Recall: Word 10': 'NCIT:C100190',
#  'CDISC ADAS-Cog - Naming Objects and Fingers Summary Score': 'NCIT:C100191',
#  'CDISC ADAS-Cog - Naming Objects and Fingers: 1': 'NCIT:C100192',
#  'CDISC ADAS-Cog - Naming Objects and Fingers: 2': 'NCIT:C100193',
#  'CDISC ADAS-Cog - Naming Objects and Fingers: 3': 'NCIT:C100194',
#  'CDISC ADAS-Cog - Naming Objects and Fingers: 4': 'NCIT:C100195',
#  'CDISC ADAS-Cog - Naming Objects and Fingers: 5': 'NCIT:C100196',
#  'CDISC ADAS-Cog - Naming Objects and Fingers: 6': 'NCIT:C100197',
#  'CDISC ADAS-Cog - Naming Objects and Fingers: 7': 'NCIT:C100198',
#  'CDISC ADAS-Cog - Naming Objects and Fingers: 8': 'NCIT:C100199',
#  'Recombinant Angiogenin': 'NCIT:C1002',
#  'Fluorouracil/Methotrexate/Mitolactol/Prednisone': 'NCIT:C10020',
#  'CDISC ADAS-Cog - Naming Objects and Fingers: 9': 'NCIT:C100200',
#  'CDISC ADAS-Cog - Naming Objects and Fingers: 10': 'NCIT:C100201',
#  'CDISC ADAS-Cog - Naming Objects and Fingers: 11': 'NCIT:C100202',
#  'CDISC ADAS-Cog - Naming Objects and Fingers: 12': 'NCIT:C100203',
#  'CDISC ADAS-Cog - Naming Objects and Fingers: Thumb': 'NCIT:C100204',
#  'CDISC ADAS-Cog - Naming Objects and Fingers: Pointer': 'NCIT:C100205',
#  'CDISC ADAS-Cog - Naming Objects and Fingers: Middle': 'NCIT:C100206',
#  'CDISC ADAS-Cog - Naming Objects and Fingers: Ring': 'NCIT:C100207',
#  'CDISC ADAS-Cog - Naming Objects and Fingers: Pinky': 'NCIT:C100208',
#  'CDISC ADAS-Cog - Commands Summary Score': 'NCIT:C100209',
#  'BCG/Cyclophosphamide/Doxorubicin/Tegafur': 'NCIT:C10021',
#  'CDISC ADAS-Cog - Commands: Fist': 'NCIT:C100210',
#  'CDISC ADAS-Cog - Commands: Ceiling': 'NCIT:C100211',
#  'CDISC ADAS-Cog - Commands: Pencil': 'NCIT:C100212',
#  'CDISC ADAS-Cog - Commands: Watch': 'NCIT:C100213',
#  'CDISC ADAS-Cog - Commands: Shoulder': 'NCIT:C100214',
#  'CDISC ADAS-Cog - Delayed Word Recall Summary Score': 'NCIT:C100215',
#  'CDISC ADAS-Cog - Delayed Word Recall: Word 1': 'NCIT:C100216',
#  'CDISC ADAS-Cog - Delayed Word Recall: Word 2': 'NCIT:C100217',
#  'CDISC ADAS-Cog - Delayed Word Recall: Word 3': 'NCIT:C100218',
#  'CDISC ADAS-Cog - Delayed Word Recall: Word 4': 'NCIT:C100219',
#  'Fluorouracil/Razoxane/Semustine': 'NCIT:C10022',
#  'CDISC ADAS-Cog - Delayed Word Recall: Word 5': 'NCIT:C100220',
#  'CDISC ADAS-Cog - Delayed Word Recall: Word 6': 'NCIT:C100221',
#  'CDISC ADAS-Cog - Delayed Word Recall: Word 7': 'NCIT:C100222',
#  'CDISC ADAS-Cog - Delayed Word Recall: Word 8': 'NCIT:C100223',
#  'CDISC ADAS-Cog - Delayed Word Recall: Word 9': 'NCIT:C100224',
#  'CDISC ADAS-Cog - Delayed Word Recall: Word 10': 'NCIT:C100225',
#  'CDISC ADAS-Cog - Constructional Praxis Summary Score': 'NCIT:C100226',
#  'CDISC ADAS-Cog - Constructional Praxis: Circle': 'NCIT:C100227',
#  'CDISC ADAS-Cog - Constructional Praxis: 2 Rectangles': 'NCIT:C100228',
#  'CDISC ADAS-Cog - Constructional Praxis: Diamond': 'NCIT:C100229',
#  'Doxorubicin/Mitomycin/Tegafur Regimen': 'NCIT:C10023',
#  'CDISC ADAS-Cog - Constructional Praxis: Cube': 'NCIT:C100230',
#  'CDISC ADAS-Cog - Attempt to Draw': 'NCIT:C100231',
#  'CDISC ADAS-Cog - Ideational Praxis Summary Score': 'NCIT:C100232',
#  'CDISC ADAS-Cog - Ideational Praxis: Fold': 'NCIT:C100233',
#  'CDISC ADAS-Cog - Ideational Praxis: Insert': 'NCIT:C100234',
#  'CDISC ADAS-Cog - Ideational Praxis: Seal': 'NCIT:C100235',
#  'CDISC ADAS-Cog - Ideational Praxis: Address': 'NCIT:C100236',
#  'CDISC ADAS-Cog - Ideational Praxis: Stamp': 'NCIT:C100237',
#  'CDISC ADAS-Cog - Orientation Summary Score': 'NCIT:C100238',
#  'CDISC ADAS-Cog - Orientation: Full Name': 'NCIT:C100239',
#  'Asparaginase/Methotrexate Regimen': 'NCIT:C10024',
#  'CDISC ADAS-Cog - Orientation: Month': 'NCIT:C100240',
#  'CDISC ADAS-Cog - Orientation: Date': 'NCIT:C100241',
#  'CDISC ADAS-Cog - Orientation: Year': 'NCIT:C100242',
#  'CDISC ADAS-Cog - Orientation: Day of Week': 'NCIT:C100243',
#  'CDISC ADAS-Cog - Orientation: Season': 'NCIT:C100244',
#  'CDISC ADAS-Cog - Orientation: Place': 'NCIT:C100245',
#  'CDISC ADAS-Cog - Orientation: Time': 'NCIT:C100246',
#  'CDISC ADAS-Cog - Word Recognition Summary Score': 'NCIT:C100247',
#  'CDISC ADAS-Cog - Word Recognition Trial 1 Summary Score': 'NCIT:C100248',
#  'CDISC ADAS-Cog - Word Recognition Trial 2 Summary Score': 'NCIT:C100249',
#  'Asparaginase/Cytarabine/Doxorubicin/Prednisone/Vincristine': 'NCIT:C10025',
#  'CDISC ADAS-Cog - Word Recognition Trial 3 Summary Score': 'NCIT:C100250',
#  'CDISC ADAS-Cog - Word Recognition: Word 1': 'NCIT:C100251',
#  'CDISC ADAS-Cog - Word Recognition: Word 2': 'NCIT:C100252',
#  'CDISC ADAS-Cog - Word Recognition: Word 3': 'NCIT:C100253',
#  'CDISC ADAS-Cog - Word Recognition: Word 4': 'NCIT:C100254',
#  'CDISC ADAS-Cog - Word Recognition: Word 5': 'NCIT:C100255',
#  'CDISC ADAS-Cog - Word Recognition: Word 6': 'NCIT:C100256',
#  'CDISC ADAS-Cog - Word Recognition: Word 7': 'NCIT:C100257',
#  'CDISC ADAS-Cog - Word Recognition: Word 8': 'NCIT:C100258',
#  'CDISC ADAS-Cog - Word Recognition: Word 9': 'NCIT:C100259',
#  'Chlorambucil/Prednisone/Vinblastine/Vincristine': 'NCIT:C10026',
#  'CDISC ADAS-Cog - Word Recognition: Word 10': 'NCIT:C100260',
#  'CDISC ADAS-Cog - Word Recognition: Word 11': 'NCIT:C100261',
#  'CDISC ADAS-Cog - Word Recognition: Word 12': 'NCIT:C100262',
#  'CDISC ADAS-Cog - Word Recognition: Word 13': 'NCIT:C100263',
#  'CDISC ADAS-Cog - Word Recognition: Word 14': 'NCIT:C100264',
#  'CDISC ADAS-Cog - Word Recognition: Word 15': 'NCIT:C100265',
#  'CDISC ADAS-Cog - Word Recognition: Word 16': 'NCIT:C100266',
#  'CDISC ADAS-Cog - Word Recognition: Word 17': 'NCIT:C100267',
#  'CDISC ADAS-Cog - Word Recognition: Word 18': 'NCIT:C100268',
#  'CDISC ADAS-Cog - Word Recognition: Word 19': 'NCIT:C100269',
#  'Fluorouracil/Mitomycin': 'NCIT:C10027',
#  'CDISC ADAS-Cog - Word Recognition: Word 20': 'NCIT:C100270',
#  'CDISC ADAS-Cog - Word Recognition: Word 21': 'NCIT:C100271',
#  'CDISC ADAS-Cog - Word Recognition: Word 22': 'NCIT:C100272',
#  'CDISC ADAS-Cog - Word Recognition: Word 23': 'NCIT:C100273',
#  'CDISC ADAS-Cog - Word Recognition: Word 24': 'NCIT:C100274',
#  'CDISC ADAS-Cog - Remembering Test Instructions': 'NCIT:C100275',
#  'CDISC ADAS-Cog - Spoken Language Ability': 'NCIT:C100276',
#  'CDISC ADAS-Cog - Word Difficulty in Spontaneous Speech': 'NCIT:C100277',
#  'CDISC ADAS-Cog - Comprehension': 'NCIT:C100278',
#  'CDISC ADAS-Cog - Concentration/Distractibility': 'NCIT:C100279',
#  'MCBP Regimen': 'NCIT:C10028',
#  'CDISC ADAS-Cog - Number Cancellation Summary Score': 'NCIT:C100280',
#  'CDISC ADAS-Cog - Number Cancellation: Correct': 'NCIT:C100281',
#  'CDISC ADAS-Cog - Number Cancellation: Errors': 'NCIT:C100282',
#  'CDISC ADAS-Cog - Number Cancellation: Remind': 'NCIT:C100283',
#  'CDISC ADAS-Cog - Executive Function Maze Summary Score': 'NCIT:C100284',
#  'CDISC ADAS-Cog - Executive Function Maze: Errors': 'NCIT:C100285',
#  'CDISC ADAS-Cog - Executive Function Maze: Time': 'NCIT:C100286',
#  'BPI - Marital Status': 'NCIT:C100287',
#  'BPI - Education': 'NCIT:C100288',
#  'BPI - Professional Degree': 'NCIT:C100289',
#  'Doxorubicin/Lomustine/Mechlorethamine': 'NCIT:C10029',
#  'BPI - Current Occupation': 'NCIT:C100290',
#  "BPI - Spouse's Occupation": 'NCIT:C100291',
#  'BPI - Current Job Status': 'NCIT:C100292',
#  'BPI - How Long Since Diagnosis': 'NCIT:C100293',
#  'BPI - Pain Due to Present Disease': 'NCIT:C100294',
#  'BPI - Pain as a Symptom': 'NCIT:C100295',
#  'BPI - Surgery in Past Month': 'NCIT:C100296',
#  'BPI - Kind of Surgery in Past Month': 'NCIT:C100297',
#  'BPI - Pain Other than Everyday Kinds': 'NCIT:C100298',
#  'BPI - Pain Medications in the Last 7 Days': 'NCIT:C100299',
#  'Ansamycin Antineoplastic Antibiotic': 'NCIT:C1003',
#  'Doxorubicin/Semustine Regimen': 'NCIT:C10030',
#  'BPI - Pain Requires Medication Daily': 'NCIT:C100300',
#  'BPI - Areas of Pain': 'NCIT:C100301',
#  'BPI - Area Hurts Most': 'NCIT:C100302',
#  'BPI - Pain at its Worst in Last Week': 'NCIT:C100303',
#  'BPI - Pain at its Least in Last Week': 'NCIT:C100304',
#  'BPI - Pain on the Average': 'NCIT:C100305',
#  'BPI - Pain Right Now': 'NCIT:C100306',
#  'BPI - Things that Make Pain Feel Better': 'NCIT:C100307',
#  'BPI - Things that Make your Pain Worse': 'NCIT:C100308',
#  'BPI - Treatments Receiving for Pain': 'NCIT:C100309',
#  'Dactinomycin/Doxorubicin/Methotrexate/Vincristine Regimen': 'NCIT:C10031',
#  'BPI - Relief Pain Treatments Provided': 'NCIT:C100310',
#  'BPI - Hours before Pain Returns': 'NCIT:C100311',
#  'BPI - Pain Due to Effects of Treatment': 'NCIT:C100312',
#  'BPI - Pain Due to Primary Disease': 'NCIT:C100313',
#  'BPI - Pain Due to Unrelated Medical Condition': 'NCIT:C100314',
#  'BPI - Describe Unrelated Medical Condition': 'NCIT:C100315',
#  'BPI - Aching': 'NCIT:C100316',
#  'BPI - Throbbing': 'NCIT:C100317',
#  'BPI - Shooting': 'NCIT:C100318',
#  'BPI - Stabbing': 'NCIT:C100319',
#  'Cyclophosphamide/Prednisolone/Teniposide': 'NCIT:C10032',
#  'BPI - Gnawing': 'NCIT:C100320',
#  'BPI - Sharp': 'NCIT:C100321',
#  'BPI - Tender': 'NCIT:C100322',
#  'BPI - Burning': 'NCIT:C100323',
#  'BPI - Exhausting': 'NCIT:C100324',
#  'BPI - Tiring': 'NCIT:C100325',
#  'BPI - Penetrating': 'NCIT:C100326',
#  'BPI - Nagging': 'NCIT:C100327',
#  'BPI - Numb': 'NCIT:C100328',
#  'BPI - Miserable': 'NCIT:C100329',
#  'Fluorouracil/Melphalan': 'NCIT:C10033',
#  'BPI - Unbearable': 'NCIT:C100330',
#  'BPI - Pain Interfered with General Activity': 'NCIT:C100331',
#  'BPI - Pain Interfered with Mood': 'NCIT:C100332',
#  'BPI - Pain Interfered with Walking Ability': 'NCIT:C100333',
#  'BPI - Pain Interfered with Normal Work': 'NCIT:C100334',
#  'BPI - Pain Interfered with Relations': 'NCIT:C100335',
#  'BPI - Pain Interfered with Sleep': 'NCIT:C100336',
#  'BPI - Pain Interfered with Enjoyment of Life': 'NCIT:C100337',
#  'BPI - Prefer to Take Pain Medicine': 'NCIT:C100338',
#  'BPI - Take my Pain Medicine': 'NCIT:C100339',
#  'Doxorubicin/Fluorouracil/Melphalan': 'NCIT:C10034',
#  'BPI - Need Stronger Type of Pain Medication': 'NCIT:C100340',
#  'BPI - Need more Pain Medication than Prescribed': 'NCIT:C100341',
#  'BPI - Concerned with Too Much Pain Medication Use': 'NCIT:C100342',
#  'BPI - Why Concerned with Too Much Pain Medication Use': 'NCIT:C100343',
#  'BPI - Problems with Side Effects Pain Medication': 'NCIT:C100344',
#  'BPI - What Side Effects from Pain Medication': 'NCIT:C100345',
#  'BPI - Need Further Information about Pain Medication': 'NCIT:C100346',
#  'BPI - Warm Compresses to Relieve Pain': 'NCIT:C100347',
#  'BPI - Cold Compresses to Relieve Pain': 'NCIT:C100348',
#  'BPI - Relaxation Techniques Relieve Pain': 'NCIT:C100349',
#  'Mercaptopurine/Methotrexate/Vincristine': 'NCIT:C10035',
#  'BPI - Distraction to Relieve Pain': 'NCIT:C100350',
#  'BPI - Biofeedback to Relieve Pain': 'NCIT:C100351',
#  'BPI - Hypnosis to Relieve Pain': 'NCIT:C100352',
#  'BPI - Other Methods to Relieve Pain': 'NCIT:C100353',
#  'BPI - Specified Other Method to Relieve Pain': 'NCIT:C100354',
#  'BPI - Medications not Prescribed Taken for Pain': 'NCIT:C100355',
#  'BPI Short Form - Pain Other Than Everyday Kinds': 'NCIT:C100356',
#  'BPI Short Form - Areas of Pain': 'NCIT:C100357',
#  'BPI Short Form - Area that Hurts Most': 'NCIT:C100358',
#  'BPI Short Form - Pain at its Worst in Last 24 Hours': 'NCIT:C100359',
#  'ROAP Regimen': 'NCIT:C10036',
#  'BPI Short Form - Pain at its Least in Last 24 Hours': 'NCIT:C100360',
#  'BPI Short Form - Pain on the Average': 'NCIT:C100361',
#  'BPI Short Form - Pain Right Now': 'NCIT:C100362',
#  'BPI Short Form - Treatments or Medications Receiving for Pain': 'NCIT:C100363',
#  'BPI Short Form - Relief from Pain Treatments Provided': 'NCIT:C100364',
#  'BPI Short Form - Pain Interfered with General Activity': 'NCIT:C100365',
#  'BPI Short Form - Pain Interfered with Mood': 'NCIT:C100366',
#  'BPI Short Form - Pain Interfered with Walking Ability': 'NCIT:C100367',
#  'BPI Short Form - Pain Interfered with Normal Work': 'NCIT:C100368',
#  'BPI Short Form - Pain Interfered with Relations': 'NCIT:C100369',
#  'Dacarbazine/Zorubicin': 'NCIT:C10037',
#  'BPI Short Form - Pain Interfered with Sleep': 'NCIT:C100370',
#  'BPI Short Form - Pain Interfered with Enjoyment of Life': 'NCIT:C100371',
#  'BPRS-A - Somatic Concern': 'NCIT:C100372',
#  'BPRS-A - Anxiety': 'NCIT:C100373',
#  'BPRS-A - Emotional Withdrawal': 'NCIT:C100374',
#  'BPRS-A - Conceptual Disorganization': 'NCIT:C100375',
#  'BPRS-A - Guilt Feelings': 'NCIT:C100376',
#  'BPRS-A - Tension': 'NCIT:C100377',
#  'BPRS-A - Mannerisms and Posturing': 'NCIT:C100378',
#  'BPRS-A - Grandiosity': 'NCIT:C100379',
#  'Methotrexate/Prednisone/Thioguanine/Vincristine': 'NCIT:C10038',
#  'BPRS-A - Depressive Mood': 'NCIT:C100380',
#  'BPRS-A - Hostility': 'NCIT:C100381',
#  'BPRS-A - Suspiciousness': 'NCIT:C100382',
#  'BPRS-A - Hallucinatory Behavior': 'NCIT:C100383',
#  'BPRS-A - Motor Retardation': 'NCIT:C100384',
#  'BPRS-A - Uncooperativeness': 'NCIT:C100385',
#  'BPRS-A - Unusual Thought Content': 'NCIT:C100386',
#  'BPRS-A - Blunted Affect': 'NCIT:C100387',
#  'BPRS-A - Excitement': 'NCIT:C100388',
#  'BPRS-A - Disorientation': 'NCIT:C100389',
#  'Amifostine/Cisplatin/Monoclonal Antibody R24': 'NCIT:C10039',
#  'Mean QRS Duration Ventricular Paced': 'NCIT:C100390',
#  'Corrected QT Interval': 'NCIT:C100391',
#  'EQ-5D-3L - Mobility': 'NCIT:C100392',
#  'EQ-5D-3L - Self-Care': 'NCIT:C100393',
#  'EQ-5D-3L - Usual Activities': 'NCIT:C100394',
#  'EQ-5D-3L - Pain or Discomfort': 'NCIT:C100395',
#  'EQ-5D-3L - Anxiety or Depression': 'NCIT:C100396',
#  'EQ-5D-3L - EQ VAS Score': 'NCIT:C100397',
#  'HAMD-17 - Depressed Mood': 'NCIT:C100398',
#  'HAMD-17 - Feelings of Guilt': 'NCIT:C100399',
#  'Antineoplaston A10': 'NCIT:C1004',
#  'Fluorouracil/Leucovorin Calcium/Sargramostim': 'NCIT:C10040',
#  'HAMD-17 - Suicide': 'NCIT:C100400',
#  'HAMD-17 - Insomnia - Early Night': 'NCIT:C100401',
#  'HAMD-17 - Insomnia - Middle Night': 'NCIT:C100402',
#  'HAMD-17 - Insomnia - Early Morning': 'NCIT:C100403',
#  'HAMD-17 - Work and Activities': 'NCIT:C100404',
#  'HAMD-17 - Retardation': 'NCIT:C100405',
#  'HAMD-17 - Agitation': 'NCIT:C100406',
#  'HAMD-17 - Psychic Anxiety': 'NCIT:C100407',
#  'HAMD-17 - Somatic Anxiety': 'NCIT:C100408',
#  'HAMD-17 - Somatic Symptoms Gastrointestinal': 'NCIT:C100409',
#  'Bleomycin/Cisplatin/Cyclophosphamide/Doxorubicin/Fluorouracil/Vincristine': 'NCIT:C10041',
#  'HAMD-17 - General Somatic Symptoms': 'NCIT:C100410',
#  'HAMD-17 - Genital Symptoms': 'NCIT:C100411',
#  'HAMD-17 - Hypochondriasis': 'NCIT:C100412',
#  'HAMD-17 - Loss of Weight According to Patient': 'NCIT:C100413',
#  'HAMD-17 - Loss of Weight According to Weekly Measurements': 'NCIT:C100414',
#  'HAMD-17 - Insight': 'NCIT:C100415',
#  'HAMD-17 - Total Score': 'NCIT:C100416',
#  'KPS Scale - Karnofsky Performance Status': 'NCIT:C100417',
#  'Sideroblast Measurement': 'NCIT:C100418',
#  'Ring Sideroblast Measurement': 'NCIT:C100419',
#  'Bleomycin/Cyclophosphamide/Cytarabine/Doxorubicin/Etoposide/Methotrexate/Prednisone/Sargramostim/Vincristine': 'NCIT:C10042',
#  'Tricyclic Antidepressant Measurement': 'NCIT:C100420',
#  'Ecarin Clotting Time Measurement': 'NCIT:C100422',
#  'CH50 Measurement': 'NCIT:C100423',
#  'Platelet Hematocrit Measurement': 'NCIT:C100424',
#  'HDL Cholesterol to LDL Cholesterol Ratio Measurement': 'NCIT:C100425',
#  'Apolipoprotein C2 Measurement': 'NCIT:C100427',
#  'Apolipoprotein J Measurement': 'NCIT:C100428',
#  'Alpha-1 Acid Glycoprotein Measurement': 'NCIT:C100429',
#  'Cisplatin/Cyclophosphamide/Fluorouracil/Vincristine': 'NCIT:C10043',
#  'Alanine Aminopeptidase Measurement': 'NCIT:C100430',
#  'Chemokine Receptor CXCR3 Measurement': 'NCIT:C100431',
#  'Ceruloplasmin Measurement': 'NCIT:C100432',
#  'Kidney Injury Molecule-1 Measurement': 'NCIT:C100433',
#  'Non-Prostatic Acid Phosphatase Measurement': 'NCIT:C100434',
#  'Prealbumin Measurement': 'NCIT:C100435',
#  'Protein S Measurement': 'NCIT:C100436',
#  'Retinol Binding Protein Measurement': 'NCIT:C100437',
#  'Soluble Transferrin Receptor Measurement': 'NCIT:C100438',
#  'Iohexol Clearance': 'NCIT:C100439',
#  'Altretamine/Cyclophosphamide/Methotrexate': 'NCIT:C10044',
#  'EDTA Clearance': 'NCIT:C100440',
#  'Diethylene Triamine Pentaacetic Acid Clearance': 'NCIT:C100441',
#  'Immature Neutrophils to Leukocytes Ratio Measurement': 'NCIT:C100442',
#  'Immature Lymphocytes to Leukocytes Ratio Measurement': 'NCIT:C100443',
#  'Immature Lymphocytes Measurement': 'NCIT:C100444',
#  'Immature Granulocytes to Leukocytes Ratio Measurement': 'NCIT:C100445',
#  'Proerythroblast Measurement': 'NCIT:C100446',
#  'Homeostatic Model Assessment of Insulin Resistance': 'NCIT:C100447',
#  'Free Glycerol Measurement': 'NCIT:C100448',
#  'Glomerular Filtration Rate from Beta-Trace Protein Adjusted for BSA Measurement': 'NCIT:C100449',
#  'Cisplatin/Mitoguazone/Vinblastine': 'NCIT:C10045',
#  'Glomerular Filtration Rate from B-2 Microglobulin Adjusted for BSA Measurement': 'NCIT:C100450',
#  'Ova and Parasite Measurement': 'NCIT:C100452',
#  'Plasmodium Measurement': 'NCIT:C100453',
#  'Liver Kidney Microsomal Type 1 IgG Antibody Measurement': 'NCIT:C100454',
#  'Liver Kidney Microsomal Type 1 IgM Antibody Measurement': 'NCIT:C100455',
#  'Liver Kidney Microsomal Type 1 IgA Antibody Measurement': 'NCIT:C100456',
#  'Ribonucleoprotein Antibody Measurement': 'NCIT:C100457',
#  'Scl-70 Antibody Measurement': 'NCIT:C100458',
#  'Jo-1 Antibody Measurement': 'NCIT:C100459',
#  'Ampligen/Interleukin-2': 'NCIT:C10046',
#  'HLA-B27 Antigen Measurement': 'NCIT:C100460',
#  'Alpha-1 Microglobulin Measurement': 'NCIT:C100461',
#  'Alpha-1 Microglobulin to Creatinine Ratio Measurement': 'NCIT:C100462',
#  'DNase-B Antibody Measurement': 'NCIT:C100463',
#  'Chlamydia trachomatis IgA Antibody Measurement': 'NCIT:C100464',
#  'Chlamydia trachomatis IgM Antibody Measurement': 'NCIT:C100465',
#  'Chlamydia trachomatis IgG Antibody Measurement': 'NCIT:C100466',
#  'Pepsinogen I Measurement': 'NCIT:C100467',
#  'Pepsinogen II Measurement': 'NCIT:C100468',
#  'Pepsinogen A Measurement': 'NCIT:C100469',
#  'Cisplatin/Cytarabine/Etoposide/Sargramostim': 'NCIT:C10047',
#  'Pepsinogen C Measurement': 'NCIT:C100470',
#  'Activated Protein C Resistance Measurement': 'NCIT:C100471',
#  'Beta Carotene Measurement': 'NCIT:C100472',
#  'MDS-UPDRS - Cognitive Impairment': 'NCIT:C100473',
#  'MDS-UPDRS - Hallucinations and Psychosis': 'NCIT:C100474',
#  'MDS-UPDRS - Depressed Mood': 'NCIT:C100475',
#  'MDS-UPDRS - Anxious Mood': 'NCIT:C100476',
#  'MDS-UPDRS - Apathy': 'NCIT:C100477',
#  'MDS-UPDRS - Features of Dopamine Dysregulation Syndrome': 'NCIT:C100478',
#  'MDS-UPDRS - Sleep Problems': 'NCIT:C100479',
#  'Cyclophosphamide/Dexrazoxane/Doxorubicin/Vincristine': 'NCIT:C10048',
#  'MDS-UPDRS - Daytime Sleepiness': 'NCIT:C100480',
#  'MDS-UPDRS - Pain and Other Sensations': 'NCIT:C100481',
#  'MDS-UPDRS - Urinary Problems': 'NCIT:C100482',
#  'MDS-UPDRS - Constipation Problems': 'NCIT:C100483',
#  'MDS-UPDRS - Lightheadedness on Standing': 'NCIT:C100484',
#  'MDS-UPDRS - Fatigue': 'NCIT:C100485',
#  'MDS-UPDRS - Speech': 'NCIT:C100486',
#  'MDS-UPDRS - Saliva and Drooling': 'NCIT:C100487',
#  'MDS-UPDRS - Chewing and Swallowing': 'NCIT:C100488',
#  'MDS-UPDRS - Eating Tasks': 'NCIT:C100489',
#  'Carmustine/Cyclophosphamide/Thiotepa/Vincristine': 'NCIT:C10049',
#  'MDS-UPDRS - Dressing': 'NCIT:C100490',
#  'MDS-UPDRS - Hygiene': 'NCIT:C100491',
#  'MDS-UPDRS - Handwriting': 'NCIT:C100492',
#  'MDS-UPDRS - Doing Hobbies and Other Activities': 'NCIT:C100493',
#  'MDS-UPDRS - Turning in Bed': 'NCIT:C100494',
#  'MDS-UPDRS - Tremor': 'NCIT:C100495',
#  'MDS-UPDRS - Walking and Balance': 'NCIT:C100496',
#  'MDS-UPDRS - Freezing': 'NCIT:C100497',
#  "MDS-UPDRS - Medication for Parkinson's Disease": 'NCIT:C100498',
#  'MDS-UPDRS - Clinical State on Medication': 'NCIT:C100499',
#  'Arsenic Trioxide': 'NCIT:C1005',
#  'Asparaginase/Idarubicin/Prednisone/Vincristine': 'NCIT:C10050',
#  'MDS-UPDRS - Taking Levodopa': 'NCIT:C100500',
#  'MDS-UPDRS - Minutes Since Levodopa Dose': 'NCIT:C100501',
#  'MDS-UPDRS - Speech Problems': 'NCIT:C100502',
#  'MDS-UPDRS - Facial Expression': 'NCIT:C100503',
#  'MDS-UPDRS - Rigidity Neck': 'NCIT:C100504',
#  'MDS-UPDRS - Rigidity Right Upper Extremity': 'NCIT:C100505',
#  'MDS-UPDRS - Rigidity Left Upper Extremity': 'NCIT:C100506',
#  'MDS-UPDRS - Rigidity Right Lower Extremity': 'NCIT:C100507',
#  'MDS-UPDRS - Rigidity Left Lower Extremity': 'NCIT:C100508',
#  'MDS-UPDRS - Right Finger Tapping': 'NCIT:C100509',
#  'Carmustine/Triazinate': 'NCIT:C10051',
#  'MDS-UPDRS - Left Finger Tapping': 'NCIT:C100510',
#  'MDS-UPDRS - Right Hand Movements': 'NCIT:C100511',
#  'MDS-UPDRS - Left Hand Movements': 'NCIT:C100512',
#  'MDS-UPDRS - Pronanation-Supination Movement of Right Hand': 'NCIT:C100513',
#  'MDS-UPDRS - Pronanation-Supination Movement of Left Hand': 'NCIT:C100514',
#  'MDS-UPDRS - Right Toe Tapping': 'NCIT:C100515',
#  'MDS-UPDRS - Left Toe Tapping': 'NCIT:C100516',
#  'MDS-UPDRS - Right Leg Agility': 'NCIT:C100517',
#  'MDS-UPDRS - Left Leg Agility': 'NCIT:C100518',
#  'MDS-UPDRS - Arising from Chair': 'NCIT:C100519',
#  'Asparaginase/Cytarabine/Idarubicin': 'NCIT:C10052',
#  'MDS-UPDRS - Gait': 'NCIT:C100520',
#  'MDS-UPDRS - Freezing of Gait': 'NCIT:C100521',
#  'MDS-UPDRS - Postural Stability': 'NCIT:C100522',
#  'MDS-UPDRS - Posture': 'NCIT:C100523',
#  'MDS-UPDRS - Body Bradykinesia': 'NCIT:C100524',
#  'MDS-UPDRS - Postural Tremor of Right Hand': 'NCIT:C100525',
#  'MDS-UPDRS - Kinetic Tremor of Left Hand': 'NCIT:C100526',
#  'MDS-UPDRS - Rest Tremor Amplitude Right Upper Extremity': 'NCIT:C100527',
#  'MDS-UPDRS - Rest Tremor Amplitude Left Upper Extremity': 'NCIT:C100528',
#  'MDS-UPDRS - Rest Tremor Amplitude Right Lower Extremity': 'NCIT:C100529',
#  'CAFP Regimen': 'NCIT:C10053',
#  'MDS-UPDRS - Rest Tremor Amplitude Left Lower Extremity': 'NCIT:C100530',
#  'MDS-UPDRS - Rest Tremor Amplitude Lip or Jaw': 'NCIT:C100531',
#  'MDS-UPDRS - Consistency of Rest Tremor': 'NCIT:C100532',
#  'MDS-UPDRS - Dyskinesias During Exam': 'NCIT:C100533',
#  'MDS-UPDRS - Movements Interfere with Ratings': 'NCIT:C100534',
#  'MDS-UPDRS - Hoehn and Yahr Stage': 'NCIT:C100535',
#  'MDS-UPDRS - Time Spent with Dyskinesias': 'NCIT:C100536',
#  'MDS-UPDRS - Functional Impact of Dyskinesias': 'NCIT:C100537',
#  'MDS-UPDRS - Time Spent in the Off State': 'NCIT:C100538',
#  'MDS-UPDRS - Functional Impact of Fluctuations': 'NCIT:C100539',
#  'Asparaginase/Cytarabine/Daunorubicin': 'NCIT:C10054',
#  'MDS-UPDRS - Complexity of Motor Fluctuations': 'NCIT:C100540',
#  'MDS-UPDRS - Painful Off-state Dystonia': 'NCIT:C100541',
#  'MMSE - Question 1': 'NCIT:C100542',
#  'MMSE - What Is the Year': 'NCIT:C100543',
#  'MMSE - What Is the Season': 'NCIT:C100544',
#  'MMSE - What Is the Date': 'NCIT:C100545',
#  'MMSE - What Is the Day of Week': 'NCIT:C100546',
#  'MMSE - What Is the Month of Year': 'NCIT:C100547',
#  'MMSE - Question 2': 'NCIT:C100548',
#  'MMSE - What Is the State': 'NCIT:C100549',
#  'Cyclophosphamide/Doxorubicin/Folic Acid/Methotrexate': 'NCIT:C10055',
#  'MMSE - What Is the County': 'NCIT:C100550',
#  'MMSE - What Is the City or Town': 'NCIT:C100551',
#  'MMSE - What Is the Building': 'NCIT:C100552',
#  'MMSE - What Is the Floor': 'NCIT:C100553',
#  'MMSE - Question 3': 'NCIT:C100554',
#  'MMSE - Repeat Word 1': 'NCIT:C100555',
#  'MMSE - Repeat Word 2': 'NCIT:C100556',
#  'MMSE - Repeat Word 3': 'NCIT:C100557',
#  'MMSE - Question 4': 'NCIT:C100558',
#  'MMSE - What is 100 Take Away 7': 'NCIT:C100559',
#  'Cyclophosphamide/Cytarabine/Daunorubicin/Dexamethasone/Thioguanine/Vincristine': 'NCIT:C10056',
#  'MMSE - Keep Subtracting 7 Step 2': 'NCIT:C100560',
#  'MMSE - Keep Subtracting 7 Step 3': 'NCIT:C100561',
#  'MMSE - Keep Subtracting 7 Step 4': 'NCIT:C100562',
#  'MMSE - Keep Subtracting 7 Step 5': 'NCIT:C100563',
#  'MMSE - Question 4C': 'NCIT:C100564',
#  'MMSE - Spell Backward Letter 1': 'NCIT:C100565',
#  'MMSE - Spell Backward Letter 2': 'NCIT:C100566',
#  'MMSE - Spell Backward Letter 3': 'NCIT:C100567',
#  'MMSE - Spell Backward Letter 4': 'NCIT:C100568',
#  'MMSE - Spell Backward Letter 5': 'NCIT:C100569',
#  'Fenretinide/Tamoxifen': 'NCIT:C10057',
#  'MMSE - Attention and Calculation Subtotal': 'NCIT:C100570',
#  'MMSE - Question 5': 'NCIT:C100571',
#  'MMSE - Recall Word 1': 'NCIT:C100572',
#  'MMSE - Recall Word 2': 'NCIT:C100573',
#  'MMSE - Recall Word 3': 'NCIT:C100574',
#  'MMSE - Question 6': 'NCIT:C100575',
#  'MMSE - Naming Object 1': 'NCIT:C100576',
#  'MMSE - Naming Object 2': 'NCIT:C100577',
#  'MMSE - Repeat What I Say': 'NCIT:C100578',
#  'MMSE - Question 8': 'NCIT:C100579',
#  'Altretamine/Cisplatin/Cyclophosphamide/Fluorouracil Regimen': 'NCIT:C10058',
#  'MMSE - Take in Right Hand': 'NCIT:C100580',
#  'MMSE - Fold in Half': 'NCIT:C100581',
#  'MMSE - Put on Floor or Table': 'NCIT:C100582',
#  'MMSE - Read This and Do What It Says': 'NCIT:C100583',
#  'MMSE - Write a Sentence': 'NCIT:C100584',
#  'MMSE - Copy This Design': 'NCIT:C100585',
#  'MMSE - Total Score': 'NCIT:C100586',
#  'MNSI - Legs and/or Feet Numb': 'NCIT:C100587',
#  'MNSI - Burning Pain Legs/Feet': 'NCIT:C100588',
#  'MNSI - Feet Too Sensitive to Touch': 'NCIT:C100589',
#  'Dactinomycin/Tumor Necrosis Factor': 'NCIT:C10059',
#  'MNSI - Muscle Cramps Legs/Feet': 'NCIT:C100590',
#  'MNSI - Prickling Feelings Legs/Feet': 'NCIT:C100591',
#  'MNSI - Hurt When Bed Covers Touch Skin': 'NCIT:C100592',
#  'MNSI - Able to Tell Hot from Cold Water': 'NCIT:C100593',
#  'MNSI - Open Sore on Foot': 'NCIT:C100594',
#  'MNSI - Doctor Says Diabetic Neuropathy': 'NCIT:C100595',
#  'MNSI - Feel Weak All Over Most Times': 'NCIT:C100596',
#  'MNSI - Symptoms Worse at Night': 'NCIT:C100597',
#  'MNSI - Legs Hurt When Walking': 'NCIT:C100598',
#  'MNSI - Able to Sense Feet When Walking': 'NCIT:C100599',
#  'Ammonium Trichlorotellurate': 'NCIT:C1006',
#  'Cisplatin/Doxorubicin/Fluorouracil/Leucovorin Calcium': 'NCIT:C10060',
#  'MNSI - Skin So Dry That Feet Crack Open': 'NCIT:C100600',
#  'MNSI - Ever Had Amputation': 'NCIT:C100601',
#  'MNSI - History Total': 'NCIT:C100602',
#  'MNSI - Right Foot Appears Normal': 'NCIT:C100603',
#  'MNSI - Right Foot Deformities': 'NCIT:C100604',
#  'MNSI - Right Foot Infection': 'NCIT:C100605',
#  'MNSI - Right Foot Fissure': 'NCIT:C100606',
#  'MNSI - Right Foot Other Abnormal Specify': 'NCIT:C100607',
#  'MNSI - Left Foot Appears Normal': 'NCIT:C100608',
#  'MNSI - Left Foot Deformities': 'NCIT:C100609',
#  'Altretamine/Lomustine/Methotrexate': 'NCIT:C10061',
#  'MNSI - Left Foot Infection': 'NCIT:C100610',
#  'MNSI - Left Foot Fissure': 'NCIT:C100611',
#  'MNSI - Left Foot Other Abnormal Specify': 'NCIT:C100612',
#  'MNSI - Right Foot Ulceration': 'NCIT:C100613',
#  'MNSI - Left Foot Ulceration': 'NCIT:C100614',
#  'MNSI - Right Ankle Reflexes': 'NCIT:C100615',
#  'MNSI - Left Ankle Reflexes': 'NCIT:C100616',
#  'MNSI - Right Foot Vibration Great Toe': 'NCIT:C100617',
#  'MNSI - Left Foot Vibration Great Toe': 'NCIT:C100618',
#  'MNSI - Right Foot Monofilament': 'NCIT:C100619',
#  'Cyclophosphamide/Doxorubicin/Melphalan/Methotrexate/Vincristine': 'NCIT:C10062',
#  'MNSI - Left Foot Monofilament': 'NCIT:C100620',
#  'MNSI - Physical Assessment Total Score': 'NCIT:C100621',
#  'NPI - Have Beliefs That You Know are Not True': 'NCIT:C100622',
#  'NPI - He/She is in Danger': 'NCIT:C100623',
#  'NPI - Others are Stealing From Him/Her': 'NCIT:C100624',
#  'NPI - His/Her Spouse is Having an Affair': 'NCIT:C100625',
#  'NPI - Unwelcome Guests are Living in His/Her House': 'NCIT:C100626',
#  'NPI - His/Her Spouse or Others Are Not Who They Claim To Be': 'NCIT:C100627',
#  'NPI - His/Her House Is Not His/Her Home': 'NCIT:C100628',
#  'NPI - Family Members Plan to Abandon Him/Her': 'NCIT:C100629',
#  'Cyclophosphamide/Doxorubicin/Ethinyl Estradiol/Fluorouracil/Leucovorin Calcium': 'NCIT:C10063',
#  'NPI - Television or Magazine Figures Are Actually Present In the Home': 'NCIT:C100630',
#  "NPI - Any Other Unusual Things That I Haven't Asked About": 'NCIT:C100631',
#  'NPI - Hallucinations Such as Seeing False Visions or Hearing False Voices': 'NCIT:C100632',
#  'NPI - Describe Hearing Voices or Act as if He/She Hears Voices': 'NCIT:C100633',
#  'NPI - Talk to People Who Are Not There': 'NCIT:C100634',
#  'NPI - Describe Seeing Things Not Seen by Others': 'NCIT:C100635',
#  'NPI - Report Smelling Odors Not Smelled by Others': 'NCIT:C100636',
#  'NPI - Describe Feeling Things on His/Her Skin': 'NCIT:C100637',
#  'NPI - Describe Tastes That Are Without Any Known Cause': 'NCIT:C100638',
#  'NPI - Describe Any Other Unusual Sensory Experiences': 'NCIT:C100639',
#  'Cyclophosphamide/Fluorouracil/Leucovorin Calcium/Mitoxantrone': 'NCIT:C10064',
#  'NPI - Periods When He/She Refuses to Cooperate': 'NCIT:C100640',
#  'NPI - Get Upset with Those Trying to Care for Him/Her': 'NCIT:C100641',
#  'NPI - Stubborn': 'NCIT:C100642',
#  'NPI - Uncooperative': 'NCIT:C100643',
#  'NPI - Any Other Behaviors That Make Him/Her Hard to Handle': 'NCIT:C100644',
#  'NPI - Shout or Curse Angrily': 'NCIT:C100645',
#  'NPI - Slam doors, Kick Furniture, Throw Things': 'NCIT:C100646',
#  'NPI - Attempt to Hurt or Hit Others': 'NCIT:C100647',
#  'NPI - Any Other Aggressive or Agitated Behaviors': 'NCIT:C100648',
#  'NPI - Seem Sad or Depressed': 'NCIT:C100649',
#  'Floxuridine/Leucovorin Calcium': 'NCIT:C10065',
#  'NPI - Periods of Tearfulness or Sobbing': 'NCIT:C100650',
#  'NPI - Say, or Act as if He/She is Sad or in Low Spirits': 'NCIT:C100651',
#  'NPI - Put Him/Herself Down or Say That He/She Feels Like a Failure': 'NCIT:C100652',
#  'NPI - Say That He/She is a Bad Person': 'NCIT:C100653',
#  'NPI - Seem Very Discouraged': 'NCIT:C100654',
#  'NPI - Say He/She is a Burden to the Family': 'NCIT:C100655',
#  'NPI - Express a Wish for Death': 'NCIT:C100656',
#  'NPI - Show Any Other Signs of Depression or Sadness': 'NCIT:C100657',
#  'NPI - Very Nervous, Worried, or Frightened for No Apparent Reason': 'NCIT:C100658',
#  'NPI - Say That He/She is Worried About Planned Events': 'NCIT:C100659',
#  'Fluorouracil/Interferon Beta': 'NCIT:C10066',
#  'NPI - Periods of Feeling Shaky, Unable to Relax, or Feeling Excessively Tense': 'NCIT:C100660',
#  'NPI - Periods of Shortness of Breath, Gasping, or Sighing for No Apparent Reason': 'NCIT:C100661',
#  'NPI - Complain of Butterflies, Racing or Pounding Heart': 'NCIT:C100662',
#  'NPI - Avoid Certain Places or Situations That Make Him/Her More Nervous': 'NCIT:C100663',
#  'NPI - Become Nervous and Upset When Separated From You': 'NCIT:C100664',
#  'NPI - Show Any Other Signs of Anxiety': 'NCIT:C100665',
#  'NPI - Seem Too Cheerful or Too Happy for No Reason': 'NCIT:C100666',
#  'NPI - Appear to Feel Good or to Be Too Happy': 'NCIT:C100667',
#  'NPI - Fine Humor and Laugh at Things That Others Do Not Find Funny': 'NCIT:C100668',
#  'NPI - Seem to Have a Childish Sense of Humor': 'NCIT:C100669',
#  'Cyclophosphamide/Doxorubicin/Fluorouracil/Streptozocin': 'NCIT:C10067',
#  'NPI - Tell Jokes or Make Remarks That are Not Funny to Others': 'NCIT:C100670',
#  'NPI - Play Childish Pranks': 'NCIT:C100671',
#  'NPI - Talk Big or Claim to Have More Abilities or Wealth Than is True': 'NCIT:C100672',
#  'NPI - Show Any Other Signs of Feeling Too Good or Being Too Happy': 'NCIT:C100673',
#  'NPI - Lost Interest in the World Around Him/Her': 'NCIT:C100674',
#  'NPI - Seem Less Spontaneous and Less Active Than Usual': 'NCIT:C100675',
#  'NPI - Less Likely Initiate to Initiate a Conversation': 'NCIT:C100676',
#  'NPI - Less Affectionate or Lacking in Emotions': 'NCIT:C100677',
#  'NPI - Contribute Less to Household Chores': 'NCIT:C100678',
#  'NPI - Less Interested in the Activities and Plans of Others': 'NCIT:C100679',
#  'Octreotide/Tamoxifen': 'NCIT:C10068',
#  'NPI - Lost Interest in Friends and Family Members': 'NCIT:C100680',
#  'NPI - Less Enthusiastic About His/Her Usual Interests': 'NCIT:C100681',
#  "NPI - Show Any Other Signs That He/She Doesn't Care About Doing New Things": 'NCIT:C100682',
#  'NPI - Seem to Act Impulsively Without Thinking': 'NCIT:C100683',
#  'NPI - Act Impulsively without Appearing to Consider the Consequences': 'NCIT:C100684',
#  'NPI - Talk to Total Strangers as if He/She Knew Them': 'NCIT:C100685',
#  'NPI - Say Things to People that are Insensitive': 'NCIT:C100686',
#  'NPI - Say Crude Things or Make Sexual Remarks': 'NCIT:C100687',
#  'NPI - Talk Openly About Very Personal or Private Matters': 'NCIT:C100688',
#  'NPI - Take Liberties or Touch or Hug Others': 'NCIT:C100689',
#  'Melphalan/Methylprednisolone/Vincristine': 'NCIT:C10069',
#  'NPI - Show Any Other Signs of Loss of Control of His/Her Impulses': 'NCIT:C100690',
#  'NPI - Get Irritated and Easily Disturbed': 'NCIT:C100691',
#  "NPI - Bad Temper, Flying 'Off the Handle' Easily Over Little Things": 'NCIT:C100692',
#  'NPI - Rapidly Change Moods From One to Another': 'NCIT:C100693',
#  'NPI - Sudden Flares of Anger': 'NCIT:C100694',
#  'NPI - Impatient, Having Trouble Coping with Delays': 'NCIT:C100695',
#  'NPI - Cranky and Irritable': 'NCIT:C100696',
#  'NPI - Argumentative and Difficult to Get Along With': 'NCIT:C100697',
#  'NPI - Show Any Other Signs of Irritability': 'NCIT:C100698',
#  'NPI - Pace, Do Things Over and Over, Repeatedly Pick at Things': 'NCIT:C100699',
#  'Azapicyl': 'NCIT:C1007',
#  'FACVP Regimen': 'NCIT:C10070',
#  'NPI - Pace Around the House Without Apparent Purpose': 'NCIT:C100700',
#  'NPI - Rummage Around Opening and Unpacking Drawers or Closets': 'NCIT:C100701',
#  'NPI - Repeatedly Put On and Take Off Clothing': 'NCIT:C100702',
#  "NPI - Repetitive Activities or 'Habits'": 'NCIT:C100703',
#  'NPI - Engage in Repetitive Activities': 'NCIT:C100704',
#  'NPI - Fidget Excessively, Seem Unable to Sit Still': 'NCIT:C100705',
#  'NPI - Do Any Other Activities Over and Over': 'NCIT:C100706',
#  'NPI - Difficulty Sleeping': 'NCIT:C100707',
#  'NPI - Difficulty Falling Asleep': 'NCIT:C100708',
#  'NPI - Get Up During the Night': 'NCIT:C100709',
#  'Cyclophosphamide/Mercaptopurine/Prednisone/Vincristine Regimen': 'NCIT:C10071',
#  'NPI - Wander, Pace or Get Involved in Inappropriate Activities at Night': 'NCIT:C100710',
#  'NPI - Awaken You During the Night': 'NCIT:C100711',
#  'NPI - Wake Up at Night, Dress, and Plan to Go Out': 'NCIT:C100712',
#  'NPI - Awaken Too Early in Morning': 'NCIT:C100713',
#  'NPI - Sleep Excessively During the Day': 'NCIT:C100714',
#  'NPI - Any Other Nighttime Behaviors That Bother You': 'NCIT:C100715',
#  'NPI - Change in Appetite, Weight, or Eating Habits': 'NCIT:C100716',
#  'NPI - Loss of Appetite': 'NCIT:C100717',
#  'NPI - Increase in Appetite': 'NCIT:C100718',
#  'NPI - Loss of Weight': 'NCIT:C100719',
#  'Cyclophosphamide/Dexrazoxane/Doxorubicin/Fluorouracil': 'NCIT:C10072',
#  'NPI - Gained Weight': 'NCIT:C100720',
#  'NPI - Change in Eating Behavior': 'NCIT:C100721',
#  'NPI - Change in Kind of Food He/She Likes': 'NCIT:C100722',
#  'NPI - Developed Eating Behaviors Such as Eating Exactly the Same Types of Food': 'NCIT:C100723',
#  'NPI - Any Other Changes in Appetite or Eating': 'NCIT:C100724',
#  'PDQUALIF - Lightheadedness': 'NCIT:C100725',
#  'PDQUALIF - Imbalance': 'NCIT:C100726',
#  'PDQUALIF - Swallowing Difficulty': 'NCIT:C100727',
#  'PDQUALIF - Communication': 'NCIT:C100728',
#  'PDQUALIF - Nocturia': 'NCIT:C100729',
#  'Doxorubicin/Fluorouracil/Mitomycin/Triazinate': 'NCIT:C10073',
#  'PDQUALIF - Sexual Ability': 'NCIT:C100730',
#  'PDQUALIF - Neuropathy in Hands or Feet': 'NCIT:C100731',
#  'PDQUALIF - Bladder Control Difficulty': 'NCIT:C100732',
#  'PDQUALIF - Constipation': 'NCIT:C100733',
#  'PDQUALIF - Trouble with Sleep Initiation or Waking Early': 'NCIT:C100734',
#  'PDQUALIF - Trouble with Sleep Maintenance': 'NCIT:C100735',
#  'PDQUALIF - Positive Outlook Difficult': 'NCIT:C100736',
#  'PDQUALIF - Burden to Others': 'NCIT:C100737',
#  'PDQUALIF - Social Life Affected': 'NCIT:C100738',
#  'PDQUALIF - Worry about Future': 'NCIT:C100739',
#  'Asparaginase/Cytarabine/Sargramostim': 'NCIT:C10074',
#  'PDQUALIF - Difficulty in Asking for Help': 'NCIT:C100740',
#  'PDQUALIF - Important to Maintain Independence': 'NCIT:C100741',
#  'PDQUALIF - Difficulty in Adjusting to Change': 'NCIT:C100742',
#  'PDQUALIF - Social Life Not Affected': 'NCIT:C100743',
#  'PDQUALIF - Travel Important': 'NCIT:C100744',
#  'PDQUALIF - Family Relationship Affected': 'NCIT:C100745',
#  'PDQUALIF - Social Isolation': 'NCIT:C100746',
#  'PDQUALIF - Self Concept Change': 'NCIT:C100747',
#  'PDQUALIF - Sexual Desirability': 'NCIT:C100748',
#  'PDQUALIF - Independent Hygiene in Past 7 Days': 'NCIT:C100749',
#  'Etoposide/Methotrexate': 'NCIT:C10075',
#  'PDQUALIF - Independent Food Preparation in Past 7 Days': 'NCIT:C100750',
#  'PDQUALIF - Problem with Communication in the Past 7 Days': 'NCIT:C100751',
#  'PDQUALIF - Fatigue in Past 7 Days': 'NCIT:C100752',
#  'PDQUALIF - House Work in Past 7 Days': 'NCIT:C100753',
#  'PDQUALIF - Sleep with Partner in Past 7 Days': 'NCIT:C100754',
#  'PDQUALIF - Driving in Past 7 Days': 'NCIT:C100755',
#  'PDQUALIF - Financial Strain in Past 7 Days': 'NCIT:C100756',
#  "PDQUALIF - Parkinson's Symptoms": 'NCIT:C100757',
#  'Lateral Decubitus Position': 'NCIT:C100758',
#  'Brief Pain Inventory Questionnaire': 'NCIT:C100759',
#  'Doxorubicin/Fluorouracil/Triazinate': 'NCIT:C10076',
#  'Brief Pain Inventory Short Form Questionnaire': 'NCIT:C100760',
#  'Brief Psychiatric Rating Scale A Clinical Classification': 'NCIT:C100761',
#  "Alzheimer's Disease Assessment Scale-Cognitive CDISC Version Questionnaire": 'NCIT:C100762',
#  'Clinical Global Impression Original Version Questionnaire': 'NCIT:C100763',
#  'Current Opioid Misuse Measure Questionnaire': 'NCIT:C100764',
#  'Columbia-Suicide Severity Rating Scale Baseline Questionnaire': 'NCIT:C100765',
#  'Faces Pain Scale Revised Questionnaire': 'NCIT:C100766',
#  'Hamilton Depression Rating Scale 17 Item Clinical Classification': 'NCIT:C100767',
#  'Karnofsky Performance Status Scale Clinical Classification': 'NCIT:C100768',
#  "Movement Disorder Society Unified Parkinson's Disease Rating Scale Questionnaire": 'NCIT:C100769',
#  'Interferon Gamma/Levamisole': 'NCIT:C10077',
#  'Michigan Neuropathy Screening Instrument Questionnaire': 'NCIT:C100771',
#  'Neuropsychiatric Inventory Questionnaire': 'NCIT:C100772',
#  "Parkinson's Disease Quality of Life Scale Questionnaire": 'NCIT:C100773',
#  'Roland Morris Disability Questionnaire': 'NCIT:C100774',
#  'Short Form 36 Health Survey Standard, US Version 1.0 Questionnaire': 'NCIT:C100775',
#  'Short-Form McGill Pain Questionnaire-2': 'NCIT:C100776',
#  'Screener and Opioid Assessment for Patients with Pain Revised Questionnaire': 'NCIT:C100777',
#  "Unified Parkinson's Disease Rating Scale Clinical Classification": 'NCIT:C100778',
#  'Work Productivity and Activity Impairment Specific Health Problems Version 2.0 Questionnaire': 'NCIT:C100779',
#  'Cyclophosphamide/Doxorubicin/Fluorouracil/Sargramostim': 'NCIT:C10078',
#  'RDQ - Stay at Home': 'NCIT:C100780',
#  'RDQ - Change Position Frequently': 'NCIT:C100781',
#  'RDQ - Walk More Slowly': 'NCIT:C100782',
#  'RDQ - Not Do Any Usual House Jobs': 'NCIT:C100783',
#  'RDQ - Use Handrail to Get Upstairs': 'NCIT:C100784',
#  'RDQ - Lie Down to Rest More Often': 'NCIT:C100785',
#  'RDQ - Hold on to Get Out of a Chair': 'NCIT:C100786',
#  'RDQ - Get Other People to Do Things': 'NCIT:C100787',
#  'RDQ - Get Dressed More Slowly': 'NCIT:C100788',
#  'RDQ - Only Stand for Short Periods': 'NCIT:C100789',
#  'Bleomycin/Procarbazine/Vinblastine': 'NCIT:C10079',
#  'RDQ - Try Not to Bend or Kneel': 'NCIT:C100790',
#  'RDQ - Difficult to Get Out of a Chair': 'NCIT:C100791',
#  'RDQ - Painful Almost All the Time': 'NCIT:C100792',
#  'RDQ - Difficult to Turn Over in Bed': 'NCIT:C100793',
#  'RDQ - Appetite is Not Very Good': 'NCIT:C100794',
#  'RDQ - Trouble Putting on Socks or Stockings': 'NCIT:C100795',
#  'RDQ - Only Walk Short Distances': 'NCIT:C100796',
#  'RDQ - Sleep Less Well': 'NCIT:C100797',
#  'RDQ - Get Dressed With Help': 'NCIT:C100798',
#  'RDQ - Sit Down Most of the Day': 'NCIT:C100799',
#  'Azaribine': 'NCIT:C1008',
#  'Cytarabine/Doxorubicin/Mercaptopurine/Prednisone/Vincristine': 'NCIT:C10080',
#  'RDQ - Avoid Heavy Jobs': 'NCIT:C100800',
#  'RDQ - More Irritable With People': 'NCIT:C100801',
#  'RDQ - Go Upstairs More Slowly': 'NCIT:C100802',
#  'RDQ - Stay in Bed': 'NCIT:C100803',
#  'RDQ - Total Derived Score': 'NCIT:C100804',
#  'Biological Grandchild': 'NCIT:C100805',
#  'Biological Grandparent': 'NCIT:C100806',
#  'Third Degree Relative': 'NCIT:C100808',
#  'Biological Sibling': 'NCIT:C100809',
#  'Altretamine/Etoposide/Procarbazine': 'NCIT:C10081',
#  'Organ Donor': 'NCIT:C100810',
#  'Pregnancy Partner': 'NCIT:C100811',
#  'Sexual Partner': 'NCIT:C100812',
#  'SF36 v1.0 Standard - In General You Say Your Health Is': 'NCIT:C100813',
#  'SF36 v1.0 Standard - Comp Year Ago Rate Gen Health Now': 'NCIT:C100814',
#  'SF36 v1.0 Standard - Limit Vigorous Activities': 'NCIT:C100815',
#  'SF36 v1.0 Standard - Limit Moderate Activities': 'NCIT:C100816',
#  'SF36 v1.0 Standard - Limit Lifting or Carrying': 'NCIT:C100817',
#  'SF36 v1.0 Standard - Limit Climbing Several Flights': 'NCIT:C100818',
#  'SF36 v1.0 Standard - Limit Climbing One Flight Stairs': 'NCIT:C100819',
#  'Bleomycin/Cisplatin/Doxorubicin': 'NCIT:C10082',
#  'SF36 v1.0 Standard - Limit Bending/Kneeling/Stooping': 'NCIT:C100820',
#  'SF36 v1.0 Standard - Limit Walking More Than a Mile': 'NCIT:C100821',
#  'SF36 v1.0 Standard - Limit Walking Several Blocks': 'NCIT:C100822',
#  'SF36 v1.0 Standard - Limit Walking One Block': 'NCIT:C100823',
#  'SF36 v1.0 Standard - Limit Bathing or Dressing Yourself': 'NCIT:C100824',
#  'SF36 v1.0 Standard - Physical: Cut Down Time on Work': 'NCIT:C100825',
#  'SF36 v1.0 Standard - Physical: Accomplished Less': 'NCIT:C100826',
#  'SF36 v1.0 Standard - Physical: Limited Kind of Work': 'NCIT:C100827',
#  'SF36 v1.0 Standard - Physical: Difficulty Perform Work': 'NCIT:C100828',
#  'SF36 v1.0 Standard - Emotional: Cut Down Time on Work': 'NCIT:C100829',
#  'FUVAC Regimen': 'NCIT:C10083',
#  'SF36 v1.0 Standard - Emotional: Accomplished Less': 'NCIT:C100830',
#  'SF36 v1.0 Standard - Emotional: Did Work Less Carefully': 'NCIT:C100831',
#  'SF36 v1.0 Standard - Extent Phys/Emotional Interfered': 'NCIT:C100832',
#  'SF36 v1.0 Standard - How Much Bodily Pain Have You Had': 'NCIT:C100833',
#  'SF36 v1.0 Standard - Pain Interfere With Normal Work': 'NCIT:C100834',
#  'SF36 v1.0 Standard - Did You Feel Full of Pep': 'NCIT:C100835',
#  'SF36 v1.0 Standard - Have You Been Very Nervous Person': 'NCIT:C100836',
#  'SF36 v1.0 Standard - Felt Down Nothing Cheer You Up': 'NCIT:C100837',
#  'SF36 v1.0 Standard - Have You Felt Calm and Peaceful': 'NCIT:C100838',
#  'SF36 v1.0 Standard - Did You Have a Lot of Energy': 'NCIT:C100839',
#  'Cytarabine/Doxorubicin/Mercaptopurine': 'NCIT:C10084',
#  'SF36 v1.0 Standard - You Felt Downhearted and Blue': 'NCIT:C100840',
#  'SF36 v1.0 Standard - Did You Feel Worn Out': 'NCIT:C100841',
#  'SF36 v1.0 Standard - Have You Been Happy Person': 'NCIT:C100842',
#  'SF36 v1.0 Standard - Did You Feel Tired': 'NCIT:C100843',
#  'SF36 v1.0 Standard - Time Phys/Emotional Interfered': 'NCIT:C100844',
#  'SF36 v1.0 Standard - Get Sick Little Easier Than Other': 'NCIT:C100845',
#  'SF36 v1.0 Standard - I Am as Healthy as Anybody I Know': 'NCIT:C100846',
#  'SF36 v1.0 Standard - I Expect My Health to Get Worse': 'NCIT:C100847',
#  'SF36 v1.0 Standard - My Health is Excellent': 'NCIT:C100848',
#  'SF-MPQ-2 - Throbbing Pain': 'NCIT:C100849',
#  'Altretamine/Cyclophosphamide/Doxorubicin': 'NCIT:C10085',
#  'SF-MPQ-2 - Shooting Pain': 'NCIT:C100850',
#  'SF-MPQ-2 - Stabbing Pain': 'NCIT:C100851',
#  'SF-MPQ-2 - Sharp Pain': 'NCIT:C100852',
#  'SF-MPQ-2 - Cramping Pain': 'NCIT:C100853',
#  'SF-MPQ-2 - Gnawing Pain': 'NCIT:C100854',
#  'SF-MPQ-2 - Hot-burning Pain': 'NCIT:C100855',
#  'SF-MPQ-2 - Aching Pain': 'NCIT:C100856',
#  'SF-MPQ-2 - Heavy Pain': 'NCIT:C100857',
#  'SF-MPQ-2 - Tender': 'NCIT:C100858',
#  'SF-MPQ-2 - Splitting Pain': 'NCIT:C100859',
#  'Cytarabine/Prednisone/Thioguanine/Vincristine': 'NCIT:C10086',
#  'SF-MPQ-2 - Tiring-Exhausting': 'NCIT:C100860',
#  'SF-MPQ-2 - Sickening': 'NCIT:C100861',
#  'SF-MPQ-2 - Fearful': 'NCIT:C100862',
#  'SF-MPQ-2 - Punishing-Cruel': 'NCIT:C100863',
#  'SF-MPQ-2 - Electric-Shock Pain': 'NCIT:C100864',
#  'SF-MPQ-2 - Cold-Freezing Pain': 'NCIT:C100865',
#  'SF-MPQ-2 - Piercing': 'NCIT:C100866',
#  'SF-MPQ-2 - Pain Caused by Light Touch': 'NCIT:C100867',
#  'SF-MPQ-2 - Itching': 'NCIT:C100868',
#  'SF-MPQ-2 - Numbness': 'NCIT:C100869',
#  'Dacarbazine/Dactinomycin/Vincristine': 'NCIT:C10087',
#  'SOAPP-R - How Often Mood Swings': 'NCIT:C100870',
#  'SOAPP-R - Need Higher Doses of Medication': 'NCIT:C100871',
#  'SOAPP-R - Felt Impatient With Doctors': 'NCIT:C100872',
#  'SOAPP-R - Felt That Things Are Overwhelming': 'NCIT:C100873',
#  'SOAPP-R - How Often Tension at Home': 'NCIT:C100874',
#  'SOAPP-R - How Often Counted Pain Pills': 'NCIT:C100875',
#  'SOAPP-R - Concerned People Will Judge You': 'NCIT:C100876',
#  'SOAPP-R - How Often Feel Bored': 'NCIT:C100877',
#  'SOAPP-R - How Often Taken More Pain Medication': 'NCIT:C100878',
#  'SOAPP-R - Worried About Being Left Alone': 'NCIT:C100879',
#  'Cytarabine/Zorubicin': 'NCIT:C10088',
#  'SOAPP-R - Felt Craving for Medication': 'NCIT:C100880',
#  'SOAPP-R - Others Expressed Concern Over Medication Use': 'NCIT:C100881',
#  'SOAPP-R - How Often Friends Had Problem': 'NCIT:C100882',
#  'SOAPP-R - Others Told You Bad Temper': 'NCIT:C100883',
#  'SOAPP-R - Felt Consumed to Get Pain Medication': 'NCIT:C100884',
#  'SOAPP-R - Run Out of Pain Medication Early': 'NCIT:C100885',
#  'SOAPP-R - Others Kept You From what You Deserve': 'NCIT:C100886',
#  'SOAPP-R - Legal Problems or Arrested': 'NCIT:C100887',
#  'SOAPP-R - Attended AA or NA Meeting': 'NCIT:C100888',
#  'SOAPP-R - Argument Where Someone Got Hurt': 'NCIT:C100889',
#  'Cisplatin/Cyclophosphamide/Cytarabine/Hydroxyurea/Lomustine/Methylprednisolone/Procarbazine/Vincristine': 'NCIT:C10089',
#  'SOAPP-R - How Often Sexually Abused': 'NCIT:C100890',
#  'SOAPP-R - Others Suggested Drug or Alcohol Problem': 'NCIT:C100891',
#  'SOAPP-R - How Often Borrowed Pain Medication': 'NCIT:C100892',
#  'SOAPP-R - Treated for Alcohol or Drug Problem': 'NCIT:C100893',
#  'SOAPP-R - Any Additional Information': 'NCIT:C100894',
#  'SOAPP-R - Score': 'NCIT:C100895',
#  'Prostatic Fluid': 'NCIT:C100896',
#  'Thousand Copies per Milliliter': 'NCIT:C100897',
#  'Million Copies per Milliliter': 'NCIT:C100898',
#  'Diopter': 'NCIT:C100899',
#  'Ethyleneimine': 'NCIT:C1009',
#  'Doxorubicin/Methotrexate/Vinblastine': 'NCIT:C10090',
#  'Copies per Milliliter': 'NCIT:C100900',
#  'UPDRS - Mentation, Behavior and Mood: Intellectual Impairment': 'NCIT:C100901',
#  'UPDRS - Mentation, Behavior and Mood: Thought Disorder': 'NCIT:C100902',
#  'UPDRS - Mentation, Behavior and Mood: Depression': 'NCIT:C100903',
#  'UPDRS - Mentation, Behavior and Mood: Motivation/Initiative': 'NCIT:C100904',
#  ...}

# %%
# Get the name for NCIT:C62554 (poly (ADP-Ribose) Polymerase Inhibitor) AKA PARP Inhibitor
parp = id_to_name['NCIT:C62554']
parp
# Out:
# 'Poly (ADP-Ribose) Polymerase Inhibitor'

# %%
# Find all ancestors (superclasses) of Parp Inhibitor. 
# Networkx ancestors correlates to 'subterms' & networkx descendants correlates to 'superclasses'
# --> A bit counter-intuitive but now we know

# Within our graph let's get all subterms of Parp Inhibitor (NCIT:C62554)
# --> where Node id: is the corresponding id for the name (i.e. see below)
nx.ancestors(graph, 'NCIT:C62554')
for node in nx.ancestors(graph, 'NCIT:C62554'):
    print('Node id: {:15s} --- maps onto --> \t{}'.format(node, id_to_name[node]))
# Out:
# Node id: NCIT:C140553    --- maps onto --> 	Simmiparib
# Node id: NCIT:C71721     --- maps onto --> 	Olaparib
# Node id: NCIT:C131178    --- maps onto --> 	Rucaparib Camsylate
# Node id: NCIT:C95733     --- maps onto --> 	Talazoparib
# Node id: NCIT:C156260    --- maps onto --> 	Temozolomide/Veliparib Regimen
# Node id: NCIT:C137800    --- maps onto --> 	Rucaparib
# Node id: NCIT:C176969    --- maps onto --> 	PARP/Microtubule Polymerization Inhibitor AMXI-5001
# Node id: NCIT:C126274    --- maps onto --> 	Fluzoparib
# Node id: NCIT:C167278    --- maps onto --> 	PARP Inhibitor NMS-03305293
# Node id: NCIT:C160812    --- maps onto --> 	Rucaparib Regimen
# Node id: NCIT:C160120    --- maps onto --> 	Talazoparib Regimen
# Node id: NCIT:C78186     --- maps onto --> 	Rucaparib Phosphate
# Node id: NCIT:C62526     --- maps onto --> 	Iniparib
# Node id: NCIT:C168601    --- maps onto --> 	Senaparib
# Node id: NCIT:C160097    --- maps onto --> 	Olaparib Regimen
# Node id: NCIT:C160807    --- maps onto --> 	Niraparib Regimen
# Node id: NCIT:C178310    --- maps onto --> 	PARP 1/2 Inhibitor SC10914
# Node id: NCIT:C95201     --- maps onto --> 	PARP Inhibitor AZD2461
# Node id: NCIT:C84880     --- maps onto --> 	PARP Inhibitor CEP-9722
# Node id: NCIT:C80059     --- maps onto --> 	Niraparib
# Node id: NCIT:C169778    --- maps onto --> 	Amelparib
# Node id: NCIT:C96795     --- maps onto --> 	PARP-1/2 Inhibitor ABT-767
# Node id: NCIT:C172134    --- maps onto --> 	Bevacizumab/Olaparib Regimen
# Node id: NCIT:C91387     --- maps onto --> 	PARP Inhibitor E7016
# Node id: NCIT:C102746    --- maps onto --> 	PARP/Tankyrase Inhibitor 2X-121
# Node id: NCIT:C120553    --- maps onto --> 	Pamiparib
# Node id: NCIT:C64763     --- maps onto --> 	Fermented Wheat Germ Extract
# Node id: NCIT:C152494    --- maps onto --> 	Talazoparib Tosylate
# Node id: NCIT:C176783    --- maps onto --> 	PARP Inhibitor AZD5305
# Node id: NCIT:C174060    --- maps onto --> 	Tankyrase Inhibitor STP1002
# Node id: NCIT:C29105     --- maps onto --> 	Hypoxanthine
# Node id: NCIT:C60768     --- maps onto --> 	Veliparib
# Node id: NCIT:C154560    --- maps onto --> 	PARP 1/2 Inhibitor NOV1401
# Node id: NCIT:C170764    --- maps onto --> 	Atamparib
# Node id: NCIT:C61315     --- maps onto --> 	INO-1001
# Node id: NCIT:C175871    --- maps onto --> 	Venadaparib
# Node id: NCIT:C133238    --- maps onto --> 	Niraparib Tosylate Monohydrate

# %%
nx.ancestors(graph, 'NCIT:C62554')
for node in nx.ancestors(graph, 'NCIT:C62554'):
    print('Node id: {:25s} --- maps onto --> \t{}'.format(id_to_name[node], id_to_name[node]))
# Out:
# Node id: Simmiparib                --- maps onto --> 	Simmiparib
# Node id: Olaparib                  --- maps onto --> 	Olaparib
# Node id: Rucaparib Camsylate       --- maps onto --> 	Rucaparib Camsylate
# Node id: Talazoparib               --- maps onto --> 	Talazoparib
# Node id: Temozolomide/Veliparib Regimen --- maps onto --> 	Temozolomide/Veliparib Regimen
# Node id: Rucaparib                 --- maps onto --> 	Rucaparib
# Node id: PARP/Microtubule Polymerization Inhibitor AMXI-5001 --- maps onto --> 	PARP/Microtubule Polymerization Inhibitor AMXI-5001
# Node id: Fluzoparib                --- maps onto --> 	Fluzoparib
# Node id: PARP Inhibitor NMS-03305293 --- maps onto --> 	PARP Inhibitor NMS-03305293
# Node id: Rucaparib Regimen         --- maps onto --> 	Rucaparib Regimen
# Node id: Talazoparib Regimen       --- maps onto --> 	Talazoparib Regimen
# Node id: Rucaparib Phosphate       --- maps onto --> 	Rucaparib Phosphate
# Node id: Iniparib                  --- maps onto --> 	Iniparib
# Node id: Senaparib                 --- maps onto --> 	Senaparib
# Node id: Olaparib Regimen          --- maps onto --> 	Olaparib Regimen
# Node id: Niraparib Regimen         --- maps onto --> 	Niraparib Regimen
# Node id: PARP 1/2 Inhibitor SC10914 --- maps onto --> 	PARP 1/2 Inhibitor SC10914
# Node id: PARP Inhibitor AZD2461    --- maps onto --> 	PARP Inhibitor AZD2461
# Node id: PARP Inhibitor CEP-9722   --- maps onto --> 	PARP Inhibitor CEP-9722
# Node id: Niraparib                 --- maps onto --> 	Niraparib
# Node id: Amelparib                 --- maps onto --> 	Amelparib
# Node id: PARP-1/2 Inhibitor ABT-767 --- maps onto --> 	PARP-1/2 Inhibitor ABT-767
# Node id: Bevacizumab/Olaparib Regimen --- maps onto --> 	Bevacizumab/Olaparib Regimen
# Node id: PARP Inhibitor E7016      --- maps onto --> 	PARP Inhibitor E7016
# Node id: PARP/Tankyrase Inhibitor 2X-121 --- maps onto --> 	PARP/Tankyrase Inhibitor 2X-121
# Node id: Pamiparib                 --- maps onto --> 	Pamiparib
# Node id: Fermented Wheat Germ Extract --- maps onto --> 	Fermented Wheat Germ Extract
# Node id: Talazoparib Tosylate      --- maps onto --> 	Talazoparib Tosylate
# Node id: PARP Inhibitor AZD5305    --- maps onto --> 	PARP Inhibitor AZD5305
# Node id: Tankyrase Inhibitor STP1002 --- maps onto --> 	Tankyrase Inhibitor STP1002
# Node id: Hypoxanthine              --- maps onto --> 	Hypoxanthine
# Node id: Veliparib                 --- maps onto --> 	Veliparib
# Node id: PARP 1/2 Inhibitor NOV1401 --- maps onto --> 	PARP 1/2 Inhibitor NOV1401
# Node id: Atamparib                 --- maps onto --> 	Atamparib
# Node id: INO-1001                  --- maps onto --> 	INO-1001
# Node id: Venadaparib               --- maps onto --> 	Venadaparib
# Node id: Niraparib Tosylate Monohydrate --- maps onto --> 	Niraparib Tosylate Monohydrate

# %%
# Find immediate parent concepts to Poly (ADP-Ribose) Polymerase Inhibitor (Code C62554)
# graph.out_edges() vs graph.in_edges() 
node = name_to_id['Poly (ADP-Ribose) Polymerase Inhibitor']
for child, parent, key in graph.out_edges(node, keys=True):
    print(f'• {id_to_name[child]} ⟶ {key} ⟶  {id_to_name[parent]}')
# Out:
# • Poly (ADP-Ribose) Polymerase Inhibitor ⟶ is_a ⟶  Targeted Therapy Agent
# • Poly (ADP-Ribose) Polymerase Inhibitor ⟶ is_a ⟶  Enzyme Inhibitor
# • Poly (ADP-Ribose) Polymerase Inhibitor ⟶ NCIT:R146 ⟶  Poly [ADP-Ribose] Polymerase 1

# %%
# All Drugs within the NCI Thesaurus that are defined to exhibit the 'drug class' of Parp Inhibitor 
# AKA all direct children of the concept NCIT_C62554 (Parp Inhibitor)

node = name_to_id['Poly (ADP-Ribose) Polymerase Inhibitor']
for parent, child, key in graph.in_edges(node, keys=True):
    print(f'• {id_to_name[child]} ⟵  {key} ⟵ {id_to_name[parent]}')
# Out:
# • Poly (ADP-Ribose) Polymerase Inhibitor ⟵  is_a ⟵ PARP/Tankyrase Inhibitor 2X-121
# • Poly (ADP-Ribose) Polymerase Inhibitor ⟵  is_a ⟵ Pamiparib
# • Poly (ADP-Ribose) Polymerase Inhibitor ⟵  is_a ⟵ Fluzoparib
# • Poly (ADP-Ribose) Polymerase Inhibitor ⟵  is_a ⟵ Rucaparib Camsylate
# • Poly (ADP-Ribose) Polymerase Inhibitor ⟵  is_a ⟵ Niraparib Tosylate Monohydrate
# • Poly (ADP-Ribose) Polymerase Inhibitor ⟵  is_a ⟵ Rucaparib
# • Poly (ADP-Ribose) Polymerase Inhibitor ⟵  is_a ⟵ Simmiparib
# • Poly (ADP-Ribose) Polymerase Inhibitor ⟵  is_a ⟵ Talazoparib Tosylate
# • Poly (ADP-Ribose) Polymerase Inhibitor ⟵  is_a ⟵ PARP 1/2 Inhibitor NOV1401
# • Poly (ADP-Ribose) Polymerase Inhibitor ⟵  is_a ⟵ PARP Inhibitor NMS-03305293
# • Poly (ADP-Ribose) Polymerase Inhibitor ⟵  is_a ⟵ Senaparib
# • Poly (ADP-Ribose) Polymerase Inhibitor ⟵  is_a ⟵ Amelparib
# • Poly (ADP-Ribose) Polymerase Inhibitor ⟵  is_a ⟵ Atamparib
# • Poly (ADP-Ribose) Polymerase Inhibitor ⟵  is_a ⟵ Tankyrase Inhibitor STP1002
# • Poly (ADP-Ribose) Polymerase Inhibitor ⟵  is_a ⟵ Venadaparib
# • Poly (ADP-Ribose) Polymerase Inhibitor ⟵  is_a ⟵ PARP Inhibitor AZD5305
# • Poly (ADP-Ribose) Polymerase Inhibitor ⟵  is_a ⟵ PARP/Microtubule Polymerization Inhibitor AMXI-5001
# • Poly (ADP-Ribose) Polymerase Inhibitor ⟵  is_a ⟵ PARP 1/2 Inhibitor SC10914
# • Poly (ADP-Ribose) Polymerase Inhibitor ⟵  is_a ⟵ Hypoxanthine
# • Poly (ADP-Ribose) Polymerase Inhibitor ⟵  is_a ⟵ Veliparib
# • Poly (ADP-Ribose) Polymerase Inhibitor ⟵  is_a ⟵ INO-1001
# • Poly (ADP-Ribose) Polymerase Inhibitor ⟵  is_a ⟵ Iniparib
# • Poly (ADP-Ribose) Polymerase Inhibitor ⟵  is_a ⟵ Fermented Wheat Germ Extract
# • Poly (ADP-Ribose) Polymerase Inhibitor ⟵  is_a ⟵ Olaparib
# • Poly (ADP-Ribose) Polymerase Inhibitor ⟵  is_a ⟵ Rucaparib Phosphate
# • Poly (ADP-Ribose) Polymerase Inhibitor ⟵  is_a ⟵ Niraparib
# • Poly (ADP-Ribose) Polymerase Inhibitor ⟵  is_a ⟵ PARP Inhibitor CEP-9722
# • Poly (ADP-Ribose) Polymerase Inhibitor ⟵  is_a ⟵ PARP Inhibitor E7016
# • Poly (ADP-Ribose) Polymerase Inhibitor ⟵  is_a ⟵ PARP Inhibitor AZD2461
# • Poly (ADP-Ribose) Polymerase Inhibitor ⟵  is_a ⟵ Talazoparib
# • Poly (ADP-Ribose) Polymerase Inhibitor ⟵  is_a ⟵ PARP-1/2 Inhibitor ABT-767

# %%
# Olaparib is a newly FDA approved Parp Inhibitor (Ovarian Cancer)
# --> demonstrate the out_edge of the graph (aka immediate parent is Poly (ADP-Ribose) Polymerase Inhibitor)
node = name_to_id['Olaparib']
for parent, child, key in graph.out_edges(node, keys=True):
    print(f'• {id_to_name[child]} ⟵  {key} ⟵ {id_to_name[parent]}')
# Out:
# • Poly (ADP-Ribose) Polymerase Inhibitor ⟵  is_a ⟵ Olaparib

# %%
# Olaparib is a newly FDA approved Parp Inhibitor (Ovarian Cancer)
# --> demonstrate the contrast of above --> in_edges of the graph illustrates the NCIt semantic relationship NCIT:R123 (where NCIT:R123 == Chemotherapy_Regimen_Has_Component)
# NIH reference for translation --> https://www.nlm.nih.gov/research/umls/sourcereleasedocs/current/NCI/sourcerepresentation.html

node = name_to_id['Olaparib']
for child, parent, key in graph.in_edges(node, keys=True):
    print(f'• {id_to_name[child]} ⟵  {key} ⟵ {id_to_name[parent]}')
# Out:
# • Olaparib Regimen ⟵  NCIT:R123 ⟵ Olaparib
# • Bevacizumab/Olaparib Regimen ⟵  NCIT:R123 ⟵ Olaparib

# %%
# Explore another Parp Inhibitor (in_edges)
node = name_to_id['Talazoparib']
for child, parent, key in graph.in_edges(node, keys=True):
    print(f'• {id_to_name[child]} ⟵  {key} ⟵ {id_to_name[parent]}')
# Out:
# • Talazoparib Regimen ⟵  NCIT:R123 ⟵ Talazoparib

# %%
# Explore another Parp Inhibitor (out_edges)
node = name_to_id['Talazoparib']
for parent, child, key in graph.out_edges(node, keys=True):
    print(f'• {id_to_name[child]} ⟵  {key} ⟵ {id_to_name[parent]}')
# Out:
# • Poly (ADP-Ribose) Polymerase Inhibitor ⟵  is_a ⟵ Talazoparib

# %%
# Pembrolizumab, sold under the brand name Keytruda, is a humanized antibody used in cancer immunotherapy that treats melanoma, lung cancer, head and neck cancer, Hodgkin lymphoma, and stomach cancer.
# Let's explore regimens within NCIt for Pembro. (AKA Keytruda)
# --> Many platinum based chemo regimens 

node = name_to_id['Pembrolizumab']
for parent, child, key in graph.in_edges(node, keys=True):
    print(f'• {id_to_name[child]} ⟵  {key} ⟵ {id_to_name[parent]}')
# Out:
# • Pembrolizumab ⟵  NCIT:R123 ⟵ Carboplatin/Pembrolizumab/Pemetrexed Regimen
# • Pembrolizumab ⟵  NCIT:R123 ⟵ Carboplatin/Paclitaxel/Pembrolizumab Regimen
# • Pembrolizumab ⟵  NCIT:R123 ⟵ Cisplatin/Pembrolizumab/Pemetrexed Regimen
# • Pembrolizumab ⟵  NCIT:R123 ⟵ Pembrolizumab/Pemetrexed Regimen
# • Pembrolizumab ⟵  NCIT:R123 ⟵ Cisplatin/Nab-Paclitaxel/Pembrolizumab Regimen
# • Pembrolizumab ⟵  NCIT:R123 ⟵ Carboplatin/Nab-Paclitaxel/Pembrolizumab Regimen
# • Pembrolizumab ⟵  NCIT:R123 ⟵ Cisplatin/Paclitaxel/Pembrolizumab Regimen
# • Pembrolizumab ⟵  NCIT:R123 ⟵ Pembrolizumab Regimen
# • Pembrolizumab ⟵  NCIT:R123 ⟵ Carboplatin/Fluorouracil/Pembrolizumab Regimen
# • Pembrolizumab ⟵  NCIT:R123 ⟵ Cisplatin/Fluorouracil/Pembrolizumab Regimen
# • Pembrolizumab ⟵  NCIT:R123 ⟵ Axitinib/Pembrolizumab Regimen
# • Pembrolizumab ⟵  NCIT:R123 ⟵ Avelumab/Axitinib Regimen

# %%
# What drug classification via NCI Thesaurus does Pembrolizumab exhibit?
# Anti-PD1 Monoclonal Antibody!
node = name_to_id['Pembrolizumab']
for parent, child, key in graph.out_edges(node, keys=True):
    print(f'• {id_to_name[child]} ⟵  {key} ⟵ {id_to_name[parent]}')
# Out:
# • Anti-PD1 Monoclonal Antibody ⟵  is_a ⟵ Pembrolizumab

# %%
# What other drugs are also Anti-PD1 Monoclonal Antibody via NCI Thesaurus?
# --> Similar to Parp Inhibitors, there are many non-FDA approved (investigational) Anti-PD1 Monoclonal Antibody drugs being developed
# ---> I.e. Anti-PD-1 Monoclonal Antibody MEDI0680, Anti-PD-1/LAG-3 Bispecific Antibody EMB-02 etc
node = name_to_id['Anti-PD1 Monoclonal Antibody']
for parent, child, key in graph.in_edges(node, keys=True):
    print(f'• {id_to_name[child]} ⟵  {key} ⟵ {id_to_name[parent]}')
# Out:
# • Anti-PD1 Monoclonal Antibody ⟵  is_a ⟵ Pembrolizumab
# • Anti-PD1 Monoclonal Antibody ⟵  is_a ⟵ Anti-PD-1 Monoclonal Antibody MEDI0680
# • Anti-PD1 Monoclonal Antibody ⟵  is_a ⟵ Cemiplimab
# • Anti-PD1 Monoclonal Antibody ⟵  is_a ⟵ Spartalizumab
# • Anti-PD1 Monoclonal Antibody ⟵  is_a ⟵ Tislelizumab
# • Anti-PD1 Monoclonal Antibody ⟵  is_a ⟵ Camrelizumab
# • Anti-PD1 Monoclonal Antibody ⟵  is_a ⟵ Dostarlimab
# • Anti-PD1 Monoclonal Antibody ⟵  is_a ⟵ Cetrelimab
# • Anti-PD1 Monoclonal Antibody ⟵  is_a ⟵ Toripalimab
# • Anti-PD1 Monoclonal Antibody ⟵  is_a ⟵ Ezabenlimab
# • Anti-PD1 Monoclonal Antibody ⟵  is_a ⟵ Sintilimab
# • Anti-PD1 Monoclonal Antibody ⟵  is_a ⟵ Balstilimab
# • Anti-PD1 Monoclonal Antibody ⟵  is_a ⟵ Retifanlimab
# • Anti-PD1 Monoclonal Antibody ⟵  is_a ⟵ Anti-PD-1 Monoclonal Antibody Sym021
# • Anti-PD1 Monoclonal Antibody ⟵  is_a ⟵ Prolgolimab
# • Anti-PD1 Monoclonal Antibody ⟵  is_a ⟵ Geptanolimab
# • Anti-PD1 Monoclonal Antibody ⟵  is_a ⟵ Anti-PD-1 Monoclonal Antibody LZM009
# • Anti-PD1 Monoclonal Antibody ⟵  is_a ⟵ Penpulimab
# • Anti-PD1 Monoclonal Antibody ⟵  is_a ⟵ Anti-PD-1 Monoclonal Antibody CS1003
# • Anti-PD1 Monoclonal Antibody ⟵  is_a ⟵ Serplulimab
# • Anti-PD1 Monoclonal Antibody ⟵  is_a ⟵ Pimivalimab
# • Anti-PD1 Monoclonal Antibody ⟵  is_a ⟵ Zimberelimab
# • Anti-PD1 Monoclonal Antibody ⟵  is_a ⟵ Pucotenlimab
# • Anti-PD1 Monoclonal Antibody ⟵  is_a ⟵ Zeluvalimab
# • Anti-PD1 Monoclonal Antibody ⟵  is_a ⟵ Anti-PD-1 Monoclonal Antibody F520
# • Anti-PD1 Monoclonal Antibody ⟵  is_a ⟵ Anti-PD-1 Monoclonal Antibody BAT1306
# • Anti-PD1 Monoclonal Antibody ⟵  is_a ⟵ Finotonlimab
# • Anti-PD1 Monoclonal Antibody ⟵  is_a ⟵ Anti-CTLA-4/Anti-PD-1 Monoclonal Antibody Combination BCD-217
# • Anti-PD1 Monoclonal Antibody ⟵  is_a ⟵ Anti-PD-1 Monoclonal Antibody 609A
# • Anti-PD1 Monoclonal Antibody ⟵  is_a ⟵ Anti-PD-1/Anti-LAG-3 Bispecific Antibody RO7247669
# • Anti-PD1 Monoclonal Antibody ⟵  is_a ⟵ Anti-CTLA-4 Monoclonal Antibody HBM4003
# • Anti-PD1 Monoclonal Antibody ⟵  is_a ⟵ Gilvetmab
# • Anti-PD1 Monoclonal Antibody ⟵  is_a ⟵ Vibostolimab/Pembrolizumab MK-7684A
# • Anti-PD1 Monoclonal Antibody ⟵  is_a ⟵ Anti-PD-1 Monoclonal Antibody SYN125
# • Anti-PD1 Monoclonal Antibody ⟵  is_a ⟵ Anti-PD-1 Monoclonal Antibody LVGN3616
# • Anti-PD1 Monoclonal Antibody ⟵  is_a ⟵ Anti-PD-1 Monoclonal Antibody TY101
# • Anti-PD1 Monoclonal Antibody ⟵  is_a ⟵ Anti-PD-1 Monoclonal Antibody MW11
# • Anti-PD1 Monoclonal Antibody ⟵  is_a ⟵ Anti-PD-1 Monoclonal Antibody GNR-051
# • Anti-PD1 Monoclonal Antibody ⟵  is_a ⟵ Anti-PD-1/LAG-3 Bispecific Antibody EMB-02
# • Anti-PD1 Monoclonal Antibody ⟵  is_a ⟵ Nivolumab
# • Anti-PD1 Monoclonal Antibody ⟵  is_a ⟵ Pidilizumab

# %%
sorted(id_to_name[subterm] for subterm in nx.ancestors(graph, 'NCIT:C62554'))
# Out:
# ['Amelparib',
#  'Atamparib',
#  'Bevacizumab/Olaparib Regimen',
#  'Fermented Wheat Germ Extract',
#  'Fluzoparib',
#  'Hypoxanthine',
#  'INO-1001',
#  'Iniparib',
#  'Niraparib',
#  'Niraparib Regimen',
#  'Niraparib Tosylate Monohydrate',
#  'Olaparib',
#  'Olaparib Regimen',
#  'PARP 1/2 Inhibitor NOV1401',
#  'PARP 1/2 Inhibitor SC10914',
#  'PARP Inhibitor AZD2461',
#  'PARP Inhibitor AZD5305',
#  'PARP Inhibitor CEP-9722',
#  'PARP Inhibitor E7016',
#  'PARP Inhibitor NMS-03305293',
#  'PARP-1/2 Inhibitor ABT-767',
#  'PARP/Microtubule Polymerization Inhibitor AMXI-5001',
#  'PARP/Tankyrase Inhibitor 2X-121',
#  'Pamiparib',
#  'Rucaparib',
#  'Rucaparib Camsylate',
#  'Rucaparib Phosphate',
#  'Rucaparib Regimen',
#  'Senaparib',
#  'Simmiparib',
#  'Talazoparib',
#  'Talazoparib Regimen',
#  'Talazoparib Tosylate',
#  'Tankyrase Inhibitor STP1002',
#  'Temozolomide/Veliparib Regimen',
#  'Veliparib',
#  'Venadaparib']

# %%
# 
sorted(id_to_name[superclass] for superclass in nx.descendants(graph, 'NCIT:C62554'))
# Out:
# ['ADP Ribosylation',
#  'Anatomic Structure, System, or Substance',
#  'Antineoplastic Agent',
#  'Base Excision Repair',
#  'Biochemical Process',
#  'Biological Process',
#  'Body Part',
#  'Cell',
#  'Cell Part',
#  'Cell Structure',
#  'Cell Survival',
#  'Cell Viability Process',
#  'Cellular Process',
#  'Chromatin',
#  'Chromosome',
#  'Chromosome Structure',
#  'DNA Maintenance',
#  'DNA Maintenance Process',
#  'DNA Repair',
#  'DNA Repair Gene',
#  'DNA Repair Protein',
#  'DNA Structure',
#  'Drug or Chemical by Structure',
#  'Drug, Food, Chemical or Biomedical Material',
#  'Enzyme Inhibitor',
#  'Excision Repair',
#  'Gene',
#  'Gene Expression',
#  'Gene Expression Process',
#  'Gene Feature',
#  'Gene Product',
#  'Intermediary Metabolic Process',
#  'Macromolecular Structure',
#  'Metabolic Process',
#  'Microanatomic Structure',
#  'Nuclear Structure',
#  'Nucleic Acids',
#  'Nucleic Acids, Nucleosides, and Nucleotides',
#  'Nucleus',
#  'Organic Chemical',
#  'PARP1 Gene',
#  'PARP1 Gene Product',
#  'Pharmacologic Substance',
#  'Poly [ADP-Ribose] Polymerase 1',
#  'Poly-ADP-Ribosylation',
#  'Post-Translational Modification',
#  'Post-Translational Regulation',
#  'Protein',
#  'Protein Metabolism Process',
#  'Protein, Organized by Function',
#  'Protoplasm',
#  'Ribonucleic Acid',
#  'Subcellular Process',
#  'Subcellular Structure',
#  'Targeted Therapy Agent',
#  'Transcription',
#  'Transcription Initiation',
#  'Transcription Process']

# %%
paths = nx.all_simple_paths(
    graph,
    target=name_to_id['Pharmacologic Substance'],
    source=name_to_id['Anti-PD-1/LAG-3 Bispecific Antibody EMB-02']
)
for path in paths:
    print('•', ' ⟶ ' '\n' ' ⟶ '.join(id_to_name[node] for node in path))
# Out:
# • Anti-PD-1/LAG-3 Bispecific Antibody EMB-02 ⟶
#  ⟶ Anti-PD1 Monoclonal Antibody ⟶
#  ⟶ PD1 Inhibitor ⟶
#  ⟶ Immune Checkpoint Inhibitor ⟶
#  ⟶ Immune Checkpoint Modulator ⟶
#  ⟶ Immunotherapeutic Agent ⟶
#  ⟶ Pharmacologic Substance
# • Anti-PD-1/LAG-3 Bispecific Antibody EMB-02 ⟶
#  ⟶ Anti-PD1 Monoclonal Antibody ⟶
#  ⟶ PD1 Inhibitor ⟶
#  ⟶ Targeted Therapy Agent ⟶
#  ⟶ Antineoplastic Agent ⟶
#  ⟶ Pharmacologic Substance
# • Anti-PD-1/LAG-3 Bispecific Antibody EMB-02 ⟶
#  ⟶ Anti-PD1 Monoclonal Antibody ⟶
#  ⟶ Monoclonal Antibody ⟶
#  ⟶ Biological Agent ⟶
#  ⟶ Pharmacologic Substance
# • Anti-PD-1/LAG-3 Bispecific Antibody EMB-02 ⟶
#  ⟶ Anti-PD1 Monoclonal Antibody ⟶
#  ⟶ Monoclonal Antibody ⟶
#  ⟶ Immunotherapeutic Agent ⟶
#  ⟶ Pharmacologic Substance
# • Anti-PD-1/LAG-3 Bispecific Antibody EMB-02 ⟶
#  ⟶ Anti-LAG-3 Monoclonal Antibody ⟶
#  ⟶ Antineoplastic Antibody ⟶
#  ⟶ Antineoplastic Biological Agent ⟶
#  ⟶ Antineoplastic Agent ⟶
#  ⟶ Pharmacologic Substance
# • Anti-PD-1/LAG-3 Bispecific Antibody EMB-02 ⟶
#  ⟶ Anti-LAG-3 Monoclonal Antibody ⟶
#  ⟶ Antineoplastic Antibody ⟶
#  ⟶ Antineoplastic Biological Agent ⟶
#  ⟶ Biological Agent ⟶
#  ⟶ Pharmacologic Substance
# • Anti-PD-1/LAG-3 Bispecific Antibody EMB-02 ⟶
#  ⟶ Anti-LAG-3 Monoclonal Antibody ⟶
#  ⟶ Immune Checkpoint Inhibitor ⟶
#  ⟶ Immune Checkpoint Modulator ⟶
#  ⟶ Immunotherapeutic Agent ⟶
#  ⟶ Pharmacologic Substance
# • Anti-PD-1/LAG-3 Bispecific Antibody EMB-02 ⟶
#  ⟶ Anti-LAG-3 Monoclonal Antibody ⟶
#  ⟶ Monoclonal Antibody ⟶
#  ⟶ Biological Agent ⟶
#  ⟶ Pharmacologic Substance
# • Anti-PD-1/LAG-3 Bispecific Antibody EMB-02 ⟶
#  ⟶ Anti-LAG-3 Monoclonal Antibody ⟶
#  ⟶ Monoclonal Antibody ⟶
#  ⟶ Immunotherapeutic Agent ⟶
#  ⟶ Pharmacologic Substance
# • Anti-PD-1/LAG-3 Bispecific Antibody EMB-02 ⟶
#  ⟶ Bispecific Monoclonal Antibody ⟶
#  ⟶ Monoclonal Antibody ⟶
#  ⟶ Biological Agent ⟶
#  ⟶ Pharmacologic Substance
# • Anti-PD-1/LAG-3 Bispecific Antibody EMB-02 ⟶
#  ⟶ Bispecific Monoclonal Antibody ⟶
#  ⟶ Monoclonal Antibody ⟶
#  ⟶ Immunotherapeutic Agent ⟶
#  ⟶ Pharmacologic Substance
