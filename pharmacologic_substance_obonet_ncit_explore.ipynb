# %%
import obonet as obo
import networkx as nx

# %%
# Using obonet, read in OBOFoundry URL for ncit.obo
## Reference http://www.obofoundry.org/ for all available OBO ontologies via OBOFoundry
# This will take ~2.5 minutes to complete

url = 'http://purl.obolibrary.org/obo/ncit.obo'
graph = obo.read_obo(url)
len(graph)
# Out:
# 162169

# %%
# Number of edges

graph.number_of_edges()
# Out:
# 235888

# %%
# Number of nodes

graph.number_of_nodes()
# Out:
# 162169

# %%
# Retreive properties of Parp Inhibitor (Poly (ADP-Ribose) Polymerase Inhibitor) ⟶ Parp Inhibitor

graph.nodes['NCIT:C62554']
# Out:
# {'name': 'Poly (ADP-Ribose) Polymerase Inhibitor',
#  'def': '"Any substance that inhibits Poly (ADP-Ribose) polymerase, an enzyme involved in detecting DNA single strand breaks and the initiation of DNA repair. Inhibition of Poly (ADP-Ribose) polymerase has direct cytotoxic effects by inhibiting DNA repair and causing cell death." []',
#  'subset': ['NCIT:C116977', 'NCIT:C116978'],
#  'synonym': ['"PARP Inhibitor" EXACT []',
#   '"PARP Inhibitor" EXACT []',
#   '"PARP inhibitor" EXACT []',
#   '"Poly (ADP-Ribose) Polymerase Inhibitor" EXACT []',
#   '"poly (ADP-ribose) polymerase inhibitor" EXACT []',
#   '"Poly(ADP-Ribose) Polymerase Inhibitor" EXACT []'],
#  'is_a': ['NCIT:C163758', 'NCIT:C471'],
#  'relationship': ['NCIT:R146 NCIT:C48215'],
#  'property_value': ['NCIT:NHC0 "C62554" xsd:string',
#   'NCIT:P106 "Chemical Viewed Functionally" xsd:string',
#   'NCIT:P107 "PARP Inhibitor" xsd:string',
#   'NCIT:P108 "Poly (ADP-Ribose) Polymerase Inhibitor" xsd:string',
#   'NCIT:P207 "C1882413" xsd:string',
#   'NCIT:P322 "CTRP" xsd:string',
#   'NCIT:P325 "A substance that blocks an enzyme involved in many functions of the cell, including the repair of DNA damage. DNA damage may be caused by normal cell actions, UV light, some anticancer drugs, and radiation used to treat cancer. It may cause cancer cells to die. It is a type of targeted therapy." xsd:string',
#   'NCIT:P366 "Poly_ADP-Ribose_Polymerase_Inhibitor" xsd:string',
#   'NCIT:P368 CHEBI:62913 xsd:string']}

# %%
# Define a id (source code i.e. NCIT:C62554) to preferred label mapping for NCI Thesaurus OBO file

id_to_name = {ID: data.get('name') for ID, data in graph.nodes(data=True)}
name_to_id = {data['name']: ID for ID, data in graph.nodes(data=True) if 'name' in data}

# %%
# id ⟶ mapsTo ⟶ name
print({len(id_to_name)})

# name ⟶ mapsTo ⟶ id
print({len(name_to_id)})
# Out:
# {162169}
# {162031}

# %%
# Get the name for NCIT:C62554 (poly (ADP-Ribose) Polymerase Inhibitor) AKA PARP Inhibitor
parp = id_to_name['NCIT:C62554']
parp
# Out:
# 'Poly (ADP-Ribose) Polymerase Inhibitor'

# %%
# Find all ancestors (superclasses) of Parp Inhibitor. 
# Networkx ancestors correlates to 'subterms' & networkx descendants correlates to 'superclasses'
# ⟶ A bit counter-intuitive but now we know

# Within our graph let's get all subterms of Parp Inhibitor (NCIT:C62554)
# ⟶ where Node id: is the corresponding id for the name (i.e. see below)

nx.ancestors(graph, 'NCIT:C62554')
for node in nx.ancestors(graph, 'NCIT:C62554'):
    print('conceptId: {:15s} ⟶ hasLabel ⟶ \t conceptLabel: {:30s}'.format(node, id_to_name[node]))
# Out:
# conceptId: NCIT:C167278    ⟶ hasLabel ⟶ 	 conceptLabel: PARP Inhibitor NMS-03305293
# conceptId: NCIT:C169778    ⟶ hasLabel ⟶ 	 conceptLabel: Amelparib
# conceptId: NCIT:C178310    ⟶ hasLabel ⟶ 	 conceptLabel: PARP 1/2 Inhibitor SC10914
# conceptId: NCIT:C62526     ⟶ hasLabel ⟶ 	 conceptLabel: Iniparib
# conceptId: NCIT:C176969    ⟶ hasLabel ⟶ 	 conceptLabel: PARP/Microtubule Polymerization Inhibitor AMXI-5001
# conceptId: NCIT:C140553    ⟶ hasLabel ⟶ 	 conceptLabel: Simmiparib
# conceptId: NCIT:C71721     ⟶ hasLabel ⟶ 	 conceptLabel: Olaparib
# conceptId: NCIT:C160812    ⟶ hasLabel ⟶ 	 conceptLabel: Rucaparib Regimen
# conceptId: NCIT:C160097    ⟶ hasLabel ⟶ 	 conceptLabel: Olaparib Regimen
# conceptId: NCIT:C60768     ⟶ hasLabel ⟶ 	 conceptLabel: Veliparib
# conceptId: NCIT:C29105     ⟶ hasLabel ⟶ 	 conceptLabel: Hypoxanthine
# conceptId: NCIT:C133238    ⟶ hasLabel ⟶ 	 conceptLabel: Niraparib Tosylate Monohydrate
# conceptId: NCIT:C172134    ⟶ hasLabel ⟶ 	 conceptLabel: Bevacizumab/Olaparib Regimen
# conceptId: NCIT:C137800    ⟶ hasLabel ⟶ 	 conceptLabel: Rucaparib
# conceptId: NCIT:C120553    ⟶ hasLabel ⟶ 	 conceptLabel: Pamiparib
# conceptId: NCIT:C175871    ⟶ hasLabel ⟶ 	 conceptLabel: Venadaparib
# conceptId: NCIT:C156260    ⟶ hasLabel ⟶ 	 conceptLabel: Temozolomide/Veliparib Regimen
# conceptId: NCIT:C176783    ⟶ hasLabel ⟶ 	 conceptLabel: PARP Inhibitor AZD5305
# conceptId: NCIT:C131178    ⟶ hasLabel ⟶ 	 conceptLabel: Rucaparib Camsylate
# conceptId: NCIT:C91387     ⟶ hasLabel ⟶ 	 conceptLabel: PARP Inhibitor E7016
# conceptId: NCIT:C152494    ⟶ hasLabel ⟶ 	 conceptLabel: Talazoparib Tosylate
# conceptId: NCIT:C160807    ⟶ hasLabel ⟶ 	 conceptLabel: Niraparib Regimen
# conceptId: NCIT:C95201     ⟶ hasLabel ⟶ 	 conceptLabel: PARP Inhibitor AZD2461
# conceptId: NCIT:C78186     ⟶ hasLabel ⟶ 	 conceptLabel: Rucaparib Phosphate
# conceptId: NCIT:C95733     ⟶ hasLabel ⟶ 	 conceptLabel: Talazoparib
# conceptId: NCIT:C174060    ⟶ hasLabel ⟶ 	 conceptLabel: Tankyrase Inhibitor STP1002
# conceptId: NCIT:C96795     ⟶ hasLabel ⟶ 	 conceptLabel: PARP-1/2 Inhibitor ABT-767
# conceptId: NCIT:C154560    ⟶ hasLabel ⟶ 	 conceptLabel: PARP 1/2 Inhibitor NOV1401
# conceptId: NCIT:C170764    ⟶ hasLabel ⟶ 	 conceptLabel: Atamparib
# conceptId: NCIT:C160120    ⟶ hasLabel ⟶ 	 conceptLabel: Talazoparib Regimen
# conceptId: NCIT:C126274    ⟶ hasLabel ⟶ 	 conceptLabel: Fluzoparib
# conceptId: NCIT:C61315     ⟶ hasLabel ⟶ 	 conceptLabel: INO-1001
# conceptId: NCIT:C80059     ⟶ hasLabel ⟶ 	 conceptLabel: Niraparib
# conceptId: NCIT:C84880     ⟶ hasLabel ⟶ 	 conceptLabel: PARP Inhibitor CEP-9722
# conceptId: NCIT:C168601    ⟶ hasLabel ⟶ 	 conceptLabel: Senaparib
# conceptId: NCIT:C64763     ⟶ hasLabel ⟶ 	 conceptLabel: Fermented Wheat Germ Extract
# conceptId: NCIT:C102746    ⟶ hasLabel ⟶ 	 conceptLabel: PARP/Tankyrase Inhibitor 2X-121

# %%
nx.ancestors(graph, 'NCIT:C62554')
for node in nx.ancestors(graph, 'NCIT:C62554'):
    print('conceptLabel: {:15s}  ⟶ hasId ⟶ \t conceptId: \t {:10s}'.format(node, id_to_name[node]))
# Out:
# conceptLabel: NCIT:C167278     ⟶ hasId ⟶ 	 conceptId: 	 PARP Inhibitor NMS-03305293
# conceptLabel: NCIT:C169778     ⟶ hasId ⟶ 	 conceptId: 	 Amelparib
# conceptLabel: NCIT:C178310     ⟶ hasId ⟶ 	 conceptId: 	 PARP 1/2 Inhibitor SC10914
# conceptLabel: NCIT:C62526      ⟶ hasId ⟶ 	 conceptId: 	 Iniparib
# conceptLabel: NCIT:C176969     ⟶ hasId ⟶ 	 conceptId: 	 PARP/Microtubule Polymerization Inhibitor AMXI-5001
# conceptLabel: NCIT:C140553     ⟶ hasId ⟶ 	 conceptId: 	 Simmiparib
# conceptLabel: NCIT:C71721      ⟶ hasId ⟶ 	 conceptId: 	 Olaparib
# conceptLabel: NCIT:C160812     ⟶ hasId ⟶ 	 conceptId: 	 Rucaparib Regimen
# conceptLabel: NCIT:C160097     ⟶ hasId ⟶ 	 conceptId: 	 Olaparib Regimen
# conceptLabel: NCIT:C60768      ⟶ hasId ⟶ 	 conceptId: 	 Veliparib
# conceptLabel: NCIT:C29105      ⟶ hasId ⟶ 	 conceptId: 	 Hypoxanthine
# conceptLabel: NCIT:C133238     ⟶ hasId ⟶ 	 conceptId: 	 Niraparib Tosylate Monohydrate
# conceptLabel: NCIT:C172134     ⟶ hasId ⟶ 	 conceptId: 	 Bevacizumab/Olaparib Regimen
# conceptLabel: NCIT:C137800     ⟶ hasId ⟶ 	 conceptId: 	 Rucaparib
# conceptLabel: NCIT:C120553     ⟶ hasId ⟶ 	 conceptId: 	 Pamiparib
# conceptLabel: NCIT:C175871     ⟶ hasId ⟶ 	 conceptId: 	 Venadaparib
# conceptLabel: NCIT:C156260     ⟶ hasId ⟶ 	 conceptId: 	 Temozolomide/Veliparib Regimen
# conceptLabel: NCIT:C176783     ⟶ hasId ⟶ 	 conceptId: 	 PARP Inhibitor AZD5305
# conceptLabel: NCIT:C131178     ⟶ hasId ⟶ 	 conceptId: 	 Rucaparib Camsylate
# conceptLabel: NCIT:C91387      ⟶ hasId ⟶ 	 conceptId: 	 PARP Inhibitor E7016
# conceptLabel: NCIT:C152494     ⟶ hasId ⟶ 	 conceptId: 	 Talazoparib Tosylate
# conceptLabel: NCIT:C160807     ⟶ hasId ⟶ 	 conceptId: 	 Niraparib Regimen
# conceptLabel: NCIT:C95201      ⟶ hasId ⟶ 	 conceptId: 	 PARP Inhibitor AZD2461
# conceptLabel: NCIT:C78186      ⟶ hasId ⟶ 	 conceptId: 	 Rucaparib Phosphate
# conceptLabel: NCIT:C95733      ⟶ hasId ⟶ 	 conceptId: 	 Talazoparib
# conceptLabel: NCIT:C174060     ⟶ hasId ⟶ 	 conceptId: 	 Tankyrase Inhibitor STP1002
# conceptLabel: NCIT:C96795      ⟶ hasId ⟶ 	 conceptId: 	 PARP-1/2 Inhibitor ABT-767
# conceptLabel: NCIT:C154560     ⟶ hasId ⟶ 	 conceptId: 	 PARP 1/2 Inhibitor NOV1401
# conceptLabel: NCIT:C170764     ⟶ hasId ⟶ 	 conceptId: 	 Atamparib
# conceptLabel: NCIT:C160120     ⟶ hasId ⟶ 	 conceptId: 	 Talazoparib Regimen
# conceptLabel: NCIT:C126274     ⟶ hasId ⟶ 	 conceptId: 	 Fluzoparib
# conceptLabel: NCIT:C61315      ⟶ hasId ⟶ 	 conceptId: 	 INO-1001
# conceptLabel: NCIT:C80059      ⟶ hasId ⟶ 	 conceptId: 	 Niraparib
# conceptLabel: NCIT:C84880      ⟶ hasId ⟶ 	 conceptId: 	 PARP Inhibitor CEP-9722
# conceptLabel: NCIT:C168601     ⟶ hasId ⟶ 	 conceptId: 	 Senaparib
# conceptLabel: NCIT:C64763      ⟶ hasId ⟶ 	 conceptId: 	 Fermented Wheat Germ Extract
# conceptLabel: NCIT:C102746     ⟶ hasId ⟶ 	 conceptId: 	 PARP/Tankyrase Inhibitor 2X-121

# %%
# Find immediate parent concepts to Poly (ADP-Ribose) Polymerase Inhibitor (Code C62554)
# graph.out_edges() vs graph.in_edges() 

node = name_to_id['Poly (ADP-Ribose) Polymerase Inhibitor']
for child, parent, key in graph.out_edges(node, keys=True):
    print(f'• {id_to_name[child]} ⟶ {key} ⟶  {id_to_name[parent]}')
# Out:
# • Poly (ADP-Ribose) Polymerase Inhibitor ⟶ is_a ⟶  Targeted Therapy Agent
# • Poly (ADP-Ribose) Polymerase Inhibitor ⟶ is_a ⟶  Enzyme Inhibitor
# • Poly (ADP-Ribose) Polymerase Inhibitor ⟶ NCIT:R146 ⟶  Poly [ADP-Ribose] Polymerase 1

# %%
# All Drugs within the NCI Thesaurus that are defined to exhibit the 'drug class' of Parp Inhibitor 
# AKA all direct children of the concept NCIT_C62554 (Parp Inhibitor)

node = name_to_id['Poly (ADP-Ribose) Polymerase Inhibitor']
for parent, child, key in graph.in_edges(node, keys=True):
    print(f'• {id_to_name[child]} \t ⟵ {key} ⟵ {id_to_name[parent]}')
# Out:
# • Poly (ADP-Ribose) Polymerase Inhibitor 	 ⟵ is_a ⟵ PARP/Tankyrase Inhibitor 2X-121
# • Poly (ADP-Ribose) Polymerase Inhibitor 	 ⟵ is_a ⟵ Pamiparib
# • Poly (ADP-Ribose) Polymerase Inhibitor 	 ⟵ is_a ⟵ Fluzoparib
# • Poly (ADP-Ribose) Polymerase Inhibitor 	 ⟵ is_a ⟵ Rucaparib Camsylate
# • Poly (ADP-Ribose) Polymerase Inhibitor 	 ⟵ is_a ⟵ Niraparib Tosylate Monohydrate
# • Poly (ADP-Ribose) Polymerase Inhibitor 	 ⟵ is_a ⟵ Rucaparib
# • Poly (ADP-Ribose) Polymerase Inhibitor 	 ⟵ is_a ⟵ Simmiparib
# • Poly (ADP-Ribose) Polymerase Inhibitor 	 ⟵ is_a ⟵ Talazoparib Tosylate
# • Poly (ADP-Ribose) Polymerase Inhibitor 	 ⟵ is_a ⟵ PARP 1/2 Inhibitor NOV1401
# • Poly (ADP-Ribose) Polymerase Inhibitor 	 ⟵ is_a ⟵ PARP Inhibitor NMS-03305293
# • Poly (ADP-Ribose) Polymerase Inhibitor 	 ⟵ is_a ⟵ Senaparib
# • Poly (ADP-Ribose) Polymerase Inhibitor 	 ⟵ is_a ⟵ Amelparib
# • Poly (ADP-Ribose) Polymerase Inhibitor 	 ⟵ is_a ⟵ Atamparib
# • Poly (ADP-Ribose) Polymerase Inhibitor 	 ⟵ is_a ⟵ Tankyrase Inhibitor STP1002
# • Poly (ADP-Ribose) Polymerase Inhibitor 	 ⟵ is_a ⟵ Venadaparib
# • Poly (ADP-Ribose) Polymerase Inhibitor 	 ⟵ is_a ⟵ PARP Inhibitor AZD5305
# • Poly (ADP-Ribose) Polymerase Inhibitor 	 ⟵ is_a ⟵ PARP/Microtubule Polymerization Inhibitor AMXI-5001
# • Poly (ADP-Ribose) Polymerase Inhibitor 	 ⟵ is_a ⟵ PARP 1/2 Inhibitor SC10914
# • Poly (ADP-Ribose) Polymerase Inhibitor 	 ⟵ is_a ⟵ Hypoxanthine
# • Poly (ADP-Ribose) Polymerase Inhibitor 	 ⟵ is_a ⟵ Veliparib
# • Poly (ADP-Ribose) Polymerase Inhibitor 	 ⟵ is_a ⟵ INO-1001
# • Poly (ADP-Ribose) Polymerase Inhibitor 	 ⟵ is_a ⟵ Iniparib
# • Poly (ADP-Ribose) Polymerase Inhibitor 	 ⟵ is_a ⟵ Fermented Wheat Germ Extract
# • Poly (ADP-Ribose) Polymerase Inhibitor 	 ⟵ is_a ⟵ Olaparib
# • Poly (ADP-Ribose) Polymerase Inhibitor 	 ⟵ is_a ⟵ Rucaparib Phosphate
# • Poly (ADP-Ribose) Polymerase Inhibitor 	 ⟵ is_a ⟵ Niraparib
# • Poly (ADP-Ribose) Polymerase Inhibitor 	 ⟵ is_a ⟵ PARP Inhibitor CEP-9722
# • Poly (ADP-Ribose) Polymerase Inhibitor 	 ⟵ is_a ⟵ PARP Inhibitor E7016
# • Poly (ADP-Ribose) Polymerase Inhibitor 	 ⟵ is_a ⟵ PARP Inhibitor AZD2461
# • Poly (ADP-Ribose) Polymerase Inhibitor 	 ⟵ is_a ⟵ Talazoparib
# • Poly (ADP-Ribose) Polymerase Inhibitor 	 ⟵ is_a ⟵ PARP-1/2 Inhibitor ABT-767

# %%
# Olaparib is a newly FDA approved Parp Inhibitor (Ovarian Cancer)
# ⟶ demonstrate the out_edge of the graph (aka immediate parent is Poly (ADP-Ribose) Polymerase Inhibitor)

node = name_to_id['Olaparib']
for parent, child, key in graph.out_edges(node, keys=True):
    print(f'• {id_to_name[child]} ⟵  {key} ⟵ {id_to_name[parent]}')
# Out:
# • Poly (ADP-Ribose) Polymerase Inhibitor ⟵  is_a ⟵ Olaparib

# %%
# Olaparib is a newly FDA approved Parp Inhibitor (Ovarian Cancer)
# Contrast to the above example. (out_edges vs in_edges) illustrates the NCIt semantic relationship NCIT:R123 (where NCIT:R123 == Chemotherapy_Regimen_Has_Component)
# NIH reference for translation ⟶ https://www.nlm.nih.gov/research/umls/sourcereleasedocs/current/NCI/sourcerepresentation.html

node = name_to_id['Olaparib']
for child, parent, key in graph.in_edges(node, keys=True):
    print(f'• {id_to_name[child]} ⟵ {key} ⟵ {id_to_name[parent]}')
# Out:
# • Olaparib Regimen ⟵ NCIT:R123 ⟵ Olaparib
# • Bevacizumab/Olaparib Regimen ⟵ NCIT:R123 ⟵ Olaparib

# %%
# Explore another Parp Inhibitor (in_edges)

node = name_to_id['Talazoparib']
for child, parent, key in graph.in_edges(node, keys=True):
    print(f'• {id_to_name[child]} ⟵  {key} ⟵ {id_to_name[parent]}')
# Out:
# • Talazoparib Regimen ⟵  NCIT:R123 ⟵ Talazoparib

# %%
# Explore another Parp Inhibitor (out_edges)

node = name_to_id['Talazoparib']
for parent, child, key in graph.out_edges(node, keys=True):
    print(f'• {id_to_name[child]} ⟵  {key} ⟵ {id_to_name[parent]}')
# Out:
# • Poly (ADP-Ribose) Polymerase Inhibitor ⟵  is_a ⟵ Talazoparib

# %%
# Pembrolizumab, sold under the brand name Keytruda, is a humanized antibody used in cancer immunotherapy that treats melanoma, lung cancer, head and neck cancer, Hodgkin lymphoma, and stomach cancer.
# Let's explore regimens within NCIt for Pembro. (AKA Keytruda)
# ⟶ Many platinum based chemo regimens 

node = name_to_id['Pembrolizumab']
for parent, child, key in graph.in_edges(node, keys=True):
    print(f'• {id_to_name[child]}  ⟵ {key} ⟵ {id_to_name[parent]}')
# Out:
# • Pembrolizumab  ⟵ NCIT:R123 ⟵ Carboplatin/Pembrolizumab/Pemetrexed Regimen
# • Pembrolizumab  ⟵ NCIT:R123 ⟵ Carboplatin/Paclitaxel/Pembrolizumab Regimen
# • Pembrolizumab  ⟵ NCIT:R123 ⟵ Cisplatin/Pembrolizumab/Pemetrexed Regimen
# • Pembrolizumab  ⟵ NCIT:R123 ⟵ Pembrolizumab/Pemetrexed Regimen
# • Pembrolizumab  ⟵ NCIT:R123 ⟵ Cisplatin/Nab-Paclitaxel/Pembrolizumab Regimen
# • Pembrolizumab  ⟵ NCIT:R123 ⟵ Carboplatin/Nab-Paclitaxel/Pembrolizumab Regimen
# • Pembrolizumab  ⟵ NCIT:R123 ⟵ Cisplatin/Paclitaxel/Pembrolizumab Regimen
# • Pembrolizumab  ⟵ NCIT:R123 ⟵ Pembrolizumab Regimen
# • Pembrolizumab  ⟵ NCIT:R123 ⟵ Carboplatin/Fluorouracil/Pembrolizumab Regimen
# • Pembrolizumab  ⟵ NCIT:R123 ⟵ Cisplatin/Fluorouracil/Pembrolizumab Regimen
# • Pembrolizumab  ⟵ NCIT:R123 ⟵ Axitinib/Pembrolizumab Regimen
# • Pembrolizumab  ⟵ NCIT:R123 ⟵ Avelumab/Axitinib Regimen

# %%
# What drug classification via NCI Thesaurus does Pembrolizumab exhibit?
# Anti-PD1 Monoclonal Antibody!

node = name_to_id['Pembrolizumab']
for parent, child, key in graph.out_edges(node, keys=True):
    print(f'• {id_to_name[child]} ⟵ {key} ⟵ {id_to_name[parent]}')
# Out:
# • Anti-PD1 Monoclonal Antibody ⟵ is_a ⟵ Pembrolizumab

# %%
# What other drugs are also Anti-PD1 Monoclonal Antibody via NCI Thesaurus?
# ⟶ Similar to Parp Inhibitors, there are many non-FDA approved (investigational) Anti-PD1 Monoclonal Antibody drugs being developed
# ⟶ I.e. Anti-PD-1 Monoclonal Antibody MEDI0680, Anti-PD-1/LAG-3 Bispecific Antibody EMB-02 etc

node = name_to_id['Anti-PD1 Monoclonal Antibody']
for parent, child, key in graph.in_edges(node, keys=True):
    print(f'• {id_to_name[child]} \t ⟵ {key} ⟵ \t {id_to_name[parent]}')
# Out:
# • Anti-PD1 Monoclonal Antibody 	 ⟵ is_a ⟵ 	 Pembrolizumab
# • Anti-PD1 Monoclonal Antibody 	 ⟵ is_a ⟵ 	 Anti-PD-1 Monoclonal Antibody MEDI0680
# • Anti-PD1 Monoclonal Antibody 	 ⟵ is_a ⟵ 	 Cemiplimab
# • Anti-PD1 Monoclonal Antibody 	 ⟵ is_a ⟵ 	 Spartalizumab
# • Anti-PD1 Monoclonal Antibody 	 ⟵ is_a ⟵ 	 Tislelizumab
# • Anti-PD1 Monoclonal Antibody 	 ⟵ is_a ⟵ 	 Camrelizumab
# • Anti-PD1 Monoclonal Antibody 	 ⟵ is_a ⟵ 	 Dostarlimab
# • Anti-PD1 Monoclonal Antibody 	 ⟵ is_a ⟵ 	 Cetrelimab
# • Anti-PD1 Monoclonal Antibody 	 ⟵ is_a ⟵ 	 Toripalimab
# • Anti-PD1 Monoclonal Antibody 	 ⟵ is_a ⟵ 	 Ezabenlimab
# • Anti-PD1 Monoclonal Antibody 	 ⟵ is_a ⟵ 	 Sintilimab
# • Anti-PD1 Monoclonal Antibody 	 ⟵ is_a ⟵ 	 Balstilimab
# • Anti-PD1 Monoclonal Antibody 	 ⟵ is_a ⟵ 	 Retifanlimab
# • Anti-PD1 Monoclonal Antibody 	 ⟵ is_a ⟵ 	 Anti-PD-1 Monoclonal Antibody Sym021
# • Anti-PD1 Monoclonal Antibody 	 ⟵ is_a ⟵ 	 Prolgolimab
# • Anti-PD1 Monoclonal Antibody 	 ⟵ is_a ⟵ 	 Geptanolimab
# • Anti-PD1 Monoclonal Antibody 	 ⟵ is_a ⟵ 	 Anti-PD-1 Monoclonal Antibody LZM009
# • Anti-PD1 Monoclonal Antibody 	 ⟵ is_a ⟵ 	 Penpulimab
# • Anti-PD1 Monoclonal Antibody 	 ⟵ is_a ⟵ 	 Anti-PD-1 Monoclonal Antibody CS1003
# • Anti-PD1 Monoclonal Antibody 	 ⟵ is_a ⟵ 	 Serplulimab
# • Anti-PD1 Monoclonal Antibody 	 ⟵ is_a ⟵ 	 Pimivalimab
# • Anti-PD1 Monoclonal Antibody 	 ⟵ is_a ⟵ 	 Zimberelimab
# • Anti-PD1 Monoclonal Antibody 	 ⟵ is_a ⟵ 	 Pucotenlimab
# • Anti-PD1 Monoclonal Antibody 	 ⟵ is_a ⟵ 	 Zeluvalimab
# • Anti-PD1 Monoclonal Antibody 	 ⟵ is_a ⟵ 	 Anti-PD-1 Monoclonal Antibody F520
# • Anti-PD1 Monoclonal Antibody 	 ⟵ is_a ⟵ 	 Anti-PD-1 Monoclonal Antibody BAT1306
# • Anti-PD1 Monoclonal Antibody 	 ⟵ is_a ⟵ 	 Finotonlimab
# • Anti-PD1 Monoclonal Antibody 	 ⟵ is_a ⟵ 	 Anti-CTLA-4/Anti-PD-1 Monoclonal Antibody Combination BCD-217
# • Anti-PD1 Monoclonal Antibody 	 ⟵ is_a ⟵ 	 Anti-PD-1 Monoclonal Antibody 609A
# • Anti-PD1 Monoclonal Antibody 	 ⟵ is_a ⟵ 	 Anti-PD-1/Anti-LAG-3 Bispecific Antibody RO7247669
# • Anti-PD1 Monoclonal Antibody 	 ⟵ is_a ⟵ 	 Anti-CTLA-4 Monoclonal Antibody HBM4003
# • Anti-PD1 Monoclonal Antibody 	 ⟵ is_a ⟵ 	 Gilvetmab
# • Anti-PD1 Monoclonal Antibody 	 ⟵ is_a ⟵ 	 Vibostolimab/Pembrolizumab MK-7684A
# • Anti-PD1 Monoclonal Antibody 	 ⟵ is_a ⟵ 	 Anti-PD-1 Monoclonal Antibody SYN125
# • Anti-PD1 Monoclonal Antibody 	 ⟵ is_a ⟵ 	 Anti-PD-1 Monoclonal Antibody LVGN3616
# • Anti-PD1 Monoclonal Antibody 	 ⟵ is_a ⟵ 	 Anti-PD-1 Monoclonal Antibody TY101
# • Anti-PD1 Monoclonal Antibody 	 ⟵ is_a ⟵ 	 Anti-PD-1 Monoclonal Antibody MW11
# • Anti-PD1 Monoclonal Antibody 	 ⟵ is_a ⟵ 	 Anti-PD-1 Monoclonal Antibody GNR-051
# • Anti-PD1 Monoclonal Antibody 	 ⟵ is_a ⟵ 	 Anti-PD-1/LAG-3 Bispecific Antibody EMB-02
# • Anti-PD1 Monoclonal Antibody 	 ⟵ is_a ⟵ 	 Nivolumab
# • Anti-PD1 Monoclonal Antibody 	 ⟵ is_a ⟵ 	 Pidilizumab

# %%
# All subterms for Parp Inhibtor (aka descendants via networkx)

sorted(id_to_name[subterm] for subterm in nx.ancestors(graph, 'NCIT:C62554'))
# Out:
# ['Amelparib',
#  'Atamparib',
#  'Bevacizumab/Olaparib Regimen',
#  'Fermented Wheat Germ Extract',
#  'Fluzoparib',
#  'Hypoxanthine',
#  'INO-1001',
#  'Iniparib',
#  'Niraparib',
#  'Niraparib Regimen',
#  'Niraparib Tosylate Monohydrate',
#  'Olaparib',
#  'Olaparib Regimen',
#  'PARP 1/2 Inhibitor NOV1401',
#  'PARP 1/2 Inhibitor SC10914',
#  'PARP Inhibitor AZD2461',
#  'PARP Inhibitor AZD5305',
#  'PARP Inhibitor CEP-9722',
#  'PARP Inhibitor E7016',
#  'PARP Inhibitor NMS-03305293',
#  'PARP-1/2 Inhibitor ABT-767',
#  'PARP/Microtubule Polymerization Inhibitor AMXI-5001',
#  'PARP/Tankyrase Inhibitor 2X-121',
#  'Pamiparib',
#  'Rucaparib',
#  'Rucaparib Camsylate',
#  'Rucaparib Phosphate',
#  'Rucaparib Regimen',
#  'Senaparib',
#  'Simmiparib',
#  'Talazoparib',
#  'Talazoparib Regimen',
#  'Talazoparib Tosylate',
#  'Tankyrase Inhibitor STP1002',
#  'Temozolomide/Veliparib Regimen',
#  'Veliparib',
#  'Venadaparib']

# %%
# Superclasses (aka ancestors via networkx) for Parp Inhibitor

sorted(id_to_name[subterm] for subterm in nx.descendants(graph, 'NCIT:C62554'))
# Out:
# ['ADP Ribosylation',
#  'Anatomic Structure, System, or Substance',
#  'Antineoplastic Agent',
#  'Base Excision Repair',
#  'Biochemical Process',
#  'Biological Process',
#  'Body Part',
#  'Cell',
#  'Cell Part',
#  'Cell Structure',
#  'Cell Survival',
#  'Cell Viability Process',
#  'Cellular Process',
#  'Chromatin',
#  'Chromosome',
#  'Chromosome Structure',
#  'DNA Maintenance',
#  'DNA Maintenance Process',
#  'DNA Repair',
#  'DNA Repair Gene',
#  'DNA Repair Protein',
#  'DNA Structure',
#  'Drug or Chemical by Structure',
#  'Drug, Food, Chemical or Biomedical Material',
#  'Enzyme Inhibitor',
#  'Excision Repair',
#  'Gene',
#  'Gene Expression',
#  'Gene Expression Process',
#  'Gene Feature',
#  'Gene Product',
#  'Intermediary Metabolic Process',
#  'Macromolecular Structure',
#  'Metabolic Process',
#  'Microanatomic Structure',
#  'Nuclear Structure',
#  'Nucleic Acids',
#  'Nucleic Acids, Nucleosides, and Nucleotides',
#  'Nucleus',
#  'Organic Chemical',
#  'PARP1 Gene',
#  'PARP1 Gene Product',
#  'Pharmacologic Substance',
#  'Poly [ADP-Ribose] Polymerase 1',
#  'Poly-ADP-Ribosylation',
#  'Post-Translational Modification',
#  'Post-Translational Regulation',
#  'Protein',
#  'Protein Metabolism Process',
#  'Protein, Organized by Function',
#  'Protoplasm',
#  'Ribonucleic Acid',
#  'Subcellular Process',
#  'Subcellular Structure',
#  'Targeted Therapy Agent',
#  'Transcription',
#  'Transcription Initiation',
#  'Transcription Process']

# %%
# All paths between source & target (Anti-PD-1/LAG-3 Bispecific Antibody EMB-02 & Pharmacologic Substance - respectively)
# Traversing from a 'narrower' NCI Thesaurus concept to its root concept within its semantic type

paths = nx.all_simple_paths(
    graph,
    target=name_to_id['Pharmacologic Substance'],
    source=name_to_id['Anti-PD-1/LAG-3 Bispecific Antibody EMB-02']
)
for path in paths:
    print('•', ' ⟶ ' '\n' ' ⟶ '.join(id_to_name[node] for node in path))
# Out:
# • Anti-PD-1/LAG-3 Bispecific Antibody EMB-02 ⟶
#  ⟶ Anti-PD1 Monoclonal Antibody ⟶
#  ⟶ PD1 Inhibitor ⟶
#  ⟶ Immune Checkpoint Inhibitor ⟶
#  ⟶ Immune Checkpoint Modulator ⟶
#  ⟶ Immunotherapeutic Agent ⟶
#  ⟶ Pharmacologic Substance
# • Anti-PD-1/LAG-3 Bispecific Antibody EMB-02 ⟶
#  ⟶ Anti-PD1 Monoclonal Antibody ⟶
#  ⟶ PD1 Inhibitor ⟶
#  ⟶ Targeted Therapy Agent ⟶
#  ⟶ Antineoplastic Agent ⟶
#  ⟶ Pharmacologic Substance
# • Anti-PD-1/LAG-3 Bispecific Antibody EMB-02 ⟶
#  ⟶ Anti-PD1 Monoclonal Antibody ⟶
#  ⟶ Monoclonal Antibody ⟶
#  ⟶ Biological Agent ⟶
#  ⟶ Pharmacologic Substance
# • Anti-PD-1/LAG-3 Bispecific Antibody EMB-02 ⟶
#  ⟶ Anti-PD1 Monoclonal Antibody ⟶
#  ⟶ Monoclonal Antibody ⟶
#  ⟶ Immunotherapeutic Agent ⟶
#  ⟶ Pharmacologic Substance
# • Anti-PD-1/LAG-3 Bispecific Antibody EMB-02 ⟶
#  ⟶ Anti-LAG-3 Monoclonal Antibody ⟶
#  ⟶ Antineoplastic Antibody ⟶
#  ⟶ Antineoplastic Biological Agent ⟶
#  ⟶ Antineoplastic Agent ⟶
#  ⟶ Pharmacologic Substance
# • Anti-PD-1/LAG-3 Bispecific Antibody EMB-02 ⟶
#  ⟶ Anti-LAG-3 Monoclonal Antibody ⟶
#  ⟶ Antineoplastic Antibody ⟶
#  ⟶ Antineoplastic Biological Agent ⟶
#  ⟶ Biological Agent ⟶
#  ⟶ Pharmacologic Substance
# • Anti-PD-1/LAG-3 Bispecific Antibody EMB-02 ⟶
#  ⟶ Anti-LAG-3 Monoclonal Antibody ⟶
#  ⟶ Immune Checkpoint Inhibitor ⟶
#  ⟶ Immune Checkpoint Modulator ⟶
#  ⟶ Immunotherapeutic Agent ⟶
#  ⟶ Pharmacologic Substance
# • Anti-PD-1/LAG-3 Bispecific Antibody EMB-02 ⟶
#  ⟶ Anti-LAG-3 Monoclonal Antibody ⟶
#  ⟶ Monoclonal Antibody ⟶
#  ⟶ Biological Agent ⟶
#  ⟶ Pharmacologic Substance
# • Anti-PD-1/LAG-3 Bispecific Antibody EMB-02 ⟶
#  ⟶ Anti-LAG-3 Monoclonal Antibody ⟶
#  ⟶ Monoclonal Antibody ⟶
#  ⟶ Immunotherapeutic Agent ⟶
#  ⟶ Pharmacologic Substance
# • Anti-PD-1/LAG-3 Bispecific Antibody EMB-02 ⟶
#  ⟶ Bispecific Monoclonal Antibody ⟶
#  ⟶ Monoclonal Antibody ⟶
#  ⟶ Biological Agent ⟶
#  ⟶ Pharmacologic Substance
# • Anti-PD-1/LAG-3 Bispecific Antibody EMB-02 ⟶
#  ⟶ Bispecific Monoclonal Antibody ⟶
#  ⟶ Monoclonal Antibody ⟶
#  ⟶ Immunotherapeutic Agent ⟶
#  ⟶ Pharmacologic Substance

# %%
# All paths between source & target (Olaparib & Pharmacologic Substance - respectively)
# Traversing from a 'narrower' NCI Thesaurus concept to its root concept within its semantic type

# Notice how few paths exists ⟶ This is a consequence to how new of a concept to the NCI Thesaurus Olaparib is

paths = nx.all_simple_paths(
    graph,
    target=name_to_id['Pharmacologic Substance'],
    source=name_to_id['Olaparib']
)
for path in paths:
    print('•', ' ⟶ ' '\n' ' ⟶ '.join(id_to_name[node] for node in path))
# Out:
# • Olaparib ⟶
#  ⟶ Poly (ADP-Ribose) Polymerase Inhibitor ⟶
#  ⟶ Targeted Therapy Agent ⟶
#  ⟶ Antineoplastic Agent ⟶
#  ⟶ Pharmacologic Substance
# • Olaparib ⟶
#  ⟶ Poly (ADP-Ribose) Polymerase Inhibitor ⟶
#  ⟶ Enzyme Inhibitor ⟶
#  ⟶ Pharmacologic Substance

# %% [markdown]
# ### Real World Example of Olaparib (PARP Inhibitor)
#
# - Olaparib (Lynparza®) - is a first-in-class poly (ADP-ribose) polymerase (AKA PARP inhibitor).
#     - Per the NCI Thesaurus:
#         - Accepted_Therapeutic_Use_For:
#             - "Adult patients with deleterious or suspected deleterious germline or somatic homologous recombination repair (HRR) gene-mutated metastatic castration-resistant prostate cancer (mCRPC), who have progressed following prior treatment with enzalutamide or abiraterone."
#         - Accepted_Therapeutic_Use_For:
#             - "Deleterious or suspected deleterious germline or somatic BRCA-mutated (gBRCAm or sBRCAm) advanced epithelial ovarian, fallopian tube or primary peritoneal cancer; deleterious or suspected deleterious germline BRCA-mutated (gBRCAm), HER2-negative metastatic breast cancer."
#          - Chemical_Formula:
#              - C24H23FN4O3
#          - Legacy Concept Name (Prior to FDA Approval):
#              - PARP_Inhibitor_AZD2281
#                  - Lynparza® (Olaparib) was jointly developed and commercialised by AstraZeneca and Merck, Sharp & Dohme
#
# [NCI Thesaurus Reference](https://ncit.nci.nih.gov/ncitbrowser/ConceptReport.jsp?dictionary=NCI_Thesaurus&version=21.08e&ns=ncit&code=C71721&key=n1960133232&b=1&n=null)

# %% [markdown]
# #### Explore all paths (source to root) for Real World histologic diagnosis for Olaparib
#
# - source:
#     - Recurrent Primary Peritoneal High Grade Serous Adenocarcinoma'
# - target:
#     - Neoplasm

# %%
# 
# All paths between source & target (Metplastic Carcinoma & Neoplasm - respectively)
# Traversing from a 'narrower' NCI Thesaurus concept to its root concept within its semantic type

# Notice how few paths exists ⟶ This is a consequence to how new of a concept to the NCI Thesaurus Olaparib is

paths = nx.all_simple_paths(
    graph,
    target=name_to_id['Neoplasm'],
    source=name_to_id['Recurrent Primary Peritoneal High Grade Serous Adenocarcinoma']
)
for path in paths:
    print('•', ' ⟶ ' '\n' ' ⟶ '.join(id_to_name[node] for node in path))
# Out:
# • Recurrent Primary Peritoneal High Grade Serous Adenocarcinoma ⟶
#  ⟶ Primary Peritoneal High Grade Serous Adenocarcinoma ⟶
#  ⟶ Primary Peritoneal Serous Adenocarcinoma ⟶
#  ⟶ Primary Peritoneal Adenocarcinoma ⟶
#  ⟶ Adenocarcinoma ⟶
#  ⟶ Carcinoma ⟶
#  ⟶ Epithelial Neoplasm ⟶
#  ⟶ Neoplasm by Morphology ⟶
#  ⟶ Neoplasm
# • Recurrent Primary Peritoneal High Grade Serous Adenocarcinoma ⟶
#  ⟶ Primary Peritoneal High Grade Serous Adenocarcinoma ⟶
#  ⟶ Primary Peritoneal Serous Adenocarcinoma ⟶
#  ⟶ Primary Peritoneal Adenocarcinoma ⟶
#  ⟶ Adenocarcinoma ⟶
#  ⟶ Carcinoma ⟶
#  ⟶ Malignant Neoplasm ⟶
#  ⟶ Neoplasm by Special Category ⟶
#  ⟶ Neoplasm
# • Recurrent Primary Peritoneal High Grade Serous Adenocarcinoma ⟶
#  ⟶ Primary Peritoneal High Grade Serous Adenocarcinoma ⟶
#  ⟶ Primary Peritoneal Serous Adenocarcinoma ⟶
#  ⟶ Primary Peritoneal Adenocarcinoma ⟶
#  ⟶ Adenocarcinoma ⟶
#  ⟶ Glandular Cell Neoplasm ⟶
#  ⟶ Epithelial Neoplasm ⟶
#  ⟶ Neoplasm by Morphology ⟶
#  ⟶ Neoplasm
# • Recurrent Primary Peritoneal High Grade Serous Adenocarcinoma ⟶
#  ⟶ Primary Peritoneal High Grade Serous Adenocarcinoma ⟶
#  ⟶ Primary Peritoneal Serous Adenocarcinoma ⟶
#  ⟶ Primary Peritoneal Adenocarcinoma ⟶
#  ⟶ Primary Peritoneal Carcinoma ⟶
#  ⟶ Carcinoma ⟶
#  ⟶ Epithelial Neoplasm ⟶
#  ⟶ Neoplasm by Morphology ⟶
#  ⟶ Neoplasm
# • Recurrent Primary Peritoneal High Grade Serous Adenocarcinoma ⟶
#  ⟶ Primary Peritoneal High Grade Serous Adenocarcinoma ⟶
#  ⟶ Primary Peritoneal Serous Adenocarcinoma ⟶
#  ⟶ Primary Peritoneal Adenocarcinoma ⟶
#  ⟶ Primary Peritoneal Carcinoma ⟶
#  ⟶ Carcinoma ⟶
#  ⟶ Malignant Neoplasm ⟶
#  ⟶ Neoplasm by Special Category ⟶
#  ⟶ Neoplasm
# • Recurrent Primary Peritoneal High Grade Serous Adenocarcinoma ⟶
#  ⟶ Primary Peritoneal High Grade Serous Adenocarcinoma ⟶
#  ⟶ Primary Peritoneal Serous Adenocarcinoma ⟶
#  ⟶ Primary Peritoneal Adenocarcinoma ⟶
#  ⟶ Primary Peritoneal Carcinoma ⟶
#  ⟶ Malignant Peritoneal Neoplasm ⟶
#  ⟶ Malignant Peritoneal and Retroperitoneal Neoplasm ⟶
#  ⟶ Peritoneal and Retroperitoneal Neoplasm ⟶
#  ⟶ Neoplasm by Site ⟶
#  ⟶ Neoplasm
# • Recurrent Primary Peritoneal High Grade Serous Adenocarcinoma ⟶
#  ⟶ Primary Peritoneal High Grade Serous Adenocarcinoma ⟶
#  ⟶ Primary Peritoneal Serous Adenocarcinoma ⟶
#  ⟶ Primary Peritoneal Adenocarcinoma ⟶
#  ⟶ Primary Peritoneal Carcinoma ⟶
#  ⟶ Malignant Peritoneal Neoplasm ⟶
#  ⟶ Malignant Peritoneal and Retroperitoneal Neoplasm ⟶
#  ⟶ Malignant Neoplasm ⟶
#  ⟶ Neoplasm by Special Category ⟶
#  ⟶ Neoplasm
# • Recurrent Primary Peritoneal High Grade Serous Adenocarcinoma ⟶
#  ⟶ Primary Peritoneal High Grade Serous Adenocarcinoma ⟶
#  ⟶ Primary Peritoneal Serous Adenocarcinoma ⟶
#  ⟶ Primary Peritoneal Adenocarcinoma ⟶
#  ⟶ Primary Peritoneal Carcinoma ⟶
#  ⟶ Malignant Peritoneal Neoplasm ⟶
#  ⟶ Peritoneal Neoplasm ⟶
#  ⟶ Peritoneal and Retroperitoneal Neoplasm ⟶
#  ⟶ Neoplasm by Site ⟶
#  ⟶ Neoplasm
# • Recurrent Primary Peritoneal High Grade Serous Adenocarcinoma ⟶
#  ⟶ Primary Peritoneal High Grade Serous Adenocarcinoma ⟶
#  ⟶ Primary Peritoneal Serous Adenocarcinoma ⟶
#  ⟶ Serous Adenocarcinoma ⟶
#  ⟶ Adenocarcinoma ⟶
#  ⟶ Carcinoma ⟶
#  ⟶ Epithelial Neoplasm ⟶
#  ⟶ Neoplasm by Morphology ⟶
#  ⟶ Neoplasm
# • Recurrent Primary Peritoneal High Grade Serous Adenocarcinoma ⟶
#  ⟶ Primary Peritoneal High Grade Serous Adenocarcinoma ⟶
#  ⟶ Primary Peritoneal Serous Adenocarcinoma ⟶
#  ⟶ Serous Adenocarcinoma ⟶
#  ⟶ Adenocarcinoma ⟶
#  ⟶ Carcinoma ⟶
#  ⟶ Malignant Neoplasm ⟶
#  ⟶ Neoplasm by Special Category ⟶
#  ⟶ Neoplasm
# • Recurrent Primary Peritoneal High Grade Serous Adenocarcinoma ⟶
#  ⟶ Primary Peritoneal High Grade Serous Adenocarcinoma ⟶
#  ⟶ Primary Peritoneal Serous Adenocarcinoma ⟶
#  ⟶ Serous Adenocarcinoma ⟶
#  ⟶ Adenocarcinoma ⟶
#  ⟶ Glandular Cell Neoplasm ⟶
#  ⟶ Epithelial Neoplasm ⟶
#  ⟶ Neoplasm by Morphology ⟶
#  ⟶ Neoplasm
# • Recurrent Primary Peritoneal High Grade Serous Adenocarcinoma ⟶
#  ⟶ Primary Peritoneal High Grade Serous Adenocarcinoma ⟶
#  ⟶ Primary Peritoneal Serous Adenocarcinoma ⟶
#  ⟶ Serous Adenocarcinoma ⟶
#  ⟶ Serous Neoplasm ⟶
#  ⟶ Glandular Cell Neoplasm ⟶
#  ⟶ Epithelial Neoplasm ⟶
#  ⟶ Neoplasm by Morphology ⟶
#  ⟶ Neoplasm
# • Recurrent Primary Peritoneal High Grade Serous Adenocarcinoma ⟶
#  ⟶ Recurrent Primary Peritoneal Serous Adenocarcinoma ⟶
#  ⟶ Recurrent Primary Peritoneal Adenocarcinoma ⟶
#  ⟶ Recurrent Primary Peritoneal Carcinoma ⟶
#  ⟶ Recurrent Primary Malignant Neoplasm ⟶
#  ⟶ Recurrent Malignant Neoplasm ⟶
#  ⟶ Recurrent Neoplasm ⟶
#  ⟶ Neoplasm by Special Category ⟶
#  ⟶ Neoplasm
# • Recurrent Primary Peritoneal High Grade Serous Adenocarcinoma ⟶
#  ⟶ Recurrent Primary Peritoneal Serous Adenocarcinoma ⟶
#  ⟶ Recurrent Primary Peritoneal Adenocarcinoma ⟶
#  ⟶ Recurrent Primary Peritoneal Carcinoma ⟶
#  ⟶ Recurrent Primary Malignant Neoplasm ⟶
#  ⟶ Recurrent Malignant Neoplasm ⟶
#  ⟶ Malignant Neoplasm ⟶
#  ⟶ Neoplasm by Special Category ⟶
#  ⟶ Neoplasm
# • Recurrent Primary Peritoneal High Grade Serous Adenocarcinoma ⟶
#  ⟶ Recurrent Primary Peritoneal Serous Adenocarcinoma ⟶
#  ⟶ Recurrent Primary Peritoneal Adenocarcinoma ⟶
#  ⟶ Recurrent Primary Peritoneal Carcinoma ⟶
#  ⟶ Primary Peritoneal Carcinoma ⟶
#  ⟶ Carcinoma ⟶
#  ⟶ Epithelial Neoplasm ⟶
#  ⟶ Neoplasm by Morphology ⟶
#  ⟶ Neoplasm
# • Recurrent Primary Peritoneal High Grade Serous Adenocarcinoma ⟶
#  ⟶ Recurrent Primary Peritoneal Serous Adenocarcinoma ⟶
#  ⟶ Recurrent Primary Peritoneal Adenocarcinoma ⟶
#  ⟶ Recurrent Primary Peritoneal Carcinoma ⟶
#  ⟶ Primary Peritoneal Carcinoma ⟶
#  ⟶ Carcinoma ⟶
#  ⟶ Malignant Neoplasm ⟶
#  ⟶ Neoplasm by Special Category ⟶
#  ⟶ Neoplasm
# • Recurrent Primary Peritoneal High Grade Serous Adenocarcinoma ⟶
#  ⟶ Recurrent Primary Peritoneal Serous Adenocarcinoma ⟶
#  ⟶ Recurrent Primary Peritoneal Adenocarcinoma ⟶
#  ⟶ Recurrent Primary Peritoneal Carcinoma ⟶
#  ⟶ Primary Peritoneal Carcinoma ⟶
#  ⟶ Malignant Peritoneal Neoplasm ⟶
#  ⟶ Malignant Peritoneal and Retroperitoneal Neoplasm ⟶
#  ⟶ Peritoneal and Retroperitoneal Neoplasm ⟶
#  ⟶ Neoplasm by Site ⟶
#  ⟶ Neoplasm
# • Recurrent Primary Peritoneal High Grade Serous Adenocarcinoma ⟶
#  ⟶ Recurrent Primary Peritoneal Serous Adenocarcinoma ⟶
#  ⟶ Recurrent Primary Peritoneal Adenocarcinoma ⟶
#  ⟶ Recurrent Primary Peritoneal Carcinoma ⟶
#  ⟶ Primary Peritoneal Carcinoma ⟶
#  ⟶ Malignant Peritoneal Neoplasm ⟶
#  ⟶ Malignant Peritoneal and Retroperitoneal Neoplasm ⟶
#  ⟶ Malignant Neoplasm ⟶
#  ⟶ Neoplasm by Special Category ⟶
#  ⟶ Neoplasm
# • Recurrent Primary Peritoneal High Grade Serous Adenocarcinoma ⟶
#  ⟶ Recurrent Primary Peritoneal Serous Adenocarcinoma ⟶
#  ⟶ Recurrent Primary Peritoneal Adenocarcinoma ⟶
#  ⟶ Recurrent Primary Peritoneal Carcinoma ⟶
#  ⟶ Primary Peritoneal Carcinoma ⟶
#  ⟶ Malignant Peritoneal Neoplasm ⟶
#  ⟶ Peritoneal Neoplasm ⟶
#  ⟶ Peritoneal and Retroperitoneal Neoplasm ⟶
#  ⟶ Neoplasm by Site ⟶
#  ⟶ Neoplasm
# • Recurrent Primary Peritoneal High Grade Serous Adenocarcinoma ⟶
#  ⟶ Recurrent Primary Peritoneal Serous Adenocarcinoma ⟶
#  ⟶ Recurrent Primary Peritoneal Adenocarcinoma ⟶
#  ⟶ Recurrent Primary Peritoneal Carcinoma ⟶
#  ⟶ Recurrent Carcinoma ⟶
#  ⟶ Carcinoma ⟶
#  ⟶ Epithelial Neoplasm ⟶
#  ⟶ Neoplasm by Morphology ⟶
#  ⟶ Neoplasm
# • Recurrent Primary Peritoneal High Grade Serous Adenocarcinoma ⟶
#  ⟶ Recurrent Primary Peritoneal Serous Adenocarcinoma ⟶
#  ⟶ Recurrent Primary Peritoneal Adenocarcinoma ⟶
#  ⟶ Recurrent Primary Peritoneal Carcinoma ⟶
#  ⟶ Recurrent Carcinoma ⟶
#  ⟶ Carcinoma ⟶
#  ⟶ Malignant Neoplasm ⟶
#  ⟶ Neoplasm by Special Category ⟶
#  ⟶ Neoplasm
# • Recurrent Primary Peritoneal High Grade Serous Adenocarcinoma ⟶
#  ⟶ Recurrent Primary Peritoneal Serous Adenocarcinoma ⟶
#  ⟶ Recurrent Primary Peritoneal Adenocarcinoma ⟶
#  ⟶ Recurrent Primary Peritoneal Carcinoma ⟶
#  ⟶ Recurrent Carcinoma ⟶
#  ⟶ Recurrent Malignant Neoplasm ⟶
#  ⟶ Recurrent Neoplasm ⟶
#  ⟶ Neoplasm by Special Category ⟶
#  ⟶ Neoplasm
# • Recurrent Primary Peritoneal High Grade Serous Adenocarcinoma ⟶
#  ⟶ Recurrent Primary Peritoneal Serous Adenocarcinoma ⟶
#  ⟶ Recurrent Primary Peritoneal Adenocarcinoma ⟶
#  ⟶ Recurrent Primary Peritoneal Carcinoma ⟶
#  ⟶ Recurrent Carcinoma ⟶
#  ⟶ Recurrent Malignant Neoplasm ⟶
#  ⟶ Malignant Neoplasm ⟶
#  ⟶ Neoplasm by Special Category ⟶
#  ⟶ Neoplasm
# • Recurrent Primary Peritoneal High Grade Serous Adenocarcinoma ⟶
#  ⟶ Recurrent Primary Peritoneal Serous Adenocarcinoma ⟶
#  ⟶ Recurrent Primary Peritoneal Adenocarcinoma ⟶
#  ⟶ Recurrent Adenocarcinoma ⟶
#  ⟶ Adenocarcinoma ⟶
#  ⟶ Carcinoma ⟶
#  ⟶ Epithelial Neoplasm ⟶
#  ⟶ Neoplasm by Morphology ⟶
#  ⟶ Neoplasm
# • Recurrent Primary Peritoneal High Grade Serous Adenocarcinoma ⟶
#  ⟶ Recurrent Primary Peritoneal Serous Adenocarcinoma ⟶
#  ⟶ Recurrent Primary Peritoneal Adenocarcinoma ⟶
#  ⟶ Recurrent Adenocarcinoma ⟶
#  ⟶ Adenocarcinoma ⟶
#  ⟶ Carcinoma ⟶
#  ⟶ Malignant Neoplasm ⟶
#  ⟶ Neoplasm by Special Category ⟶
#  ⟶ Neoplasm
# • Recurrent Primary Peritoneal High Grade Serous Adenocarcinoma ⟶
#  ⟶ Recurrent Primary Peritoneal Serous Adenocarcinoma ⟶
#  ⟶ Recurrent Primary Peritoneal Adenocarcinoma ⟶
#  ⟶ Recurrent Adenocarcinoma ⟶
#  ⟶ Adenocarcinoma ⟶
#  ⟶ Glandular Cell Neoplasm ⟶
#  ⟶ Epithelial Neoplasm ⟶
#  ⟶ Neoplasm by Morphology ⟶
#  ⟶ Neoplasm
# • Recurrent Primary Peritoneal High Grade Serous Adenocarcinoma ⟶
#  ⟶ Recurrent Primary Peritoneal Serous Adenocarcinoma ⟶
#  ⟶ Recurrent Primary Peritoneal Adenocarcinoma ⟶
#  ⟶ Recurrent Adenocarcinoma ⟶
#  ⟶ Recurrent Carcinoma ⟶
#  ⟶ Carcinoma ⟶
#  ⟶ Epithelial Neoplasm ⟶
#  ⟶ Neoplasm by Morphology ⟶
#  ⟶ Neoplasm
# • Recurrent Primary Peritoneal High Grade Serous Adenocarcinoma ⟶
#  ⟶ Recurrent Primary Peritoneal Serous Adenocarcinoma ⟶
#  ⟶ Recurrent Primary Peritoneal Adenocarcinoma ⟶
#  ⟶ Recurrent Adenocarcinoma ⟶
#  ⟶ Recurrent Carcinoma ⟶
#  ⟶ Carcinoma ⟶
#  ⟶ Malignant Neoplasm ⟶
#  ⟶ Neoplasm by Special Category ⟶
#  ⟶ Neoplasm
# • Recurrent Primary Peritoneal High Grade Serous Adenocarcinoma ⟶
#  ⟶ Recurrent Primary Peritoneal Serous Adenocarcinoma ⟶
#  ⟶ Recurrent Primary Peritoneal Adenocarcinoma ⟶
#  ⟶ Recurrent Adenocarcinoma ⟶
#  ⟶ Recurrent Carcinoma ⟶
#  ⟶ Recurrent Malignant Neoplasm ⟶
#  ⟶ Recurrent Neoplasm ⟶
#  ⟶ Neoplasm by Special Category ⟶
#  ⟶ Neoplasm
# • Recurrent Primary Peritoneal High Grade Serous Adenocarcinoma ⟶
#  ⟶ Recurrent Primary Peritoneal Serous Adenocarcinoma ⟶
#  ⟶ Recurrent Primary Peritoneal Adenocarcinoma ⟶
#  ⟶ Recurrent Adenocarcinoma ⟶
#  ⟶ Recurrent Carcinoma ⟶
#  ⟶ Recurrent Malignant Neoplasm ⟶
#  ⟶ Malignant Neoplasm ⟶
#  ⟶ Neoplasm by Special Category ⟶
#  ⟶ Neoplasm
# • Recurrent Primary Peritoneal High Grade Serous Adenocarcinoma ⟶
#  ⟶ Recurrent Primary Peritoneal Serous Adenocarcinoma ⟶
#  ⟶ Recurrent Primary Peritoneal Adenocarcinoma ⟶
#  ⟶ Primary Peritoneal Adenocarcinoma ⟶
#  ⟶ Adenocarcinoma ⟶
#  ⟶ Carcinoma ⟶
#  ⟶ Epithelial Neoplasm ⟶
#  ⟶ Neoplasm by Morphology ⟶
#  ⟶ Neoplasm
# • Recurrent Primary Peritoneal High Grade Serous Adenocarcinoma ⟶
#  ⟶ Recurrent Primary Peritoneal Serous Adenocarcinoma ⟶
#  ⟶ Recurrent Primary Peritoneal Adenocarcinoma ⟶
#  ⟶ Primary Peritoneal Adenocarcinoma ⟶
#  ⟶ Adenocarcinoma ⟶
#  ⟶ Carcinoma ⟶
#  ⟶ Malignant Neoplasm ⟶
#  ⟶ Neoplasm by Special Category ⟶
#  ⟶ Neoplasm
# • Recurrent Primary Peritoneal High Grade Serous Adenocarcinoma ⟶
#  ⟶ Recurrent Primary Peritoneal Serous Adenocarcinoma ⟶
#  ⟶ Recurrent Primary Peritoneal Adenocarcinoma ⟶
#  ⟶ Primary Peritoneal Adenocarcinoma ⟶
#  ⟶ Adenocarcinoma ⟶
#  ⟶ Glandular Cell Neoplasm ⟶
#  ⟶ Epithelial Neoplasm ⟶
#  ⟶ Neoplasm by Morphology ⟶
#  ⟶ Neoplasm
# • Recurrent Primary Peritoneal High Grade Serous Adenocarcinoma ⟶
#  ⟶ Recurrent Primary Peritoneal Serous Adenocarcinoma ⟶
#  ⟶ Recurrent Primary Peritoneal Adenocarcinoma ⟶
#  ⟶ Primary Peritoneal Adenocarcinoma ⟶
#  ⟶ Primary Peritoneal Carcinoma ⟶
#  ⟶ Carcinoma ⟶
#  ⟶ Epithelial Neoplasm ⟶
#  ⟶ Neoplasm by Morphology ⟶
#  ⟶ Neoplasm
# • Recurrent Primary Peritoneal High Grade Serous Adenocarcinoma ⟶
#  ⟶ Recurrent Primary Peritoneal Serous Adenocarcinoma ⟶
#  ⟶ Recurrent Primary Peritoneal Adenocarcinoma ⟶
#  ⟶ Primary Peritoneal Adenocarcinoma ⟶
#  ⟶ Primary Peritoneal Carcinoma ⟶
#  ⟶ Carcinoma ⟶
#  ⟶ Malignant Neoplasm ⟶
#  ⟶ Neoplasm by Special Category ⟶
#  ⟶ Neoplasm
# • Recurrent Primary Peritoneal High Grade Serous Adenocarcinoma ⟶
#  ⟶ Recurrent Primary Peritoneal Serous Adenocarcinoma ⟶
#  ⟶ Recurrent Primary Peritoneal Adenocarcinoma ⟶
#  ⟶ Primary Peritoneal Adenocarcinoma ⟶
#  ⟶ Primary Peritoneal Carcinoma ⟶
#  ⟶ Malignant Peritoneal Neoplasm ⟶
#  ⟶ Malignant Peritoneal and Retroperitoneal Neoplasm ⟶
#  ⟶ Peritoneal and Retroperitoneal Neoplasm ⟶
#  ⟶ Neoplasm by Site ⟶
#  ⟶ Neoplasm
# • Recurrent Primary Peritoneal High Grade Serous Adenocarcinoma ⟶
#  ⟶ Recurrent Primary Peritoneal Serous Adenocarcinoma ⟶
#  ⟶ Recurrent Primary Peritoneal Adenocarcinoma ⟶
#  ⟶ Primary Peritoneal Adenocarcinoma ⟶
#  ⟶ Primary Peritoneal Carcinoma ⟶
#  ⟶ Malignant Peritoneal Neoplasm ⟶
#  ⟶ Malignant Peritoneal and Retroperitoneal Neoplasm ⟶
#  ⟶ Malignant Neoplasm ⟶
#  ⟶ Neoplasm by Special Category ⟶
#  ⟶ Neoplasm
# • Recurrent Primary Peritoneal High Grade Serous Adenocarcinoma ⟶
#  ⟶ Recurrent Primary Peritoneal Serous Adenocarcinoma ⟶
#  ⟶ Recurrent Primary Peritoneal Adenocarcinoma ⟶
#  ⟶ Primary Peritoneal Adenocarcinoma ⟶
#  ⟶ Primary Peritoneal Carcinoma ⟶
#  ⟶ Malignant Peritoneal Neoplasm ⟶
#  ⟶ Peritoneal Neoplasm ⟶
#  ⟶ Peritoneal and Retroperitoneal Neoplasm ⟶
#  ⟶ Neoplasm by Site ⟶
#  ⟶ Neoplasm
# • Recurrent Primary Peritoneal High Grade Serous Adenocarcinoma ⟶
#  ⟶ Recurrent Primary Peritoneal Serous Adenocarcinoma ⟶
#  ⟶ Primary Peritoneal Serous Adenocarcinoma ⟶
#  ⟶ Primary Peritoneal Adenocarcinoma ⟶
#  ⟶ Adenocarcinoma ⟶
#  ⟶ Carcinoma ⟶
#  ⟶ Epithelial Neoplasm ⟶
#  ⟶ Neoplasm by Morphology ⟶
#  ⟶ Neoplasm
# • Recurrent Primary Peritoneal High Grade Serous Adenocarcinoma ⟶
#  ⟶ Recurrent Primary Peritoneal Serous Adenocarcinoma ⟶
#  ⟶ Primary Peritoneal Serous Adenocarcinoma ⟶
#  ⟶ Primary Peritoneal Adenocarcinoma ⟶
#  ⟶ Adenocarcinoma ⟶
#  ⟶ Carcinoma ⟶
#  ⟶ Malignant Neoplasm ⟶
#  ⟶ Neoplasm by Special Category ⟶
#  ⟶ Neoplasm
# • Recurrent Primary Peritoneal High Grade Serous Adenocarcinoma ⟶
#  ⟶ Recurrent Primary Peritoneal Serous Adenocarcinoma ⟶
#  ⟶ Primary Peritoneal Serous Adenocarcinoma ⟶
#  ⟶ Primary Peritoneal Adenocarcinoma ⟶
#  ⟶ Adenocarcinoma ⟶
#  ⟶ Glandular Cell Neoplasm ⟶
#  ⟶ Epithelial Neoplasm ⟶
#  ⟶ Neoplasm by Morphology ⟶
#  ⟶ Neoplasm
# • Recurrent Primary Peritoneal High Grade Serous Adenocarcinoma ⟶
#  ⟶ Recurrent Primary Peritoneal Serous Adenocarcinoma ⟶
#  ⟶ Primary Peritoneal Serous Adenocarcinoma ⟶
#  ⟶ Primary Peritoneal Adenocarcinoma ⟶
#  ⟶ Primary Peritoneal Carcinoma ⟶
#  ⟶ Carcinoma ⟶
#  ⟶ Epithelial Neoplasm ⟶
#  ⟶ Neoplasm by Morphology ⟶
#  ⟶ Neoplasm
# • Recurrent Primary Peritoneal High Grade Serous Adenocarcinoma ⟶
#  ⟶ Recurrent Primary Peritoneal Serous Adenocarcinoma ⟶
#  ⟶ Primary Peritoneal Serous Adenocarcinoma ⟶
#  ⟶ Primary Peritoneal Adenocarcinoma ⟶
#  ⟶ Primary Peritoneal Carcinoma ⟶
#  ⟶ Carcinoma ⟶
#  ⟶ Malignant Neoplasm ⟶
#  ⟶ Neoplasm by Special Category ⟶
#  ⟶ Neoplasm
# • Recurrent Primary Peritoneal High Grade Serous Adenocarcinoma ⟶
#  ⟶ Recurrent Primary Peritoneal Serous Adenocarcinoma ⟶
#  ⟶ Primary Peritoneal Serous Adenocarcinoma ⟶
#  ⟶ Primary Peritoneal Adenocarcinoma ⟶
#  ⟶ Primary Peritoneal Carcinoma ⟶
#  ⟶ Malignant Peritoneal Neoplasm ⟶
#  ⟶ Malignant Peritoneal and Retroperitoneal Neoplasm ⟶
#  ⟶ Peritoneal and Retroperitoneal Neoplasm ⟶
#  ⟶ Neoplasm by Site ⟶
#  ⟶ Neoplasm
# • Recurrent Primary Peritoneal High Grade Serous Adenocarcinoma ⟶
#  ⟶ Recurrent Primary Peritoneal Serous Adenocarcinoma ⟶
#  ⟶ Primary Peritoneal Serous Adenocarcinoma ⟶
#  ⟶ Primary Peritoneal Adenocarcinoma ⟶
#  ⟶ Primary Peritoneal Carcinoma ⟶
#  ⟶ Malignant Peritoneal Neoplasm ⟶
#  ⟶ Malignant Peritoneal and Retroperitoneal Neoplasm ⟶
#  ⟶ Malignant Neoplasm ⟶
#  ⟶ Neoplasm by Special Category ⟶
#  ⟶ Neoplasm
# • Recurrent Primary Peritoneal High Grade Serous Adenocarcinoma ⟶
#  ⟶ Recurrent Primary Peritoneal Serous Adenocarcinoma ⟶
#  ⟶ Primary Peritoneal Serous Adenocarcinoma ⟶
#  ⟶ Primary Peritoneal Adenocarcinoma ⟶
#  ⟶ Primary Peritoneal Carcinoma ⟶
#  ⟶ Malignant Peritoneal Neoplasm ⟶
#  ⟶ Peritoneal Neoplasm ⟶
#  ⟶ Peritoneal and Retroperitoneal Neoplasm ⟶
#  ⟶ Neoplasm by Site ⟶
#  ⟶ Neoplasm
# • Recurrent Primary Peritoneal High Grade Serous Adenocarcinoma ⟶
#  ⟶ Recurrent Primary Peritoneal Serous Adenocarcinoma ⟶
#  ⟶ Primary Peritoneal Serous Adenocarcinoma ⟶
#  ⟶ Serous Adenocarcinoma ⟶
#  ⟶ Adenocarcinoma ⟶
#  ⟶ Carcinoma ⟶
#  ⟶ Epithelial Neoplasm ⟶
#  ⟶ Neoplasm by Morphology ⟶
#  ⟶ Neoplasm
# • Recurrent Primary Peritoneal High Grade Serous Adenocarcinoma ⟶
#  ⟶ Recurrent Primary Peritoneal Serous Adenocarcinoma ⟶
#  ⟶ Primary Peritoneal Serous Adenocarcinoma ⟶
#  ⟶ Serous Adenocarcinoma ⟶
#  ⟶ Adenocarcinoma ⟶
#  ⟶ Carcinoma ⟶
#  ⟶ Malignant Neoplasm ⟶
#  ⟶ Neoplasm by Special Category ⟶
#  ⟶ Neoplasm
# • Recurrent Primary Peritoneal High Grade Serous Adenocarcinoma ⟶
#  ⟶ Recurrent Primary Peritoneal Serous Adenocarcinoma ⟶
#  ⟶ Primary Peritoneal Serous Adenocarcinoma ⟶
#  ⟶ Serous Adenocarcinoma ⟶
#  ⟶ Adenocarcinoma ⟶
#  ⟶ Glandular Cell Neoplasm ⟶
#  ⟶ Epithelial Neoplasm ⟶
#  ⟶ Neoplasm by Morphology ⟶
#  ⟶ Neoplasm
# • Recurrent Primary Peritoneal High Grade Serous Adenocarcinoma ⟶
#  ⟶ Recurrent Primary Peritoneal Serous Adenocarcinoma ⟶
#  ⟶ Primary Peritoneal Serous Adenocarcinoma ⟶
#  ⟶ Serous Adenocarcinoma ⟶
#  ⟶ Serous Neoplasm ⟶
#  ⟶ Glandular Cell Neoplasm ⟶
#  ⟶ Epithelial Neoplasm ⟶
#  ⟶ Neoplasm by Morphology ⟶
#  ⟶ Neoplasm
